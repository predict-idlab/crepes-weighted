# %% [markdown]
# # Simulation Experiments

# %%
import sys
sys.path.append('..')
sys.path.append('../src')

import opendatasets as od
import tempfile
import zipfile
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor
from src.crepes_weighted import WrapRegressor
import copy
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
import dabest
# Out:
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def weighted_sample(weights, frac=0.5):
    return np.random.choice(range(len(weights)), size=int(len(weights) * frac), p=weights)

# %% [markdown]
# ## Airfoil Dataset

# %%
with tempfile.TemporaryDirectory() as temp_dir:
    od.download("https://archive.ics.uci.edu/static/public/291/airfoil+self+noise.zip",
                temp_dir)
    with zipfile.ZipFile(temp_dir + "/airfoil+self+noise.zip", 'r') as zip_ref:
        df = pd.read_csv(zip_ref.open('airfoil_self_noise.dat'), sep='\t', header=None)
        df.columns = ['Frequency', 'Angle', 'Chord', 'Velocity', 'Suction', 'Sound']
        df['Log_freq'] = np.log(df['Frequency'])
        df['Log_suct'] = np.log(df['Suction'])
        df = df.drop(columns=['Frequency', 'Suction'])
# Out:
# Downloading https://archive.ics.uci.edu/static/public/291/airfoil+self+noise.zip to /tmp/tmp1ks7qt5f/airfoil+self+noise.zip
# 65536it [00:01, 35566.66it/s]

# %%
NSim = 1000
confidence = 0.8

for i in tqdm(range(NSim)):
    # Without covariate-shift
    X_train, X_test, y_train, y_test = train_test_split(df.drop('Sound', axis=1), df['Sound'], test_size=0.5)
    X_train_prop, X_cal, y_train_prop, y_cal = train_test_split(X_train, y_train, test_size=0.5)

    shifted_likelihood_train_prop = np.exp(X_train_prop[['Log_freq', 'Log_suct']].to_numpy() @ np.array([-1, 1]))
    shifted_weights_train_prop = shifted_likelihood_train_prop / np.sum(shifted_likelihood_train_prop)
    shifted_likelihood_test = np.exp(X_test[['Log_freq', 'Log_suct']].to_numpy() @ np.array([-1, 1]))
    shifted_weights_test = shifted_likelihood_test / np.sum(shifted_likelihood_test)
    shifted_likelihood_cal = np.exp(X_cal[['Log_freq', 'Log_suct']].to_numpy() @ np.array([-1, 1]))
    
    rf_cps = WrapRegressor(RandomForestRegressor(n_estimators=100, random_state=17))
    rf_cps.fit(X_train_prop, y_train_prop)
    rf_cp = copy.deepcopy(rf_cps)
    rf_cp.calibrate(X_cal, y_cal, cps=False)
    rf_cps.calibrate(X_cal, y_cal, cps=True)
    
    idx_no_shift = weighted_sample(np.ones(len(shifted_weights_test))/len(shifted_weights_test), frac=0.25)
    idx_shift = weighted_sample(shifted_weights_test, frac=0.25)

    n_reduced = np.sum(np.abs(shifted_likelihood_cal))**2 / np.sum(shifted_likelihood_cal**2)
    n = len(shifted_likelihood_cal)
        
    result_cps_no_shift = rf_cps.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift],
                                  confidence=confidence)
    result_cps_shift_not_weighted = rf_cps.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift],
                                            confidence=confidence)
    result_cp_no_shift = rf_cp.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift],
                                    confidence=confidence)
    result_cp_shift_not_weighted = rf_cp.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift],
                                              confidence=confidence)
    
    idx_cal_n_reduced = np.random.choice(range(n), size=int(n_reduced), replace=False)
    
    rf_cps_shift = copy.deepcopy(rf_cps)
    rf_cps_no_shift_reduced = copy.deepcopy(rf_cps)
    rf_cp_shift = copy.deepcopy(rf_cp)
    rf_cp_no_shift_reduced = copy.deepcopy(rf_cp)

    
    rf_cps_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=True)
    rf_cp_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=False)

    rf_cps_no_shift_reduced.calibrate(X_cal.iloc[idx_cal_n_reduced], y_cal.iloc[idx_cal_n_reduced], cps=True)    
    rf_cp_no_shift_reduced.calibrate(X_cal.iloc[idx_cal_n_reduced], y_cal.iloc[idx_cal_n_reduced], cps=False)
    
    result_cps_shift_weighted = rf_cps_shift.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift].to_numpy(), 
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cp_shift_weighted = rf_cp_shift.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift].to_numpy(), 
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cps_no_shift_reduced = rf_cps_no_shift_reduced.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift].to_numpy(), 
                    confidence=confidence)
    result_cp_no_shift_reduced = rf_cp_no_shift_reduced.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift].to_numpy(),
                    confidence=confidence)
    
    result_cps_shift_weighted["reduced_n"] = n_reduced
    result_cp_shift_weighted["reduced_n"] = n_reduced
    result_cps_no_shift_reduced["reduced_n"] = int(n_reduced)
    result_cp_no_shift_reduced["reduced_n"] = int(n_reduced)
    
    result_cps_no_shift["sim_id"] = i
    result_cps_shift_not_weighted["sim_id"] = i
    result_cps_shift_weighted["sim_id"] = i
    result_cp_no_shift["sim_id"] = i
    result_cp_shift_not_weighted["sim_id"] = i
    result_cp_shift_weighted["sim_id"] = i
    result_cps_no_shift_reduced["sim_id"] = i
    result_cp_no_shift_reduced["sim_id"] = i
    
    if i == 0:
        df_results_cps_no_shift = pd.DataFrame(result_cps_no_shift, index=[0])
        df_results_cps_shift_not_weighted = pd.DataFrame(result_cps_shift_not_weighted, index=[0])
        df_results_cps_shift_weighted = pd.DataFrame(result_cps_shift_weighted, index=[0])
        df_results_cp_no_shift = pd.DataFrame(result_cp_no_shift, index=[0])
        df_results_cp_shift_not_weighted = pd.DataFrame(result_cp_shift_not_weighted, index=[0])
        df_results_cp_shift_weighted = pd.DataFrame(result_cp_shift_weighted, index=[0])
        df_results_cps_no_shift_reduced = pd.DataFrame(result_cps_no_shift_reduced, index=[0])
        df_results_cp_no_shift_reduced = pd.DataFrame(result_cp_no_shift_reduced, index=[0])
    else:
        df_results_cps_no_shift = pd.concat([df_results_cps_no_shift, pd.DataFrame(result_cps_no_shift, index=[0])])
        df_results_cps_shift_not_weighted = pd.concat([df_results_cps_shift_not_weighted, pd.DataFrame(result_cps_shift_not_weighted, index=[0])])
        df_results_cps_shift_weighted = pd.concat([df_results_cps_shift_weighted, pd.DataFrame(result_cps_shift_weighted, index=[0])])
        df_results_cp_no_shift = pd.concat([df_results_cp_no_shift, pd.DataFrame(result_cp_no_shift, index=[0])])
        df_results_cp_shift_not_weighted = pd.concat([df_results_cp_shift_not_weighted, pd.DataFrame(result_cp_shift_not_weighted, index=[0])])
        df_results_cp_shift_weighted = pd.concat([df_results_cp_shift_weighted, pd.DataFrame(result_cp_shift_weighted, index=[0])])
        df_results_cps_no_shift_reduced = pd.concat([df_results_cps_no_shift_reduced, pd.DataFrame(result_cps_no_shift_reduced, index=[0])])
        df_results_cp_no_shift_reduced = pd.concat([df_results_cp_no_shift_reduced, pd.DataFrame(result_cp_no_shift_reduced, index=[0])])
# Out:
# 100%|██████████| 1000/1000 [02:45<00:00,  6.03it/s]

# %%
df_results_cps_no_shift['Method'] = 'SCPS (no shift)'
df_results_cps_shift_not_weighted['Method'] = 'SCPS (shift)'
df_results_cps_shift_weighted['Method'] = 'WSCPS (shift)'
df_results_cps_no_shift_reduced['Method'] = 'SCPS (no shift, reduced)'
df_results_cp_no_shift['Method'] = 'CP (no shift)'
df_results_cp_shift_not_weighted['Method'] = 'CP (shift)'
df_results_cp_shift_weighted['Method'] = 'WCP (shift)'
df_results_cp_no_shift_reduced['Method'] = 'CP (no shift, reduced)'

df_results = pd.concat([df_results_cps_no_shift, df_results_cps_shift_not_weighted, df_results_cps_shift_weighted,
                        df_results_cps_no_shift_reduced,
                        df_results_cp_no_shift, df_results_cp_shift_not_weighted, df_results_cp_shift_weighted,
                        df_results_cp_no_shift_reduced])

df_results["Coverage"] = 1 - df_results["error"]

fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results[df_results["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper left")
# set the color palette
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper left")
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="Coverage", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper left")
axs[0].vlines(0.8, 0, 250, color='r', linestyle='--')
axs[1].vlines(0.8, 0, 160, color='r', linestyle='--')
axs[2].vlines(0.8, 0, 175, color='r', linestyle='--')
plt.tight_layout()
fig.savefig("plots/coverage_airfoil.pdf")
plt.show()
# Out:
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results[df_results["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper right")
# set the color palette
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper right")
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="CRPS", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper right")
plt.tight_layout()
fig.savefig("plots/crps_airfoil.pdf")
plt.show()
# Out:
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import scipy.stats as ss
import scikit_posthocs as sp

df_results_cps = df_results[df_results["Method"].isin(['SCPS (no shift)', 'SCPS (shift)', 'WSCPS (shift)', 'SCPS (no shift, reduced)'])]

avg_rank = df_results_cps.groupby("sim_id")["CRPS"].rank(pct=True).groupby(df_results_cps.Method).mean()

ss.friedmanchisquare(*[df_results_cps[df_results_cps.Method == method].CRPS for method in df_results_cps.Method.unique()])

test_results = sp.posthoc_nemenyi_friedman(df_results_cps, melted=True, y_col="CRPS", block_col="sim_id", group_col="Method")


plt.figure(figsize=(10, 2))
# plt.title("Post-hoc Friedman-Nemenyi test for CRPS")
sp.critical_difference_diagram(avg_rank, test_results, color_palette={"SCPS (no shift)": sns.color_palette()[0],
                                                                      "SCPS (shift)": sns.color_palette()[1],
                                                                      "WSCPS (shift)": sns.color_palette()[2],
                                                                      "SCPS (no shift, reduced)": sns.color_palette()[3]})
plt.tight_layout()
plt.savefig("plots/nemenyi_airfoil.pdf")
plt.show()
# Out:
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %% [markdown]
# ## Synthetic Dataset (Kang and Schafer (2007))
# **Note: that this synthetic dataset is also used in Yang et al. 2022**

# %%
def synthetic_kang_schafer_2007(n=2000, weights=None):
    if weights is None:
        weights = np.ones(n)/n
    x1 = np.random.normal(size=n)
    x2 = np.random.normal(size=n)
    x3 = np.random.normal(size=n)
    x4 = np.random.normal(size=n)
    
    y = 210 + 27.4*x1 + 13.7*x2 + 13.7*x3 + 13.7*x4 + np.random.normal(size=n)
    
    return np.stack([x1, x2, x3, x4], axis=1), y

# %%
NSim = 1000
confidence = 0.8

for i in tqdm(range(NSim)):
    X, y = synthetic_kang_schafer_2007()
    # Without covariate-shift
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
    X_train_prop, X_cal, y_train_prop, y_cal = train_test_split(X_train, y_train, test_size=0.5)

    shift_weights = np.array([-1, 0.5, -0.25, -0.1])
    shifted_likelihood_train_prop = np.exp(X_train_prop @ shift_weights)
    shifted_weights_train_prop = shifted_likelihood_train_prop / np.sum(shifted_likelihood_train_prop)
    shifted_likelihood_test = np.exp(X_test @ shift_weights)
    shifted_weights_test = shifted_likelihood_test / np.sum(shifted_likelihood_test)
    shifted_likelihood_cal =  np.exp(X_cal @ shift_weights)
    
    rf_cps = WrapRegressor(RandomForestRegressor(n_estimators=100, random_state=17))
    rf_cps.fit(X_train_prop, y_train_prop)
    rf_cp = copy.deepcopy(rf_cps)
    rf_cp.calibrate(X_cal, y_cal, cps=False)
    rf_cps.calibrate(X_cal, y_cal, cps=True)
    
    idx_no_shift = weighted_sample(np.ones(len(shifted_weights_test))/len(shifted_weights_test), frac=0.25)
    idx_shift = weighted_sample(shifted_weights_test, frac=0.25)

    n_reduced = np.sum(np.abs(shifted_likelihood_cal))**2 / np.sum(shifted_likelihood_cal**2)
    n = len(shifted_likelihood_cal)
        
    result_cps_no_shift = rf_cps.evaluate(X_test[idx_no_shift], y_test[idx_no_shift],
                                  confidence=confidence)
    result_cps_shift_not_weighted = rf_cps.evaluate(X_test[idx_shift], y_test[idx_shift],
                                            confidence=confidence)
    result_cp_no_shift = rf_cp.evaluate(X_test[idx_no_shift], y_test[idx_no_shift],
                                    confidence=confidence)
    result_cp_shift_not_weighted = rf_cp.evaluate(X_test[idx_shift], y_test[idx_shift],
                                              confidence=confidence)
    
    idx_cal_n_reduced = np.random.choice(range(n), size=int(n_reduced), replace=False)
    
    rf_cps_shift = copy.deepcopy(rf_cps)
    rf_cps_no_shift_reduced = copy.deepcopy(rf_cps)
    rf_cp_shift = copy.deepcopy(rf_cp)
    rf_cp_no_shift_reduced = copy.deepcopy(rf_cp)

    
    rf_cps_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=True)
    rf_cp_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=False)

    rf_cps_no_shift_reduced.calibrate(X_cal[idx_cal_n_reduced], y_cal[idx_cal_n_reduced], cps=True)    
    rf_cp_no_shift_reduced.calibrate(X_cal[idx_cal_n_reduced], y_cal[idx_cal_n_reduced], cps=False)
    
    result_cps_shift_weighted = rf_cps_shift.evaluate(X_test[idx_shift], y_test[idx_shift], 
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cp_shift_weighted = rf_cp_shift.evaluate(X_test[idx_shift], y_test[idx_shift], 
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cps_no_shift_reduced = rf_cps_no_shift_reduced.evaluate(X_test[idx_no_shift], y_test[idx_no_shift], 
                    confidence=confidence)
    result_cp_no_shift_reduced = rf_cp_no_shift_reduced.evaluate(X_test[idx_no_shift], y_test[idx_no_shift],
                    confidence=confidence)
    
    result_cps_shift_weighted["reduced_n"] = n_reduced
    result_cp_shift_weighted["reduced_n"] = n_reduced
    result_cps_no_shift_reduced["reduced_n"] = int(n_reduced)
    result_cp_no_shift_reduced["reduced_n"] = int(n_reduced)
    
    result_cps_no_shift["sim_id"] = i
    result_cps_shift_not_weighted["sim_id"] = i
    result_cps_shift_weighted["sim_id"] = i
    result_cp_no_shift["sim_id"] = i
    result_cp_shift_not_weighted["sim_id"] = i
    result_cp_shift_weighted["sim_id"] = i
    result_cps_no_shift_reduced["sim_id"] = i
    result_cp_no_shift_reduced["sim_id"] = i
    
    if i == 0:
        df_results_cps_no_shift_syn = pd.DataFrame(result_cps_no_shift, index=[0])
        df_results_cps_shift_not_weighted_syn = pd.DataFrame(result_cps_shift_not_weighted, index=[0])
        df_results_cps_shift_weighted_syn = pd.DataFrame(result_cps_shift_weighted, index=[0])
        df_results_cp_no_shift_syn = pd.DataFrame(result_cp_no_shift, index=[0])
        df_results_cp_shift_not_weighted_syn = pd.DataFrame(result_cp_shift_not_weighted, index=[0])
        df_results_cp_shift_weighted_syn = pd.DataFrame(result_cp_shift_weighted, index=[0])
        df_results_cps_no_shift_reduced_syn = pd.DataFrame(result_cps_no_shift_reduced, index=[0])
        df_results_cp_no_shift_reduced_syn = pd.DataFrame(result_cp_no_shift_reduced, index=[0])
    else:
        df_results_cps_no_shift_syn = pd.concat([df_results_cps_no_shift_syn, pd.DataFrame(result_cps_no_shift, index=[0])])
        df_results_cps_shift_not_weighted_syn = pd.concat([df_results_cps_shift_not_weighted_syn, pd.DataFrame(result_cps_shift_not_weighted, index=[0])])
        df_results_cps_shift_weighted_syn = pd.concat([df_results_cps_shift_weighted_syn, pd.DataFrame(result_cps_shift_weighted, index=[0])])
        df_results_cp_no_shift_syn = pd.concat([df_results_cp_no_shift_syn, pd.DataFrame(result_cp_no_shift, index=[0])])
        df_results_cp_shift_not_weighted_syn = pd.concat([df_results_cp_shift_not_weighted_syn, pd.DataFrame(result_cp_shift_not_weighted, index=[0])])
        df_results_cp_shift_weighted_syn = pd.concat([df_results_cp_shift_weighted_syn, pd.DataFrame(result_cp_shift_weighted, index=[0])])
        df_results_cps_no_shift_reduced_syn = pd.concat([df_results_cps_no_shift_reduced_syn, pd.DataFrame(result_cps_no_shift_reduced, index=[0])])
        df_results_cp_no_shift_reduced_syn = pd.concat([df_results_cp_no_shift_reduced_syn, pd.DataFrame(result_cp_no_shift_reduced, index=[0])])
# Out:
#   3%|▎         | 26/1000 [00:05<03:36,  4.49it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 20, Weight obs: [0.06222828], Smallest density: [0.11173058])
# (Perc: 9.999999999999998, Obs: 60, Weight obs: [0.06222828], Smallest density: [0.11173058])
# (Perc: 9.999999999999998, Obs: 79, Weight obs: [0.06222828], Smallest density: [0.11173058])
# (Perc: 9.999999999999998, Obs: 127, Weight obs: [0.06222828], Smallest density: [0.11173058])
# (Perc: 9.999999999999998, Obs: 196, Weight obs: [0.06222828], Smallest density: [0.11173058])
# (Perc: 9.999999999999998, Obs: 227, Weight obs: [0.06222828], Smallest density: [0.11173058]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 20, Weight obs: [0.06222828], Smallest density: [0.11173058])
# (Perc: 10.0, Obs: 60, Weight obs: [0.06222828], Smallest density: [0.11173058])
# (Perc: 10.0, Obs: 79, Weight obs: [0.06222828], Smallest density: [0.11173058])
# (Perc: 10.0, Obs: 127, Weight obs: [0.06222828], Smallest density: [0.11173058])
# (Perc: 10.0, Obs: 196, Weight obs: [0.06222828], Smallest density: [0.11173058])
# (Perc: 10.0, Obs: 227, Weight obs: [0.06222828], Smallest density: [0.11173058]); the corresponding values are set to y_min
#   warnings.warn(
#   4%|▍         | 41/1000 [00:08<03:19,  4.82it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 1, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 22, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 27, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 30, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 43, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 53, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 55, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 69, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 83, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 120, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 135, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 145, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 164, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 165, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 166, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 187, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 9.999999999999998, Obs: 188, Weight obs: [0.11864913], Smallest density: [0.11872943]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 1, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 22, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 27, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 30, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 43, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 53, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 55, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 69, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 83, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 120, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 135, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 145, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 164, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 165, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 166, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 187, Weight obs: [0.11864913], Smallest density: [0.11872943])
# (Perc: 10.0, Obs: 188, Weight obs: [0.11864913], Smallest density: [0.11872943]); the corresponding values are set to y_min
#   warnings.warn(
#   6%|▋         | 65/1000 [00:13<03:19,  4.70it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 20, Weight obs: [0.04072675], Smallest density: [0.10120358])
# (Perc: 9.999999999999998, Obs: 114, Weight obs: [0.04072675], Smallest density: [0.10120358])
# (Perc: 9.999999999999998, Obs: 141, Weight obs: [0.04072675], Smallest density: [0.10120358]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 20, Weight obs: [0.04072675], Smallest density: [0.10120358])
# (Perc: 10.0, Obs: 114, Weight obs: [0.04072675], Smallest density: [0.10120358])
# (Perc: 10.0, Obs: 141, Weight obs: [0.04072675], Smallest density: [0.10120358]); the corresponding values are set to y_min
#   warnings.warn(
#   7%|▋         | 67/1000 [00:14<03:16,  4.74it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 28, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 30, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 70, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 78, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 92, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 98, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 101, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 124, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 134, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 186, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 202, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 229, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 235, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 9.999999999999998, Obs: 237, Weight obs: [0.1080021], Smallest density: [0.11139212]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 28, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 30, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 70, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 78, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 92, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 98, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 101, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 124, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 134, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 186, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 202, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 229, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 235, Weight obs: [0.1080021], Smallest density: [0.11139212])
# (Perc: 10.0, Obs: 237, Weight obs: [0.1080021], Smallest density: [0.11139212]); the corresponding values are set to y_min
#   warnings.warn(
#   7%|▋         | 70/1000 [00:14<03:14,  4.79it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 10, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 9.999999999999998, Obs: 25, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 9.999999999999998, Obs: 39, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 9.999999999999998, Obs: 53, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 9.999999999999998, Obs: 59, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 9.999999999999998, Obs: 82, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 9.999999999999998, Obs: 116, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 9.999999999999998, Obs: 123, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 9.999999999999998, Obs: 137, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 9.999999999999998, Obs: 145, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 9.999999999999998, Obs: 155, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 9.999999999999998, Obs: 202, Weight obs: [0.07702936], Smallest density: [0.13849938]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 10, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 10.0, Obs: 25, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 10.0, Obs: 39, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 10.0, Obs: 53, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 10.0, Obs: 59, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 10.0, Obs: 82, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 10.0, Obs: 116, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 10.0, Obs: 123, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 10.0, Obs: 137, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 10.0, Obs: 145, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 10.0, Obs: 155, Weight obs: [0.07702936], Smallest density: [0.13849938])
# (Perc: 10.0, Obs: 202, Weight obs: [0.07702936], Smallest density: [0.13849938]); the corresponding values are set to y_min
#   warnings.warn(
#   8%|▊         | 83/1000 [00:17<03:17,  4.64it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 4, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 9.999999999999998, Obs: 34, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 9.999999999999998, Obs: 75, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 9.999999999999998, Obs: 90, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 9.999999999999998, Obs: 169, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 9.999999999999998, Obs: 225, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 9.999999999999998, Obs: 238, Weight obs: [0.07550764], Smallest density: [0.12442565]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 4, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 10.0, Obs: 34, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 10.0, Obs: 75, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 10.0, Obs: 90, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 10.0, Obs: 169, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 10.0, Obs: 225, Weight obs: [0.07550764], Smallest density: [0.12442565])
# (Perc: 10.0, Obs: 238, Weight obs: [0.07550764], Smallest density: [0.12442565]); the corresponding values are set to y_min
#   warnings.warn(
#   9%|▉         | 88/1000 [00:18<03:18,  4.60it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 30, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 39, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 88, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 90, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 101, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 129, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 134, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 142, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 148, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 157, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 176, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 229, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 9.999999999999998, Obs: 237, Weight obs: [0.10048291], Smallest density: [0.12369393]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 30, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 39, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 88, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 90, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 101, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 129, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 134, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 142, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 148, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 157, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 176, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 229, Weight obs: [0.10048291], Smallest density: [0.12369393])
# (Perc: 10.0, Obs: 237, Weight obs: [0.10048291], Smallest density: [0.12369393]); the corresponding values are set to y_min
#   warnings.warn(
#   9%|▉         | 89/1000 [00:18<03:15,  4.65it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 17, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 9.999999999999998, Obs: 49, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 9.999999999999998, Obs: 50, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 9.999999999999998, Obs: 70, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 9.999999999999998, Obs: 172, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 9.999999999999998, Obs: 177, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 9.999999999999998, Obs: 184, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 9.999999999999998, Obs: 202, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 9.999999999999998, Obs: 247, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 9.999999999999998, Obs: 248, Weight obs: [0.07623792], Smallest density: [0.11491632]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 17, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 10.0, Obs: 49, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 10.0, Obs: 50, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 10.0, Obs: 70, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 10.0, Obs: 172, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 10.0, Obs: 177, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 10.0, Obs: 184, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 10.0, Obs: 202, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 10.0, Obs: 247, Weight obs: [0.07623792], Smallest density: [0.11491632])
# (Perc: 10.0, Obs: 248, Weight obs: [0.07623792], Smallest density: [0.11491632]); the corresponding values are set to y_min
#   warnings.warn(
#   9%|▉         | 92/1000 [00:19<03:37,  4.18it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 0, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 9.999999999999998, Obs: 48, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 9.999999999999998, Obs: 51, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 9.999999999999998, Obs: 76, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 9.999999999999998, Obs: 77, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 9.999999999999998, Obs: 81, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 9.999999999999998, Obs: 84, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 9.999999999999998, Obs: 109, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 9.999999999999998, Obs: 158, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 9.999999999999998, Obs: 181, Weight obs: [0.10541705], Smallest density: [0.10559756]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 0, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 10.0, Obs: 48, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 10.0, Obs: 51, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 10.0, Obs: 76, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 10.0, Obs: 77, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 10.0, Obs: 81, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 10.0, Obs: 84, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 10.0, Obs: 109, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 10.0, Obs: 158, Weight obs: [0.10541705], Smallest density: [0.10559756])
# (Perc: 10.0, Obs: 181, Weight obs: [0.10541705], Smallest density: [0.10559756]); the corresponding values are set to y_min
#   warnings.warn(
#  10%|█         | 100/1000 [00:21<03:17,  4.55it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 0, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 6, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 7, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 19, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 20, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 75, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 96, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 122, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 132, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 133, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 164, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 170, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 171, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 188, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 189, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 195, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 210, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 9.999999999999998, Obs: 235, Weight obs: [0.11009199], Smallest density: [0.1341773]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 0, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 6, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 7, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 19, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 20, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 75, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 96, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 122, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 132, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 133, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 164, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 170, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 171, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 188, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 189, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 195, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 210, Weight obs: [0.11009199], Smallest density: [0.1341773])
# (Perc: 10.0, Obs: 235, Weight obs: [0.11009199], Smallest density: [0.1341773]); the corresponding values are set to y_min
#   warnings.warn(
#  10%|█         | 101/1000 [00:21<03:15,  4.59it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 6, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 14, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 30, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 45, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 49, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 65, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 92, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 94, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 104, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 114, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 118, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 124, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 126, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 135, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 139, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 162, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 189, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 203, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 207, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 220, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 9.999999999999998, Obs: 242, Weight obs: [0.17501902], Smallest density: [0.17570848]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 6, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 14, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 30, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 45, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 49, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 65, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 92, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 94, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 104, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 114, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 118, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 124, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 126, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 135, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 139, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 162, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 189, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 203, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 207, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 220, Weight obs: [0.17501902], Smallest density: [0.17570848])
# (Perc: 10.0, Obs: 242, Weight obs: [0.17501902], Smallest density: [0.17570848]); the corresponding values are set to y_min
#   warnings.warn(
#  11%|█▏        | 113/1000 [00:24<03:02,  4.85it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 0, Weight obs: [0.00263309], Smallest density: [0.16707631])
# (Perc: 9.999999999999998, Obs: 1, Weight obs: [0.00123614], Smallest density: [0.16590969])
# (Perc: 9.999999999999998, Obs: 2, Weight obs: [0.00307615], Smallest density: [0.16744632])
# (Perc: 9.999999999999998, Obs: 3, Weight obs: [0.0008733], Smallest density: [0.16560667])
# (Perc: 9.999999999999998, Obs: 4, Weight obs: [0.00455858], Smallest density: [0.16868433])
# (Perc: 9.999999999999998, Obs: 5, Weight obs: [0.00025213], Smallest density: [0.16508791])
# (Perc: 9.999999999999998, Obs: 6, Weight obs: [0.00436125], Smallest density: [0.16851954])
# (Perc: 9.999999999999998, Obs: 7, Weight obs: [0.00101376], Smallest density: [0.16572397])
# (Perc: 9.999999999999998, Obs: 8, Weight obs: [0.01145872], Smallest density: [0.1744468])
# (Perc: 9.999999999999998, Obs: 9, Weight obs: [0.01659399], Smallest density: [0.17873537])
# (Perc: 9.999999999999998, Obs: 10, Weight obs: [0.00280774], Smallest density: [0.16722217])
# (Perc: 9.999999999999998, Obs: 11, Weight obs: [0.00387613], Smallest density: [0.1681144])
# (Perc: 9.999999999999998, Obs: 12, Weight obs: [0.01808685], Smallest density: [0.1799821])
# (Perc: 9.999999999999998, Obs: 13, Weight obs: [0.02613399], Smallest density: [0.18670245])
# (Perc: 9.999999999999998, Obs: 14, Weight obs: [0.0030921], Smallest density: [0.16745964])
# (Perc: 9.999999999999998, Obs: 15, Weight obs: [0.02613399], Smallest density: [0.18670245])
# (Perc: 9.999999999999998, Obs: 16, Weight obs: [0.00217177], Smallest density: [0.16669105])
# (Perc: 9.999999999999998, Obs: 17, Weight obs: [0.00074403], Smallest density: [0.16549871])
# (Perc: 9.999999999999998, Obs: 18, Weight obs: [0.00086226], Smallest density: [0.16559745])
# (Perc: 9.999999999999998, Obs: 19, Weight obs: [0.0013374], Smallest density: [0.16599425])
# (Perc: 9.999999999999998, Obs: 20, Weight obs: [0.0045461], Smallest density: [0.16867391])
# (Perc: 9.999999999999998, Obs: 21, Weight obs: [0.00347115], Smallest density: [0.16777619])
# (Perc: 9.999999999999998, Obs: 22, Weight obs: [0.02208832], Smallest density: [0.18332382])
# (Perc: 9.999999999999998, Obs: 23, Weight obs: [0.00128212], Smallest density: [0.16594809])
# (Perc: 9.999999999999998, Obs: 24, Weight obs: [0.00137124], Smallest density: [0.16602251])
# (Perc: 9.999999999999998, Obs: 25, Weight obs: [0.00065817], Smallest density: [0.16542701])
# (Perc: 9.999999999999998, Obs: 26, Weight obs: [0.00953597], Smallest density: [0.17284106])
# (Perc: 9.999999999999998, Obs: 27, Weight obs: [0.00953597], Smallest density: [0.17284106])
# (Perc: 9.999999999999998, Obs: 28, Weight obs: [0.00396062], Smallest density: [0.16818496])
# (Perc: 9.999999999999998, Obs: 29, Weight obs: [0.00071999], Smallest density: [0.16547864])
# (Perc: 9.999999999999998, Obs: 30, Weight obs: [0.0029105], Smallest density: [0.16730798])
# (Perc: 9.999999999999998, Obs: 31, Weight obs: [0.00387613], Smallest density: [0.1681144])
# (Perc: 9.999999999999998, Obs: 32, Weight obs: [0.00025307], Smallest density: [0.1650887])
# (Perc: 9.999999999999998, Obs: 33, Weight obs: [0.00490601], Smallest density: [0.16897448])
# (Perc: 9.999999999999998, Obs: 34, Weight obs: [0.00415856], Smallest density: [0.16835026])
# (Perc: 9.999999999999998, Obs: 35, Weight obs: [0.00252366], Smallest density: [0.16698492])
# (Perc: 9.999999999999998, Obs: 36, Weight obs: [0.00143478], Smallest density: [0.16607557])
# (Perc: 9.999999999999998, Obs: 37, Weight obs: [0.00193207], Smallest density: [0.16649087])
# (Perc: 9.999999999999998, Obs: 38, Weight obs: [0.00257259], Smallest density: [0.16702578])
# (Perc: 9.999999999999998, Obs: 39, Weight obs: [0.01798964], Smallest density: [0.17990091])
# (Perc: 9.999999999999998, Obs: 40, Weight obs: [0.00219085], Smallest density: [0.16670699])
# (Perc: 9.999999999999998, Obs: 41, Weight obs: [0.00065775], Smallest density: [0.16542666])
# (Perc: 9.999999999999998, Obs: 42, Weight obs: [0.01505249], Smallest density: [0.17744803])
# (Perc: 9.999999999999998, Obs: 43, Weight obs: [0.01284454], Smallest density: [0.17560412])
# (Perc: 9.999999999999998, Obs: 44, Weight obs: [0.00932873], Smallest density: [0.17266799])
# (Perc: 9.999999999999998, Obs: 45, Weight obs: [0.00527627], Smallest density: [0.16928369])
# (Perc: 9.999999999999998, Obs: 46, Weight obs: [0.02208832], Smallest density: [0.18332382])
# (Perc: 9.999999999999998, Obs: 47, Weight obs: [0.00315007], Smallest density: [0.16750805])
# (Perc: 9.999999999999998, Obs: 48, Weight obs: [0.01505249], Smallest density: [0.17744803])
# (Perc: 9.999999999999998, Obs: 49, Weight obs: [0.00669532], Smallest density: [0.17046877])
# (Perc: 9.999999999999998, Obs: 50, Weight obs: [0.01808685], Smallest density: [0.1799821])
# (Perc: 9.999999999999998, Obs: 51, Weight obs: [0.0007462], Smallest density: [0.16550053])
# (Perc: 9.999999999999998, Obs: 52, Weight obs: [0.00699996], Smallest density: [0.17072318])
# (Perc: 9.999999999999998, Obs: 53, Weight obs: [0.01659399], Smallest density: [0.17873537])
# (Perc: 9.999999999999998, Obs: 54, Weight obs: [0.00367926], Smallest density: [0.16794999])
# (Perc: 9.999999999999998, Obs: 55, Weight obs: [0.00127227], Smallest density: [0.16593986])
# (Perc: 9.999999999999998, Obs: 56, Weight obs: [0.00297928], Smallest density: [0.16736542])
# (Perc: 9.999999999999998, Obs: 57, Weight obs: [0.00483955], Smallest density: [0.16891897])
# (Perc: 9.999999999999998, Obs: 58, Weight obs: [0.00113029], Smallest density: [0.16582129])
# (Perc: 9.999999999999998, Obs: 59, Weight obs: [0.00073928], Smallest density: [0.16549475])
# (Perc: 9.999999999999998, Obs: 60, Weight obs: [0.00043179], Smallest density: [0.16523795])
# (Perc: 9.999999999999998, Obs: 61, Weight obs: [0.00848214], Smallest density: [0.17196099])
# (Perc: 9.999999999999998, Obs: 62, Weight obs: [0.00863383], Smallest density: [0.17208767])
# (Perc: 9.999999999999998, Obs: 63, Weight obs: [0.00283442], Smallest density: [0.16724444])
# (Perc: 9.999999999999998, Obs: 64, Weight obs: [0.00501542], Smallest density: [0.16906584])
# (Perc: 9.999999999999998, Obs: 65, Weight obs: [0.00428814], Smallest density: [0.16845848])
# (Perc: 9.999999999999998, Obs: 66, Weight obs: [0.00436125], Smallest density: [0.16851954])
# (Perc: 9.999999999999998, Obs: 67, Weight obs: [0.00022979], Smallest density: [0.16506926])
# (Perc: 9.999999999999998, Obs: 68, Weight obs: [0.00478675], Smallest density: [0.16887488])
# (Perc: 9.999999999999998, Obs: 69, Weight obs: [0.00257741], Smallest density: [0.16702981])
# (Perc: 9.999999999999998, Obs: 70, Weight obs: [0.00046883], Smallest density: [0.16526889])
# (Perc: 9.999999999999998, Obs: 71, Weight obs: [0.0056615], Smallest density: [0.16960541])
# (Perc: 9.999999999999998, Obs: 72, Weight obs: [0.00089274], Smallest density: [0.1656229])
# (Perc: 9.999999999999998, Obs: 73, Weight obs: [0.00163451], Smallest density: [0.16624237])
# (Perc: 9.999999999999998, Obs: 74, Weight obs: [0.00815486], Smallest density: [0.17168767])
# (Perc: 9.999999999999998, Obs: 75, Weight obs: [0.0016812], Smallest density: [0.16628137])
# (Perc: 9.999999999999998, Obs: 76, Weight obs: [0.00513667], Smallest density: [0.16916711])
# (Perc: 9.999999999999998, Obs: 77, Weight obs: [0.00180266], Smallest density: [0.1663828])
# (Perc: 9.999999999999998, Obs: 78, Weight obs: [0.00863383], Smallest density: [0.17208767])
# (Perc: 9.999999999999998, Obs: 79, Weight obs: [0.00251601], Smallest density: [0.16697853])
# (Perc: 9.999999999999998, Obs: 80, Weight obs: [0.00323097], Smallest density: [0.16757561])
# (Perc: 9.999999999999998, Obs: 81, Weight obs: [0.0005873], Smallest density: [0.16536782])
# (Perc: 9.999999999999998, Obs: 82, Weight obs: [0.00249531], Smallest density: [0.16696125])
# (Perc: 9.999999999999998, Obs: 83, Weight obs: [0.01145872], Smallest density: [0.1744468])
# (Perc: 9.999999999999998, Obs: 84, Weight obs: [0.00455675], Smallest density: [0.1686828])
# (Perc: 9.999999999999998, Obs: 85, Weight obs: [0.00545065], Smallest density: [0.16942932])
# (Perc: 9.999999999999998, Obs: 86, Weight obs: [0.00197338], Smallest density: [0.16652537])
# (Perc: 9.999999999999998, Obs: 87, Weight obs: [0.01194274], Smallest density: [0.17485101])
# (Perc: 9.999999999999998, Obs: 88, Weight obs: [0.00297159], Smallest density: [0.167359])
# (Perc: 9.999999999999998, Obs: 89, Weight obs: [0.00462286], Smallest density: [0.16873801])
# (Perc: 9.999999999999998, Obs: 90, Weight obs: [0.00138018], Smallest density: [0.16602998])
# (Perc: 9.999999999999998, Obs: 91, Weight obs: [0.00629404], Smallest density: [0.17013365])
# (Perc: 9.999999999999998, Obs: 92, Weight obs: [0.00519547], Smallest density: [0.16921621])
# (Perc: 9.999999999999998, Obs: 93, Weight obs: [0.00415856], Smallest density: [0.16835026])
# (Perc: 9.999999999999998, Obs: 94, Weight obs: [0.0267314], Smallest density: [0.18720136])
# (Perc: 9.999999999999998, Obs: 95, Weight obs: [0.00050149], Smallest density: [0.16529617])
# (Perc: 9.999999999999998, Obs: 96, Weight obs: [0.00711023], Smallest density: [0.17081527])
# (Perc: 9.999999999999998, Obs: 97, Weight obs: [0.01505249], Smallest density: [0.17744803])
# (Perc: 9.999999999999998, Obs: 98, Weight obs: [0.0001949], Smallest density: [0.16504012])
# (Perc: 9.999999999999998, Obs: 99, Weight obs: [0.00343458], Smallest density: [0.16774565])
# (Perc: 9.999999999999998, Obs: 100, Weight obs: [0.00187559], Smallest density: [0.1664437])
# (Perc: 9.999999999999998, Obs: 101, Weight obs: [0.00089516], Smallest density: [0.16562493])
# (Perc: 9.999999999999998, Obs: 102, Weight obs: [0.0003094], Smallest density: [0.16513575])
# (Perc: 9.999999999999998, Obs: 103, Weight obs: [0.00490601], Smallest density: [0.16897448])
# (Perc: 9.999999999999998, Obs: 104, Weight obs: [0.00421148], Smallest density: [0.16839446])
# (Perc: 9.999999999999998, Obs: 105, Weight obs: [0.00994069], Smallest density: [0.17317905])
# (Perc: 9.999999999999998, Obs: 106, Weight obs: [0.00679576], Smallest density: [0.17055265])
# (Perc: 9.999999999999998, Obs: 107, Weight obs: [0.02613399], Smallest density: [0.18670245])
# (Perc: 9.999999999999998, Obs: 108, Weight obs: [0.02613399], Smallest density: [0.18670245])
# (Perc: 9.999999999999998, Obs: 109, Weight obs: [0.00519547], Smallest density: [0.16921621])
# (Perc: 9.999999999999998, Obs: 110, Weight obs: [0.0043238], Smallest density: [0.16848826])
# (Perc: 9.999999999999998, Obs: 111, Weight obs: [0.0045461], Smallest density: [0.16867391])
# (Perc: 9.999999999999998, Obs: 112, Weight obs: [0.00269543], Smallest density: [0.16712837])
# (Perc: 9.999999999999998, Obs: 113, Weight obs: [0.00345631], Smallest density: [0.1677638])
# (Perc: 9.999999999999998, Obs: 114, Weight obs: [0.00193207], Smallest density: [0.16649087])
# (Perc: 9.999999999999998, Obs: 115, Weight obs: [0.00240863], Smallest density: [0.16688886])
# (Perc: 9.999999999999998, Obs: 116, Weight obs: [0.000504], Smallest density: [0.16529826])
# (Perc: 9.999999999999998, Obs: 117, Weight obs: [0.00250039], Smallest density: [0.16696549])
# (Perc: 9.999999999999998, Obs: 118, Weight obs: [0.01798964], Smallest density: [0.17990091])
# (Perc: 9.999999999999998, Obs: 119, Weight obs: [0.00079158], Smallest density: [0.16553843])
# (Perc: 9.999999999999998, Obs: 120, Weight obs: [0.00101474], Smallest density: [0.16572479])
# (Perc: 9.999999999999998, Obs: 121, Weight obs: [0.00116636], Smallest density: [0.16585141])
# (Perc: 9.999999999999998, Obs: 122, Weight obs: [0.00257259], Smallest density: [0.16702578])
# (Perc: 9.999999999999998, Obs: 123, Weight obs: [0.01145872], Smallest density: [0.1744468])
# (Perc: 9.999999999999998, Obs: 124, Weight obs: [0.00147767], Smallest density: [0.16611139])
# (Perc: 9.999999999999998, Obs: 125, Weight obs: [0.00064987], Smallest density: [0.16542008])
# (Perc: 9.999999999999998, Obs: 126, Weight obs: [0.00432848], Smallest density: [0.16849217])
# (Perc: 9.999999999999998, Obs: 127, Weight obs: [0.00800711], Smallest density: [0.17156428])
# (Perc: 9.999999999999998, Obs: 128, Weight obs: [0.00184006], Smallest density: [0.16641403])
# (Perc: 9.999999999999998, Obs: 129, Weight obs: [0.00158596], Smallest density: [0.16620183])
# (Perc: 9.999999999999998, Obs: 130, Weight obs: [0.00252366], Smallest density: [0.16698492])
# (Perc: 9.999999999999998, Obs: 131, Weight obs: [0.00351579], Smallest density: [0.16781347])
# (Perc: 9.999999999999998, Obs: 132, Weight obs: [0.00328411], Smallest density: [0.16762])
# (Perc: 9.999999999999998, Obs: 133, Weight obs: [0.01284454], Smallest density: [0.17560412])
# (Perc: 9.999999999999998, Obs: 134, Weight obs: [0.01505249], Smallest density: [0.17744803])
# (Perc: 9.999999999999998, Obs: 135, Weight obs: [0.00011871], Smallest density: [0.16497649])
# (Perc: 9.999999999999998, Obs: 136, Weight obs: [0.00550664], Smallest density: [0.16947608])
# (Perc: 9.999999999999998, Obs: 137, Weight obs: [0.00093956], Smallest density: [0.16566201])
# (Perc: 9.999999999999998, Obs: 138, Weight obs: [0.00221667], Smallest density: [0.16672855])
# (Perc: 9.999999999999998, Obs: 139, Weight obs: [0.0053441], Smallest density: [0.16934034])
# (Perc: 9.999999999999998, Obs: 140, Weight obs: [0.02208832], Smallest density: [0.18332382])
# (Perc: 9.999999999999998, Obs: 141, Weight obs: [0.01659399], Smallest density: [0.17873537])
# (Perc: 9.999999999999998, Obs: 142, Weight obs: [0.00017355], Smallest density: [0.16502229])
# (Perc: 9.999999999999998, Obs: 143, Weight obs: [0.0267314], Smallest density: [0.18720136])
# (Perc: 9.999999999999998, Obs: 144, Weight obs: [0.00700384], Smallest density: [0.17072642])
# (Perc: 9.999999999999998, Obs: 145, Weight obs: [0.00953597], Smallest density: [0.17284106])
# (Perc: 9.999999999999998, Obs: 146, Weight obs: [0.00149884], Smallest density: [0.16612907])
# (Perc: 9.999999999999998, Obs: 147, Weight obs: [0.00095393], Smallest density: [0.16567401])
# (Perc: 9.999999999999998, Obs: 148, Weight obs: [0.00513667], Smallest density: [0.16916711])
# (Perc: 9.999999999999998, Obs: 149, Weight obs: [0.00994069], Smallest density: [0.17317905])
# (Perc: 9.999999999999998, Obs: 150, Weight obs: [0.00204641], Smallest density: [0.16658636])
# (Perc: 9.999999999999998, Obs: 151, Weight obs: [0.00485604], Smallest density: [0.16893275])
# (Perc: 9.999999999999998, Obs: 152, Weight obs: [0.00542446], Smallest density: [0.16940745])
# (Perc: 9.999999999999998, Obs: 153, Weight obs: [0.00463077], Smallest density: [0.16874462])
# (Perc: 9.999999999999998, Obs: 154, Weight obs: [0.00587281], Smallest density: [0.16978187])
# (Perc: 9.999999999999998, Obs: 155, Weight obs: [0.0043238], Smallest density: [0.16848826])
# (Perc: 9.999999999999998, Obs: 156, Weight obs: [0.00455675], Smallest density: [0.1686828])
# (Perc: 9.999999999999998, Obs: 157, Weight obs: [0.00022979], Smallest density: [0.16506926])
# (Perc: 9.999999999999998, Obs: 158, Weight obs: [0.00276881], Smallest density: [0.16718966])
# (Perc: 9.999999999999998, Obs: 159, Weight obs: [0.00059218], Smallest density: [0.1653719])
# (Perc: 9.999999999999998, Obs: 160, Weight obs: [0.00725064], Smallest density: [0.17093253])
# (Perc: 9.999999999999998, Obs: 161, Weight obs: [0.00354081], Smallest density: [0.16783437])
# (Perc: 9.999999999999998, Obs: 162, Weight obs: [0.00384224], Smallest density: [0.1680861])
# (Perc: 9.999999999999998, Obs: 163, Weight obs: [0.0267314], Smallest density: [0.18720136])
# (Perc: 9.999999999999998, Obs: 164, Weight obs: [0.00278889], Smallest density: [0.16720642])
# (Perc: 9.999999999999998, Obs: 165, Weight obs: [0.00034005], Smallest density: [0.16516134])
# (Perc: 9.999999999999998, Obs: 166, Weight obs: [0.00100338], Smallest density: [0.1657153])
# (Perc: 9.999999999999998, Obs: 167, Weight obs: [0.00167856], Smallest density: [0.16627916])
# (Perc: 9.999999999999998, Obs: 168, Weight obs: [0.00062084], Smallest density: [0.16539583])
# (Perc: 9.999999999999998, Obs: 169, Weight obs: [0.00461447], Smallest density: [0.16873101])
# (Perc: 9.999999999999998, Obs: 170, Weight obs: [0.00146626], Smallest density: [0.16610186])
# (Perc: 9.999999999999998, Obs: 171, Weight obs: [0.00174619], Smallest density: [0.16633564])
# (Perc: 9.999999999999998, Obs: 172, Weight obs: [0.00863383], Smallest density: [0.17208767])
# (Perc: 9.999999999999998, Obs: 173, Weight obs: [0.00232065], Smallest density: [0.16681538])
# (Perc: 9.999999999999998, Obs: 174, Weight obs: [0.00169505], Smallest density: [0.16629293])
# (Perc: 9.999999999999998, Obs: 175, Weight obs: [0.00380444], Smallest density: [0.16805453])
# (Perc: 9.999999999999998, Obs: 176, Weight obs: [0.00345631], Smallest density: [0.1677638])
# (Perc: 9.999999999999998, Obs: 177, Weight obs: [0.00455858], Smallest density: [0.16868433])
# (Perc: 9.999999999999998, Obs: 178, Weight obs: [0.00083048], Smallest density: [0.16557091])
# (Perc: 9.999999999999998, Obs: 179, Weight obs: [0.00679576], Smallest density: [0.17055265])
# (Perc: 9.999999999999998, Obs: 180, Weight obs: [0.00165177], Smallest density: [0.16625679])
# (Perc: 9.999999999999998, Obs: 181, Weight obs: [0.00463154], Smallest density: [0.16874526])
# (Perc: 9.999999999999998, Obs: 182, Weight obs: [0.0013567], Smallest density: [0.16601037])
# (Perc: 9.999999999999998, Obs: 183, Weight obs: [0.00105621], Smallest density: [0.16575942])
# (Perc: 9.999999999999998, Obs: 184, Weight obs: [0.00503044], Smallest density: [0.16907839])
# (Perc: 9.999999999999998, Obs: 185, Weight obs: [0.0005483], Smallest density: [0.16533526])
# (Perc: 9.999999999999998, Obs: 186, Weight obs: [0.00325234], Smallest density: [0.16759346])
# (Perc: 9.999999999999998, Obs: 187, Weight obs: [0.00583089], Smallest density: [0.16974687])
# (Perc: 9.999999999999998, Obs: 188, Weight obs: [0.00197338], Smallest density: [0.16652537])
# (Perc: 9.999999999999998, Obs: 189, Weight obs: [0.00383749], Smallest density: [0.16808213])
# (Perc: 9.999999999999998, Obs: 190, Weight obs: [0.00325234], Smallest density: [0.16759346])
# (Perc: 9.999999999999998, Obs: 191, Weight obs: [0.00149884], Smallest density: [0.16612907])
# (Perc: 9.999999999999998, Obs: 192, Weight obs: [0.00122737], Smallest density: [0.16590236])
# (Perc: 9.999999999999998, Obs: 193, Weight obs: [0.00567551], Smallest density: [0.16961711])
# (Perc: 9.999999999999998, Obs: 194, Weight obs: [0.0006925], Smallest density: [0.16545568])
# (Perc: 9.999999999999998, Obs: 195, Weight obs: [0.00217452], Smallest density: [0.16669335])
# (Perc: 9.999999999999998, Obs: 196, Weight obs: [0.00034005], Smallest density: [0.16516134])
# (Perc: 9.999999999999998, Obs: 197, Weight obs: [0.00041128], Smallest density: [0.16522082])
# (Perc: 9.999999999999998, Obs: 198, Weight obs: [0.00445075], Smallest density: [0.16859428])
# (Perc: 9.999999999999998, Obs: 199, Weight obs: [0.00166744], Smallest density: [0.16626988])
# (Perc: 9.999999999999998, Obs: 200, Weight obs: [0.00154324], Smallest density: [0.16616615])
# (Perc: 9.999999999999998, Obs: 201, Weight obs: [0.01561108], Smallest density: [0.17791453])
# ...
# (Perc: 10.0, Obs: 198, Weight obs: [0.0243411], Smallest density: [0.14399769])
# (Perc: 10.0, Obs: 199, Weight obs: [0.00098811], Smallest density: [0.12350875])
# (Perc: 10.0, Obs: 200, Weight obs: [0.0243411], Smallest density: [0.14399769])
# (Perc: 10.0, Obs: 201, Weight obs: [0.00124304], Smallest density: [0.12373241])
# (Perc: 10.0, Obs: 202, Weight obs: [0.00203661], Smallest density: [0.12442866])
# (Perc: 10.0, Obs: 203, Weight obs: [0.00745776], Smallest density: [0.12918495])
# (Perc: 10.0, Obs: 204, Weight obs: [0.01549729], Smallest density: [0.1362385])
# (Perc: 10.0, Obs: 205, Weight obs: [0.00116227], Smallest density: [0.12366155])
# (Perc: 10.0, Obs: 206, Weight obs: [0.00523763], Smallest density: [0.1272371])
# (Perc: 10.0, Obs: 207, Weight obs: [0.00148613], Smallest density: [0.12394569])
# (Perc: 10.0, Obs: 208, Weight obs: [0.00597677], Smallest density: [0.12788559])
# (Perc: 10.0, Obs: 209, Weight obs: [0.00110459], Smallest density: [0.12361095])
# (Perc: 10.0, Obs: 210, Weight obs: [0.00356089], Smallest density: [0.125766])
# (Perc: 10.0, Obs: 211, Weight obs: [0.00369806], Smallest density: [0.12588635])
# (Perc: 10.0, Obs: 212, Weight obs: [0.00101567], Smallest density: [0.12353293])
# (Perc: 10.0, Obs: 213, Weight obs: [0.00112283], Smallest density: [0.12362695])
# (Perc: 10.0, Obs: 214, Weight obs: [0.00782819], Smallest density: [0.12950995])
# (Perc: 10.0, Obs: 215, Weight obs: [0.00221859], Smallest density: [0.12458832])
# (Perc: 10.0, Obs: 216, Weight obs: [0.00041634], Smallest density: [0.1230071])
# (Perc: 10.0, Obs: 217, Weight obs: [0.00232625], Smallest density: [0.12468278])
# (Perc: 10.0, Obs: 218, Weight obs: [0.00506483], Smallest density: [0.12708549])
# (Perc: 10.0, Obs: 219, Weight obs: [0.00200759], Smallest density: [0.12440319])
# (Perc: 10.0, Obs: 220, Weight obs: [0.00275729], Smallest density: [0.12506095])
# (Perc: 10.0, Obs: 221, Weight obs: [0.01910731], Smallest density: [0.13940577])
# (Perc: 10.0, Obs: 222, Weight obs: [0.01307827], Smallest density: [0.13411615])
# (Perc: 10.0, Obs: 223, Weight obs: [0.00220704], Smallest density: [0.12457819])
# (Perc: 10.0, Obs: 224, Weight obs: [0.00110475], Smallest density: [0.12361108])
# (Perc: 10.0, Obs: 225, Weight obs: [0.00349182], Smallest density: [0.1257054])
# (Perc: 10.0, Obs: 226, Weight obs: [0.00683103], Smallest density: [0.12863508])
# (Perc: 10.0, Obs: 227, Weight obs: [0.00275956], Smallest density: [0.12506295])
# (Perc: 10.0, Obs: 228, Weight obs: [0.00342439], Smallest density: [0.12564624])
# (Perc: 10.0, Obs: 229, Weight obs: [0.00048478], Smallest density: [0.12306715])
# (Perc: 10.0, Obs: 230, Weight obs: [0.00300105], Smallest density: [0.12527482])
# (Perc: 10.0, Obs: 231, Weight obs: [0.00337477], Smallest density: [0.1256027])
# (Perc: 10.0, Obs: 232, Weight obs: [0.00304179], Smallest density: [0.12531056])
# (Perc: 10.0, Obs: 233, Weight obs: [0.00238929], Smallest density: [0.12473809])
# (Perc: 10.0, Obs: 234, Weight obs: [0.00517869], Smallest density: [0.12718538])
# (Perc: 10.0, Obs: 235, Weight obs: [0.00342439], Smallest density: [0.12564624])
# (Perc: 10.0, Obs: 236, Weight obs: [0.01045586], Smallest density: [0.13181536])
# (Perc: 10.0, Obs: 237, Weight obs: [0.0243411], Smallest density: [0.14399769])
# (Perc: 10.0, Obs: 238, Weight obs: [0.00197655], Smallest density: [0.12437596])
# (Perc: 10.0, Obs: 239, Weight obs: [0.00641925], Smallest density: [0.12827381])
# (Perc: 10.0, Obs: 240, Weight obs: [0.01133685], Smallest density: [0.1325883])
# (Perc: 10.0, Obs: 241, Weight obs: [0.00118607], Smallest density: [0.12368243])
# (Perc: 10.0, Obs: 242, Weight obs: [0.00134893], Smallest density: [0.12382532])
# (Perc: 10.0, Obs: 243, Weight obs: [0.00181291], Smallest density: [0.12423239])
# (Perc: 10.0, Obs: 244, Weight obs: [0.00830318], Smallest density: [0.12992669])
# (Perc: 10.0, Obs: 245, Weight obs: [0.00722054], Smallest density: [0.12897682])
# (Perc: 10.0, Obs: 246, Weight obs: [0.00217022], Smallest density: [0.12454588])
# (Perc: 10.0, Obs: 247, Weight obs: [0.0243411], Smallest density: [0.14399769])
# (Perc: 10.0, Obs: 248, Weight obs: [0.00233785], Smallest density: [0.12469296])
# (Perc: 10.0, Obs: 249, Weight obs: [0.00053707], Smallest density: [0.12311303]); the corresponding values are set to y_min
#   warnings.warn(
#  92%|█████████▏| 915/1000 [03:17<00:19,  4.31it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 26, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 9.999999999999998, Obs: 57, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 9.999999999999998, Obs: 62, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 9.999999999999998, Obs: 120, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 9.999999999999998, Obs: 160, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 9.999999999999998, Obs: 164, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 9.999999999999998, Obs: 177, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 9.999999999999998, Obs: 178, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 9.999999999999998, Obs: 245, Weight obs: [0.05670997], Smallest density: [0.11050754]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 26, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 10.0, Obs: 57, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 10.0, Obs: 62, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 10.0, Obs: 120, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 10.0, Obs: 160, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 10.0, Obs: 164, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 10.0, Obs: 177, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 10.0, Obs: 178, Weight obs: [0.05670997], Smallest density: [0.11050754])
# (Perc: 10.0, Obs: 245, Weight obs: [0.05670997], Smallest density: [0.11050754]); the corresponding values are set to y_min
#   warnings.warn(
#  94%|█████████▍| 938/1000 [03:23<00:13,  4.61it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 6, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 9.999999999999998, Obs: 21, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 9.999999999999998, Obs: 40, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 9.999999999999998, Obs: 64, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 9.999999999999998, Obs: 66, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 9.999999999999998, Obs: 74, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 9.999999999999998, Obs: 93, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 9.999999999999998, Obs: 98, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 9.999999999999998, Obs: 132, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 9.999999999999998, Obs: 136, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 9.999999999999998, Obs: 143, Weight obs: [0.11766449], Smallest density: [0.11804491]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 6, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 10.0, Obs: 21, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 10.0, Obs: 40, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 10.0, Obs: 64, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 10.0, Obs: 66, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 10.0, Obs: 74, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 10.0, Obs: 93, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 10.0, Obs: 98, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 10.0, Obs: 132, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 10.0, Obs: 136, Weight obs: [0.11766449], Smallest density: [0.11804491])
# (Perc: 10.0, Obs: 143, Weight obs: [0.11766449], Smallest density: [0.11804491]); the corresponding values are set to y_min
#   warnings.warn(
#  98%|█████████▊| 978/1000 [03:31<00:04,  4.82it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 5, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 7, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 101, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 107, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 118, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 128, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 130, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 133, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 144, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 165, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 175, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 186, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 191, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 195, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 229, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 232, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 241, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 9.999999999999998, Obs: 243, Weight obs: [0.10542023], Smallest density: [0.10971792]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 5, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 7, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 101, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 107, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 118, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 128, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 130, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 133, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 144, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 165, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 175, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 186, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 191, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 195, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 229, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 232, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 241, Weight obs: [0.10542023], Smallest density: [0.10971792])
# (Perc: 10.0, Obs: 243, Weight obs: [0.10542023], Smallest density: [0.10971792]); the corresponding values are set to y_min
#   warnings.warn(
#  98%|█████████▊| 979/1000 [03:32<00:04,  4.66it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 7, Weight obs: [0.08189101], Smallest density: [0.109475])
# (Perc: 9.999999999999998, Obs: 21, Weight obs: [0.08189101], Smallest density: [0.109475])
# (Perc: 9.999999999999998, Obs: 107, Weight obs: [0.08189101], Smallest density: [0.109475])
# (Perc: 9.999999999999998, Obs: 181, Weight obs: [0.08189101], Smallest density: [0.109475])
# (Perc: 9.999999999999998, Obs: 248, Weight obs: [0.08189101], Smallest density: [0.109475]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 7, Weight obs: [0.08189101], Smallest density: [0.109475])
# (Perc: 10.0, Obs: 21, Weight obs: [0.08189101], Smallest density: [0.109475])
# (Perc: 10.0, Obs: 107, Weight obs: [0.08189101], Smallest density: [0.109475])
# (Perc: 10.0, Obs: 181, Weight obs: [0.08189101], Smallest density: [0.109475])
# (Perc: 10.0, Obs: 248, Weight obs: [0.08189101], Smallest density: [0.109475]); the corresponding values are set to y_min
#   warnings.warn(
#  99%|█████████▊| 986/1000 [03:33<00:03,  4.54it/s]/home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 19, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 9.999999999999998, Obs: 54, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 9.999999999999998, Obs: 102, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 9.999999999999998, Obs: 106, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 9.999999999999998, Obs: 128, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 9.999999999999998, Obs: 135, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 9.999999999999998, Obs: 159, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 9.999999999999998, Obs: 236, Weight obs: [0.06473555], Smallest density: [0.11126269]); the corresponding values are set to y_min
#   warnings.warn(
# /home/jef/Code/crepes-weighted/src/crepes_weighted/base.py:1215: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 19, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 10.0, Obs: 54, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 10.0, Obs: 102, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 10.0, Obs: 106, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 10.0, Obs: 128, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 10.0, Obs: 135, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 10.0, Obs: 159, Weight obs: [0.06473555], Smallest density: [0.11126269])
# (Perc: 10.0, Obs: 236, Weight obs: [0.06473555], Smallest density: [0.11126269]); the corresponding values are set to y_min
#   warnings.warn(
# 100%|██████████| 1000/1000 [03:36<00:00,  4.61it/s]

# %%
df_results_cps_no_shift_syn['Method'] = 'SCPS (no shift)'
df_results_cps_shift_not_weighted_syn['Method'] = 'SCPS (shift)'
df_results_cps_shift_weighted_syn['Method'] = 'WSCPS (shift)'
df_results_cps_no_shift_reduced_syn['Method'] = 'SCPS (no shift, reduced)'
df_results_cp_no_shift_syn['Method'] = 'CP (no shift)'
df_results_cp_shift_not_weighted_syn['Method'] = 'CP (shift)'
df_results_cp_shift_weighted_syn['Method'] = 'WCP (shift)'
df_results_cp_no_shift_reduced_syn['Method'] = 'CP (no shift, reduced)'

df_results_syn = pd.concat([df_results_cps_no_shift_syn, df_results_cps_shift_not_weighted_syn, df_results_cps_shift_weighted_syn,
                        df_results_cps_no_shift_reduced_syn,
                        df_results_cp_no_shift_syn, df_results_cp_shift_not_weighted_syn, df_results_cp_shift_weighted_syn,
                        df_results_cp_no_shift_reduced_syn])

df_results_syn["Coverage"] = 1 - df_results_syn["error"]

fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper left")
# set the color palette
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper left")
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="Coverage", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper left")
axs[0].vlines(0.8, 0, 250, color='r', linestyle='--')
axs[1].vlines(0.8, 0, 200, color='r', linestyle='--')
axs[2].vlines(0.8, 0, 175, color='r', linestyle='--')
plt.tight_layout()
plt.savefig("plots/coverage_synthetic.pdf")
plt.show()
# Out:
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper right")
# set the color palette
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper right")
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="CRPS", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper right")
plt.tight_layout()
fig.savefig("plots/crps_synthetic.pdf")
plt.show()
# Out:
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import scipy.stats as ss
import scikit_posthocs as sp

df_results_cps = df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)', 'SCPS (shift)', 'WSCPS (shift)', 'SCPS (no shift, reduced)'])]

avg_rank = df_results_cps.groupby("sim_id")["CRPS"].rank(pct=True).groupby(df_results_cps.Method).mean()

ss.friedmanchisquare(*[df_results_cps[df_results_cps.Method == method].CRPS for method in df_results_cps.Method.unique()])

test_results = sp.posthoc_nemenyi_friedman(df_results_cps, melted=True, y_col="CRPS", block_col="sim_id", group_col="Method")

plt.figure(figsize=(10, 2))
# plt.title("Post-hoc Friedman-Nemenyi test for CRPS")
sp.critical_difference_diagram(avg_rank, test_results, color_palette={"SCPS (no shift)": sns.color_palette()[0],
                                                                      "SCPS (shift)": sns.color_palette()[1],
                                                                      "WSCPS (shift)": sns.color_palette()[2],
                                                                      "SCPS (no shift, reduced)": sns.color_palette()[3]})
plt.tight_layout()
plt.savefig("plots/nemenyi_synthetic.pdf")
plt.show()
# Out:
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %%
quantile_names = [f"coverage_q{q}" for q in np.arange(10, 100, 10)]

# Plot calibration curves
df_results_cps = df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)', 'SCPS (shift)', 'WSCPS (shift)', 'SCPS (no shift, reduced)'])]

## melt the data
df_results_cps_melted = pd.melt(df_results_cps, id_vars=["sim_id", "Method"], value_vars=quantile_names, value_name="Error", var_name="Quantile")
df_results_cps_melted["Quantile"] = df_results_cps_melted["Quantile"].str.replace("coverage_q", "").astype(int)

# %%
sns.pointplot(data=df_results_cps_melted, x="Quantile", y="Error", hue="Method", errorbar="sd")
sns.pointplot(y=np.arange(0.1, 1, 0.1), x=np.arange(10, 100, 10), color='black')
plt.savefig("plots/marginal_calibration_synthetic.pdf")

# %%
NSim = 1000

list_p_values_cps = []
list_p_values_wcps = []
list_p_values_cps_no_shift = []
for i in tqdm(range(NSim)):
    X, y = synthetic_kang_schafer_2007()
    # Without covariate-shift
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
    X_train_prop, X_cal, y_train_prop, y_cal = train_test_split(X_train, y_train, test_size=0.25)

    shift_weights = np.array([-1, 0.5, -0.25, -0.1])
    shifted_likelihood_train_prop = np.exp(X_train_prop @ shift_weights)
    shifted_weights_train_prop = shifted_likelihood_train_prop / np.sum(shifted_likelihood_train_prop)
    shifted_likelihood_test = np.exp(X_test @ shift_weights)
    shifted_weights_test = shifted_likelihood_test / np.sum(shifted_likelihood_test)
    shifted_likelihood_cal =  np.exp(X_cal @ shift_weights)
    
    rf_cps = WrapRegressor(RandomForestRegressor(n_estimators=100, random_state=17))
    rf_cps.fit(X_train_prop, y_train_prop)
    rf_wcps = copy.deepcopy(rf_cps)
    

    idx_shift = weighted_sample(shifted_weights_test, frac=0.5)
    idx_no_shift = weighted_sample(np.ones(len(y_test))/ len(y_test), frac=0.5)
    
    rf_cps.calibrate(X_cal, y_cal, cps=True)
    rf_wcps.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=True)
    
    p_values_cps = rf_cps.predict_cps(X_test[idx_shift], y=y_test[idx_shift])
    p_values_cps_no_shift = rf_cps.predict_cps(X_test[idx_no_shift], y=y_test[idx_no_shift])
    p_values_wcps = rf_wcps.predict_cps(X_test[idx_shift], y=y_test[idx_shift], likelihood_ratios=shifted_likelihood_test[idx_shift])
    
    list_p_values_cps.append(p_values_cps)
    list_p_values_cps_no_shift.append(p_values_cps_no_shift)
    list_p_values_wcps.append(p_values_wcps)
# Out:
# 100%|██████████| 1000/1000 [03:20<00:00,  4.99it/s]

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
bins = 30
sns.histplot(np.concatenate(list_p_values_cps_no_shift), ax = axs[0], bins=bins, 
             color=sns.color_palette()[0], label="CPS (no shift)")
sns.histplot(np.concatenate(list_p_values_cps), ax = axs[1], bins=bins,
             color=sns.color_palette()[1], label="CPS (shift)")
sns.histplot(np.concatenate(list_p_values_wcps), ax = axs[2], bins=bins,
             color=sns.color_palette()[2], label="WCPS (shift)")


axs[0].hlines(len(np.concatenate(list_p_values_cps_no_shift)) / bins, 0, 1, color='r', linestyle='--')
axs[1].hlines(len(np.concatenate(list_p_values_cps)) / bins, 0, 1, color='r', linestyle='--')
axs[2].hlines(len(np.concatenate(list_p_values_wcps)) / bins, 0, 1, color='r', linestyle='--')

axs[0].vlines(0, 0, len(np.concatenate(list_p_values_cps_no_shift)) / bins, color='r', linestyle='--')
axs[1].vlines(0, 0, len(np.concatenate(list_p_values_cps)) / bins, color='r', linestyle='--')
axs[2].vlines(0, 0, len(np.concatenate(list_p_values_wcps)) / bins, color='r', linestyle='--')

axs[0].vlines(1, 0, len(np.concatenate(list_p_values_cps_no_shift)) / bins, color='r', linestyle='--')
axs[1].vlines(1, 0, len(np.concatenate(list_p_values_cps)) / bins, color='r', linestyle='--')
axs[2].vlines(1, 0, len(np.concatenate(list_p_values_wcps)) / bins, color='r', linestyle='--')

axs[0].set_title("Distribution of SCPS(X,y)\n(no shift)")
axs[1].set_title("Distribution of SCPS(X,y)\n(shift)")
axs[2].set_title("Distribution of WSCPS(X,y)\n(shift)")

axs[0].set_xlabel("Q(X,y)")
axs[1].set_xlabel("Q(X,y)")
axs[2].set_xlabel("Q(X,y)")

plt.tight_layout()
fig.savefig("plots/prob_calibration_synthetic.pdf")
plt.show()
# Out:
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jef/anaconda3/envs/crepes/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
