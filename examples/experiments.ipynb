# %% [markdown]
# # Simulation Experiments

# %%
import sys
sys.path.append('..')
sys.path.append('../src')

import opendatasets as od
import tempfile
import zipfile
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor
from src.crepes_weighted import WrapRegressor
import copy
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def weighted_sample(weights, frac=0.5):
    return np.random.choice(range(len(weights)), size=int(len(weights) * frac), p=weights)

# %% [markdown]
# ## Airfoil Dataset

# %%
with tempfile.TemporaryDirectory() as temp_dir:
    od.download("https://archive.ics.uci.edu/static/public/291/airfoil+self+noise.zip",
                temp_dir)
    with zipfile.ZipFile(temp_dir + "/airfoil+self+noise.zip", 'r') as zip_ref:
        df = pd.read_csv(zip_ref.open('airfoil_self_noise.dat'), sep='\t', header=None)
        df.columns = ['Frequency', 'Angle', 'Chord', 'Velocity', 'Suction', 'Sound']
        df['Log_freq'] = np.log(df['Frequency'])
        df['Log_suct'] = np.log(df['Suction'])
        df = df.drop(columns=['Frequency', 'Suction'])
# Out:
# Downloading https://archive.ics.uci.edu/static/public/291/airfoil+self+noise.zip to /var/folders/fb/lzd0fz_d69v05khmd495_rwr0000gn/T/tmpj3blv9lx/airfoil+self+noise.zip
# 65536it [00:01, 50717.12it/s]

# %%
NSim = 1000
confidence = 0.8

for i in tqdm(range(NSim)):
    # Without covariate-shift
    X_train, X_test, y_train, y_test = train_test_split(df.drop('Sound', axis=1), df['Sound'], test_size=0.5)
    X_train_prop, X_cal, y_train_prop, y_cal = train_test_split(X_train, y_train, test_size=0.5)

    shifted_likelihood_train_prop = np.exp(X_train_prop[['Log_freq', 'Log_suct']].to_numpy() @ np.array([-1, 1]))
    shifted_weights_train_prop = shifted_likelihood_train_prop / np.sum(shifted_likelihood_train_prop)
    shifted_likelihood_test = np.exp(X_test[['Log_freq', 'Log_suct']].to_numpy() @ np.array([-1, 1]))
    shifted_weights_test = shifted_likelihood_test / np.sum(shifted_likelihood_test)
    shifted_likelihood_cal = np.exp(X_cal[['Log_freq', 'Log_suct']].to_numpy() @ np.array([-1, 1]))

    rf_cps = WrapRegressor(RandomForestRegressor(n_estimators=100, random_state=17))
    rf_cps.fit(X_train_prop, y_train_prop)
    rf_cp = copy.deepcopy(rf_cps)
    rf_cp.calibrate(X_cal, y_cal, cps=False)
    rf_cps.calibrate(X_cal, y_cal, cps=True)

    idx_no_shift = weighted_sample(np.ones(len(shifted_weights_test))/len(shifted_weights_test), frac=0.25)
    idx_shift = weighted_sample(shifted_weights_test, frac=0.25)

    n_reduced = np.sum(np.abs(shifted_likelihood_cal))**2 / np.sum(shifted_likelihood_cal**2)
    n = len(shifted_likelihood_cal)

    result_cps_no_shift = rf_cps.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift],
                                  confidence=confidence)
    result_cps_shift_not_weighted = rf_cps.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift],
                                            confidence=confidence)
    result_cp_no_shift = rf_cp.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift],
                                    confidence=confidence)
    result_cp_shift_not_weighted = rf_cp.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift],
                                              confidence=confidence)

    idx_cal_n_reduced = np.random.choice(range(n), size=int(n_reduced), replace=False)

    rf_cps_shift = copy.deepcopy(rf_cps)
    rf_cps_no_shift_reduced = copy.deepcopy(rf_cps)
    rf_cp_shift = copy.deepcopy(rf_cp)
    rf_cp_no_shift_reduced = copy.deepcopy(rf_cp)


    rf_cps_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=True)
    rf_cp_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=False)

    rf_cps_no_shift_reduced.calibrate(X_cal.iloc[idx_cal_n_reduced], y_cal.iloc[idx_cal_n_reduced], cps=True)
    rf_cp_no_shift_reduced.calibrate(X_cal.iloc[idx_cal_n_reduced], y_cal.iloc[idx_cal_n_reduced], cps=False)

    result_cps_shift_weighted = rf_cps_shift.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift].to_numpy(),
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cp_shift_weighted = rf_cp_shift.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift].to_numpy(),
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cps_no_shift_reduced = rf_cps_no_shift_reduced.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift].to_numpy(),
                    confidence=confidence)
    result_cp_no_shift_reduced = rf_cp_no_shift_reduced.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift].to_numpy(),
                    confidence=confidence)

    result_cps_shift_weighted["reduced_n"] = n_reduced
    result_cp_shift_weighted["reduced_n"] = n_reduced
    result_cps_no_shift_reduced["reduced_n"] = int(n_reduced)
    result_cp_no_shift_reduced["reduced_n"] = int(n_reduced)

    result_cps_no_shift["sim_id"] = i
    result_cps_shift_not_weighted["sim_id"] = i
    result_cps_shift_weighted["sim_id"] = i
    result_cp_no_shift["sim_id"] = i
    result_cp_shift_not_weighted["sim_id"] = i
    result_cp_shift_weighted["sim_id"] = i
    result_cps_no_shift_reduced["sim_id"] = i
    result_cp_no_shift_reduced["sim_id"] = i

    if i == 0:
        df_results_cps_no_shift = pd.DataFrame(result_cps_no_shift, index=[0])
        df_results_cps_shift_not_weighted = pd.DataFrame(result_cps_shift_not_weighted, index=[0])
        df_results_cps_shift_weighted = pd.DataFrame(result_cps_shift_weighted, index=[0])
        df_results_cp_no_shift = pd.DataFrame(result_cp_no_shift, index=[0])
        df_results_cp_shift_not_weighted = pd.DataFrame(result_cp_shift_not_weighted, index=[0])
        df_results_cp_shift_weighted = pd.DataFrame(result_cp_shift_weighted, index=[0])
        df_results_cps_no_shift_reduced = pd.DataFrame(result_cps_no_shift_reduced, index=[0])
        df_results_cp_no_shift_reduced = pd.DataFrame(result_cp_no_shift_reduced, index=[0])
    else:
        df_results_cps_no_shift = pd.concat([df_results_cps_no_shift, pd.DataFrame(result_cps_no_shift, index=[0])])
        df_results_cps_shift_not_weighted = pd.concat([df_results_cps_shift_not_weighted, pd.DataFrame(result_cps_shift_not_weighted, index=[0])])
        df_results_cps_shift_weighted = pd.concat([df_results_cps_shift_weighted, pd.DataFrame(result_cps_shift_weighted, index=[0])])
        df_results_cp_no_shift = pd.concat([df_results_cp_no_shift, pd.DataFrame(result_cp_no_shift, index=[0])])
        df_results_cp_shift_not_weighted = pd.concat([df_results_cp_shift_not_weighted, pd.DataFrame(result_cp_shift_not_weighted, index=[0])])
        df_results_cp_shift_weighted = pd.concat([df_results_cp_shift_weighted, pd.DataFrame(result_cp_shift_weighted, index=[0])])
        df_results_cps_no_shift_reduced = pd.concat([df_results_cps_no_shift_reduced, pd.DataFrame(result_cps_no_shift_reduced, index=[0])])
        df_results_cp_no_shift_reduced = pd.concat([df_results_cp_no_shift_reduced, pd.DataFrame(result_cp_no_shift_reduced, index=[0])])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2 confidence = 0.8
#       4 for i in tqdm(range(NSim)):
#       5     # Without covariate-shift
# ----> 6     X_train, X_test, y_train, y_test = train_test_split(df.drop('Sound', axis=1), df['Sound'], test_size=0.5)
#       7     X_train_prop, X_cal, y_train_prop, y_cal = train_test_split(X_train, y_train, test_size=0.5)
#       9     shifted_likelihood_train_prop = np.exp(X_train_prop[['Log_freq', 'Log_suct']].to_numpy() @ np.array([-1, 1]))
#
# NameError: name 'df' is not defined

# %%
df_results_cps_no_shift['Method'] = 'SCPS (no shift)'
df_results_cps_shift_not_weighted['Method'] = 'SCPS (shift)'
df_results_cps_shift_weighted['Method'] = 'WSCPS (shift)'
df_results_cps_no_shift_reduced['Method'] = 'SCPS (no shift, reduced)'
df_results_cp_no_shift['Method'] = 'CP (no shift)'
df_results_cp_shift_not_weighted['Method'] = 'CP (shift)'
df_results_cp_shift_weighted['Method'] = 'WCP (shift)'
df_results_cp_no_shift_reduced['Method'] = 'CP (no shift, reduced)'

df_results = pd.concat([df_results_cps_no_shift, df_results_cps_shift_not_weighted, df_results_cps_shift_weighted,
                        df_results_cps_no_shift_reduced,
                        df_results_cp_no_shift, df_results_cp_shift_not_weighted, df_results_cp_shift_weighted,
                        df_results_cp_no_shift_reduced])

df_results["Coverage"] = 1 - df_results["error"]

fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results[df_results["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper left")
# set the color palette
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper left")
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="Coverage", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper left")
axs[0].vlines(0.8, 0, 250, color='r', linestyle='--')
axs[1].vlines(0.8, 0, 160, color='r', linestyle='--')
axs[2].vlines(0.8, 0, 175, color='r', linestyle='--')
plt.tight_layout()
fig.savefig("plots/coverage_airfoil.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results[df_results["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper right")
# set the color palette
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper right")
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="CRPS", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper right")
plt.tight_layout()
fig.savefig("plots/crps_airfoil.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results[df_results["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="ks_pvalue", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper right")
# set the color palette
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="ks_pvalue", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper right")
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="ks_pvalue", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper right")
plt.tight_layout()
fig.savefig("plots/ks_pvalue_airfoil.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import scipy.stats as ss
import scikit_posthocs as sp

df_results_cps = df_results[df_results["Method"].isin(['SCPS (no shift)', 'SCPS (shift)', 'WSCPS (shift)', 'SCPS (no shift, reduced)'])]

avg_rank = df_results_cps.groupby("sim_id")["CRPS"].rank(pct=True).groupby(df_results_cps.Method).mean()

ss.friedmanchisquare(*[df_results_cps[df_results_cps.Method == method].CRPS for method in df_results_cps.Method.unique()])

test_results = sp.posthoc_nemenyi_friedman(df_results_cps, melted=True, y_col="CRPS", block_col="sim_id", group_col="Method")


plt.figure(figsize=(10, 2))
# plt.title("Post-hoc Friedman-Nemenyi test for CRPS")
sp.critical_difference_diagram(avg_rank, test_results, color_palette={"SCPS (no shift)": sns.color_palette()[0],
                                                                      "SCPS (shift)": sns.color_palette()[1],
                                                                      "WSCPS (shift)": sns.color_palette()[2],
                                                                      "SCPS (no shift, reduced)": sns.color_palette()[3]})
plt.tight_layout()
plt.savefig("plots/nemenyi_airfoil.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %%
import scipy.stats as ss
import scikit_posthocs as sp

df_results_cps = df_results[df_results["Method"].isin(['SCPS (no shift)', 'SCPS (shift)', 'WSCPS (shift)', 'SCPS (no shift, reduced)'])]

avg_rank = df_results_cps.groupby("sim_id")["ks_pvalue"].rank(pct=True).groupby(df_results_cps.Method).mean()

ss.friedmanchisquare(*[df_results_cps[df_results_cps.Method == method].ks_pvalue for method in df_results_cps.Method.unique()])

test_results = sp.posthoc_nemenyi_friedman(df_results_cps, melted=True, y_col="ks_pvalue", block_col="sim_id", group_col="Method")


plt.figure(figsize=(10, 2))
# plt.title("Post-hoc Friedman-Nemenyi test for CRPS")
sp.critical_difference_diagram(avg_rank, test_results, color_palette={"SCPS (no shift)": sns.color_palette()[0],
                                                                      "SCPS (shift)": sns.color_palette()[1],
                                                                      "WSCPS (shift)": sns.color_palette()[2],
                                                                      "SCPS (no shift, reduced)": sns.color_palette()[3]})
plt.tight_layout()
plt.savefig("plots/nemenyi_airfoil_ks_pvalue.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %% [markdown]
# ## Synthetic Dataset (Kang and Schafer (2007))
# **Note: that this synthetic dataset is also used in Yang et al. 2022**

# %%
def synthetic_kang_schafer_2007(n=2000, weights=None):
    if weights is None:
        weights = np.ones(n)/n
    x1 = np.random.normal(size=n)
    x2 = np.random.normal(size=n)
    x3 = np.random.normal(size=n)
    x4 = np.random.normal(size=n)

    y = 210 + 27.4*x1 + 13.7*x2 + 13.7*x3 + 13.7*x4 + np.random.normal(size=n)

    return np.stack([x1, x2, x3, x4], axis=1), y

# %%
NSim = 1000
confidence = 0.8

for i in tqdm(range(NSim)):
    X, y = synthetic_kang_schafer_2007()
    # Without covariate-shift
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
    X_train_prop, X_cal, y_train_prop, y_cal = train_test_split(X_train, y_train, test_size=0.5)

    shift_weights = np.array([-1, 0.5, -0.25, -0.1])
    shifted_likelihood_train_prop = np.exp(X_train_prop @ shift_weights)
    shifted_weights_train_prop = shifted_likelihood_train_prop / np.sum(shifted_likelihood_train_prop)
    shifted_likelihood_test = np.exp(X_test @ shift_weights)
    shifted_weights_test = shifted_likelihood_test / np.sum(shifted_likelihood_test)
    shifted_likelihood_cal =  np.exp(X_cal @ shift_weights)

    rf_cps = WrapRegressor(RandomForestRegressor(n_estimators=100, random_state=17))
    rf_cps.fit(X_train_prop, y_train_prop)
    rf_cp = copy.deepcopy(rf_cps)
    rf_cp.calibrate(X_cal, y_cal, cps=False)
    rf_cps.calibrate(X_cal, y_cal, cps=True)

    idx_no_shift = weighted_sample(np.ones(len(shifted_weights_test))/len(shifted_weights_test), frac=0.25)
    idx_shift = weighted_sample(shifted_weights_test, frac=0.25)

    n_reduced = np.sum(np.abs(shifted_likelihood_cal))**2 / np.sum(shifted_likelihood_cal**2)
    n = len(shifted_likelihood_cal)

    result_cps_no_shift = rf_cps.evaluate(X_test[idx_no_shift], y_test[idx_no_shift],
                                  confidence=confidence)
    result_cps_shift_not_weighted = rf_cps.evaluate(X_test[idx_shift], y_test[idx_shift],
                                            confidence=confidence)
    result_cp_no_shift = rf_cp.evaluate(X_test[idx_no_shift], y_test[idx_no_shift],
                                    confidence=confidence)
    result_cp_shift_not_weighted = rf_cp.evaluate(X_test[idx_shift], y_test[idx_shift],
                                              confidence=confidence)

    idx_cal_n_reduced = np.random.choice(range(n), size=int(n_reduced), replace=False)

    rf_cps_shift = copy.deepcopy(rf_cps)
    rf_cps_no_shift_reduced = copy.deepcopy(rf_cps)
    rf_cp_shift = copy.deepcopy(rf_cp)
    rf_cp_no_shift_reduced = copy.deepcopy(rf_cp)


    rf_cps_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=True)
    rf_cp_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=False)

    rf_cps_no_shift_reduced.calibrate(X_cal[idx_cal_n_reduced], y_cal[idx_cal_n_reduced], cps=True)
    rf_cp_no_shift_reduced.calibrate(X_cal[idx_cal_n_reduced], y_cal[idx_cal_n_reduced], cps=False)

    result_cps_shift_weighted = rf_cps_shift.evaluate(X_test[idx_shift], y_test[idx_shift],
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cp_shift_weighted = rf_cp_shift.evaluate(X_test[idx_shift], y_test[idx_shift],
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cps_no_shift_reduced = rf_cps_no_shift_reduced.evaluate(X_test[idx_no_shift], y_test[idx_no_shift],
                    confidence=confidence)
    result_cp_no_shift_reduced = rf_cp_no_shift_reduced.evaluate(X_test[idx_no_shift], y_test[idx_no_shift],
                    confidence=confidence)

    result_cps_shift_weighted["reduced_n"] = n_reduced
    result_cp_shift_weighted["reduced_n"] = n_reduced
    result_cps_no_shift_reduced["reduced_n"] = int(n_reduced)
    result_cp_no_shift_reduced["reduced_n"] = int(n_reduced)

    result_cps_no_shift["sim_id"] = i
    result_cps_shift_not_weighted["sim_id"] = i
    result_cps_shift_weighted["sim_id"] = i
    result_cp_no_shift["sim_id"] = i
    result_cp_shift_not_weighted["sim_id"] = i
    result_cp_shift_weighted["sim_id"] = i
    result_cps_no_shift_reduced["sim_id"] = i
    result_cp_no_shift_reduced["sim_id"] = i

    if i == 0:
        df_results_cps_no_shift_syn = pd.DataFrame(result_cps_no_shift, index=[0])
        df_results_cps_shift_not_weighted_syn = pd.DataFrame(result_cps_shift_not_weighted, index=[0])
        df_results_cps_shift_weighted_syn = pd.DataFrame(result_cps_shift_weighted, index=[0])
        df_results_cp_no_shift_syn = pd.DataFrame(result_cp_no_shift, index=[0])
        df_results_cp_shift_not_weighted_syn = pd.DataFrame(result_cp_shift_not_weighted, index=[0])
        df_results_cp_shift_weighted_syn = pd.DataFrame(result_cp_shift_weighted, index=[0])
        df_results_cps_no_shift_reduced_syn = pd.DataFrame(result_cps_no_shift_reduced, index=[0])
        df_results_cp_no_shift_reduced_syn = pd.DataFrame(result_cp_no_shift_reduced, index=[0])
    else:
        df_results_cps_no_shift_syn = pd.concat([df_results_cps_no_shift_syn, pd.DataFrame(result_cps_no_shift, index=[0])])
        df_results_cps_shift_not_weighted_syn = pd.concat([df_results_cps_shift_not_weighted_syn, pd.DataFrame(result_cps_shift_not_weighted, index=[0])])
        df_results_cps_shift_weighted_syn = pd.concat([df_results_cps_shift_weighted_syn, pd.DataFrame(result_cps_shift_weighted, index=[0])])
        df_results_cp_no_shift_syn = pd.concat([df_results_cp_no_shift_syn, pd.DataFrame(result_cp_no_shift, index=[0])])
        df_results_cp_shift_not_weighted_syn = pd.concat([df_results_cp_shift_not_weighted_syn, pd.DataFrame(result_cp_shift_not_weighted, index=[0])])
        df_results_cp_shift_weighted_syn = pd.concat([df_results_cp_shift_weighted_syn, pd.DataFrame(result_cp_shift_weighted, index=[0])])
        df_results_cps_no_shift_reduced_syn = pd.concat([df_results_cps_no_shift_reduced_syn, pd.DataFrame(result_cps_no_shift_reduced, index=[0])])
        df_results_cp_no_shift_reduced_syn = pd.concat([df_results_cp_no_shift_reduced_syn, pd.DataFrame(result_cp_no_shift_reduced, index=[0])])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   1%|          | 12/1000 [00:02<03:59,  4.13it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 7, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 9.999999999999998, Obs: 108, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 9.999999999999998, Obs: 214, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 9.999999999999998, Obs: 219, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 9.999999999999998, Obs: 229, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 9.999999999999998, Obs: 236, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 9.999999999999998, Obs: 248, Weight obs: [0.07550492], Smallest density: [0.10026416]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 7, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 10.0, Obs: 108, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 10.0, Obs: 214, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 10.0, Obs: 219, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 10.0, Obs: 229, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 10.0, Obs: 236, Weight obs: [0.07550492], Smallest density: [0.10026416])
# (Perc: 10.0, Obs: 248, Weight obs: [0.07550492], Smallest density: [0.10026416]); the corresponding values are set to y_min
#   warnings.warn(
#   2%|▏         | 17/1000 [00:04<03:54,  4.19it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 19, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 34, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 50, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 68, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 87, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 92, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 99, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 107, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 118, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 139, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 191, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 211, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 9.999999999999998, Obs: 229, Weight obs: [0.1090831], Smallest density: [0.10986552]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1272: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 19, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 34, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 50, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 68, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 87, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 92, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 99, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 107, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 118, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 139, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 191, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 211, Weight obs: [0.1090831])
# (Perc: 90.0, Obs: 229, Weight obs: [0.1090831]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 19, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 34, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 50, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 68, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 87, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 92, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 99, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 107, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 118, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 139, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 191, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 211, Weight obs: [0.1090831], Smallest density: [0.10986552])
# (Perc: 10.0, Obs: 229, Weight obs: [0.1090831], Smallest density: [0.10986552]); the corresponding values are set to y_min
#   warnings.warn(
#   3%|▎         | 30/1000 [00:07<03:57,  4.09it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 30, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 37, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 46, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 49, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 82, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 99, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 102, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 152, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 165, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 170, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 178, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 200, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 227, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 9.999999999999998, Obs: 232, Weight obs: [0.10077743], Smallest density: [0.11010542]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1272: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 30, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 37, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 46, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 49, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 82, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 99, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 102, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 152, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 165, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 170, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 178, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 200, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 227, Weight obs: [0.10077743])
# (Perc: 90.0, Obs: 232, Weight obs: [0.10077743]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 30, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 37, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 46, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 49, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 82, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 99, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 102, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 152, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 165, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 170, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 178, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 200, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 227, Weight obs: [0.10077743], Smallest density: [0.11010542])
# (Perc: 10.0, Obs: 232, Weight obs: [0.10077743], Smallest density: [0.11010542]); the corresponding values are set to y_min
#   warnings.warn(
#   5%|▌         | 51/1000 [00:12<03:48,  4.16it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 14, Weight obs: [0.04008392], Smallest density: [0.10445009])
# (Perc: 9.999999999999998, Obs: 24, Weight obs: [0.04008392], Smallest density: [0.10445009])
# (Perc: 9.999999999999998, Obs: 25, Weight obs: [0.04008392], Smallest density: [0.10445009])
# (Perc: 9.999999999999998, Obs: 119, Weight obs: [0.04008392], Smallest density: [0.10445009])
# (Perc: 9.999999999999998, Obs: 126, Weight obs: [0.04008392], Smallest density: [0.10445009])
# (Perc: 9.999999999999998, Obs: 243, Weight obs: [0.04008392], Smallest density: [0.10445009]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 14, Weight obs: [0.04008392], Smallest density: [0.10445009])
# (Perc: 10.0, Obs: 24, Weight obs: [0.04008392], Smallest density: [0.10445009])
# (Perc: 10.0, Obs: 25, Weight obs: [0.04008392], Smallest density: [0.10445009])
# (Perc: 10.0, Obs: 119, Weight obs: [0.04008392], Smallest density: [0.10445009])
# (Perc: 10.0, Obs: 126, Weight obs: [0.04008392], Smallest density: [0.10445009])
# (Perc: 10.0, Obs: 243, Weight obs: [0.04008392], Smallest density: [0.10445009]); the corresponding values are set to y_min
#   warnings.warn(
#   7%|▋         | 70/1000 [00:16<03:41,  4.20it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 62, Weight obs: [0.05064011], Smallest density: [0.11944918])
# (Perc: 9.999999999999998, Obs: 119, Weight obs: [0.05064011], Smallest density: [0.11944918])
# (Perc: 9.999999999999998, Obs: 123, Weight obs: [0.05064011], Smallest density: [0.11944918])
# (Perc: 9.999999999999998, Obs: 178, Weight obs: [0.05064011], Smallest density: [0.11944918])
# (Perc: 9.999999999999998, Obs: 231, Weight obs: [0.05064011], Smallest density: [0.11944918]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 62, Weight obs: [0.05064011], Smallest density: [0.11944918])
# (Perc: 10.0, Obs: 119, Weight obs: [0.05064011], Smallest density: [0.11944918])
# (Perc: 10.0, Obs: 123, Weight obs: [0.05064011], Smallest density: [0.11944918])
# (Perc: 10.0, Obs: 178, Weight obs: [0.05064011], Smallest density: [0.11944918])
# (Perc: 10.0, Obs: 231, Weight obs: [0.05064011], Smallest density: [0.11944918]); the corresponding values are set to y_min
#   warnings.warn(
#   9%|▉         | 91/1000 [00:21<03:34,  4.24it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 4, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 9.999999999999998, Obs: 12, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 9.999999999999998, Obs: 34, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 9.999999999999998, Obs: 43, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 9.999999999999998, Obs: 63, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 9.999999999999998, Obs: 120, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 9.999999999999998, Obs: 127, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 9.999999999999998, Obs: 142, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 9.999999999999998, Obs: 191, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 9.999999999999998, Obs: 242, Weight obs: [0.09105355], Smallest density: [0.11545362]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1272: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 4, Weight obs: [0.09105355])
# (Perc: 90.0, Obs: 12, Weight obs: [0.09105355])
# (Perc: 90.0, Obs: 34, Weight obs: [0.09105355])
# (Perc: 90.0, Obs: 43, Weight obs: [0.09105355])
# (Perc: 90.0, Obs: 63, Weight obs: [0.09105355])
# (Perc: 90.0, Obs: 120, Weight obs: [0.09105355])
# (Perc: 90.0, Obs: 127, Weight obs: [0.09105355])
# (Perc: 90.0, Obs: 142, Weight obs: [0.09105355])
# (Perc: 90.0, Obs: 191, Weight obs: [0.09105355])
# (Perc: 90.0, Obs: 242, Weight obs: [0.09105355]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 4, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 10.0, Obs: 12, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 10.0, Obs: 34, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 10.0, Obs: 43, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 10.0, Obs: 63, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 10.0, Obs: 120, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 10.0, Obs: 127, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 10.0, Obs: 142, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 10.0, Obs: 191, Weight obs: [0.09105355], Smallest density: [0.11545362])
# (Perc: 10.0, Obs: 242, Weight obs: [0.09105355], Smallest density: [0.11545362]); the corresponding values are set to y_min
#   warnings.warn(
#   9%|▉         | 94/1000 [00:22<03:32,  4.26it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 6, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 9.999999999999998, Obs: 12, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 9.999999999999998, Obs: 16, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 9.999999999999998, Obs: 34, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 9.999999999999998, Obs: 35, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 9.999999999999998, Obs: 44, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 9.999999999999998, Obs: 56, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 9.999999999999998, Obs: 58, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 9.999999999999998, Obs: 71, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 9.999999999999998, Obs: 92, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 9.999999999999998, Obs: 125, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 9.999999999999998, Obs: 142, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 9.999999999999998, Obs: 148, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 9.999999999999998, Obs: 151, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 9.999999999999998, Obs: 163, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 9.999999999999998, Obs: 193, Weight obs: [0.04812897], Smallest density: [0.11457985]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 6, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 10.0, Obs: 12, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 10.0, Obs: 16, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 10.0, Obs: 34, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 10.0, Obs: 35, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 10.0, Obs: 44, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 10.0, Obs: 56, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 10.0, Obs: 58, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 10.0, Obs: 71, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 10.0, Obs: 92, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 10.0, Obs: 125, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 10.0, Obs: 142, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 10.0, Obs: 148, Weight obs: [0.07666623], Smallest density: [0.1411249])
# (Perc: 10.0, Obs: 151, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 10.0, Obs: 163, Weight obs: [0.04812897], Smallest density: [0.11457985])
# (Perc: 10.0, Obs: 193, Weight obs: [0.04812897], Smallest density: [0.11457985]); the corresponding values are set to y_min
#   warnings.warn(
#  12%|█▏        | 122/1000 [00:29<03:26,  4.24it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 27, Weight obs: [0.04675142], Smallest density: [0.11696918])
# (Perc: 9.999999999999998, Obs: 80, Weight obs: [0.04675142], Smallest density: [0.11696918])
# (Perc: 9.999999999999998, Obs: 177, Weight obs: [0.04675142], Smallest density: [0.11696918])
# (Perc: 9.999999999999998, Obs: 232, Weight obs: [0.04675142], Smallest density: [0.11696918]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 27, Weight obs: [0.04675142], Smallest density: [0.11696918])
# (Perc: 10.0, Obs: 80, Weight obs: [0.04675142], Smallest density: [0.11696918])
# (Perc: 10.0, Obs: 177, Weight obs: [0.04675142], Smallest density: [0.11696918])
# (Perc: 10.0, Obs: 232, Weight obs: [0.04675142], Smallest density: [0.11696918]); the corresponding values are set to y_min
#   warnings.warn(
#  12%|█▏        | 124/1000 [00:29<03:25,  4.26it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 15, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 9.999999999999998, Obs: 24, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 9.999999999999998, Obs: 34, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 9.999999999999998, Obs: 63, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 9.999999999999998, Obs: 77, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 9.999999999999998, Obs: 152, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 9.999999999999998, Obs: 176, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 9.999999999999998, Obs: 179, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 9.999999999999998, Obs: 213, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 9.999999999999998, Obs: 217, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 9.999999999999998, Obs: 231, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 9.999999999999998, Obs: 239, Weight obs: [0.09132979], Smallest density: [0.10787494]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 15, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 10.0, Obs: 24, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 10.0, Obs: 34, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 10.0, Obs: 63, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 10.0, Obs: 77, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 10.0, Obs: 152, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 10.0, Obs: 176, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 10.0, Obs: 179, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 10.0, Obs: 213, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 10.0, Obs: 217, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 10.0, Obs: 231, Weight obs: [0.09132979], Smallest density: [0.10787494])
# (Perc: 10.0, Obs: 239, Weight obs: [0.09132979], Smallest density: [0.10787494]); the corresponding values are set to y_min
#   warnings.warn(
#  14%|█▍        | 145/1000 [00:34<03:27,  4.13it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 42, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 67, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 84, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 93, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 95, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 100, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 125, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 127, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 129, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 136, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 149, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 166, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 185, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 194, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 207, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 210, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 234, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 243, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 9.999999999999998, Obs: 249, Weight obs: [0.08768659], Smallest density: [0.10051428]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 42, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 67, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 84, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 93, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 95, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 100, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 125, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 127, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 129, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 136, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 149, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 166, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 185, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 194, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 207, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 210, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 234, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 243, Weight obs: [0.08768659], Smallest density: [0.10051428])
# (Perc: 10.0, Obs: 249, Weight obs: [0.08768659], Smallest density: [0.10051428]); the corresponding values are set to y_min
#   warnings.warn(
#  18%|█▊        | 175/1000 [00:41<03:16,  4.20it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 0, Weight obs: [0.04094424], Smallest density: [0.11005111])
# (Perc: 9.999999999999998, Obs: 7, Weight obs: [0.04094424], Smallest density: [0.11005111])
# (Perc: 9.999999999999998, Obs: 107, Weight obs: [0.04094424], Smallest density: [0.11005111])
# (Perc: 9.999999999999998, Obs: 108, Weight obs: [0.04094424], Smallest density: [0.11005111]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 0, Weight obs: [0.04094424], Smallest density: [0.11005111])
# (Perc: 10.0, Obs: 7, Weight obs: [0.04094424], Smallest density: [0.11005111])
# (Perc: 10.0, Obs: 107, Weight obs: [0.04094424], Smallest density: [0.11005111])
# (Perc: 10.0, Obs: 108, Weight obs: [0.04094424], Smallest density: [0.11005111]); the corresponding values are set to y_min
#   warnings.warn(
#  18%|█▊        | 176/1000 [00:42<03:14,  4.23it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 41, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 9.999999999999998, Obs: 54, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 9.999999999999998, Obs: 70, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 9.999999999999998, Obs: 145, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 9.999999999999998, Obs: 188, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 9.999999999999998, Obs: 214, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 9.999999999999998, Obs: 237, Weight obs: [0.09239705], Smallest density: [0.13244018]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1272: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 41, Weight obs: [0.09239705])
# (Perc: 90.0, Obs: 54, Weight obs: [0.09239705])
# (Perc: 90.0, Obs: 70, Weight obs: [0.09239705])
# (Perc: 90.0, Obs: 145, Weight obs: [0.09239705])
# (Perc: 90.0, Obs: 188, Weight obs: [0.09239705])
# (Perc: 90.0, Obs: 214, Weight obs: [0.09239705])
# (Perc: 90.0, Obs: 237, Weight obs: [0.09239705]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 41, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 10.0, Obs: 54, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 10.0, Obs: 70, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 10.0, Obs: 145, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 10.0, Obs: 188, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 10.0, Obs: 214, Weight obs: [0.09239705], Smallest density: [0.13244018])
# (Perc: 10.0, Obs: 237, Weight obs: [0.09239705], Smallest density: [0.13244018]); the corresponding values are set to y_min
#   warnings.warn(
#  18%|█▊        | 179/1000 [00:42<03:18,  4.14it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 72, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 9.999999999999998, Obs: 96, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 9.999999999999998, Obs: 99, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 9.999999999999998, Obs: 169, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 9.999999999999998, Obs: 210, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 9.999999999999998, Obs: 218, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 9.999999999999998, Obs: 243, Weight obs: [0.0867359], Smallest density: [0.12036155]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 72, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 10.0, Obs: 96, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 10.0, Obs: 99, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 10.0, Obs: 169, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 10.0, Obs: 210, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 10.0, Obs: 218, Weight obs: [0.0867359], Smallest density: [0.12036155])
# (Perc: 10.0, Obs: 243, Weight obs: [0.0867359], Smallest density: [0.12036155]); the corresponding values are set to y_min
#   warnings.warn(
#  19%|█▉        | 188/1000 [00:44<03:10,  4.27it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 11, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 9.999999999999998, Obs: 32, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 9.999999999999998, Obs: 38, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 9.999999999999998, Obs: 56, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 9.999999999999998, Obs: 115, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 9.999999999999998, Obs: 148, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 9.999999999999998, Obs: 155, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 9.999999999999998, Obs: 178, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 9.999999999999998, Obs: 198, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 9.999999999999998, Obs: 214, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 9.999999999999998, Obs: 226, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 9.999999999999998, Obs: 234, Weight obs: [0.08658364], Smallest density: [0.11682192]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 11, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 10.0, Obs: 32, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 10.0, Obs: 38, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 10.0, Obs: 56, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 10.0, Obs: 115, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 10.0, Obs: 148, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 10.0, Obs: 155, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 10.0, Obs: 178, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 10.0, Obs: 198, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 10.0, Obs: 214, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 10.0, Obs: 226, Weight obs: [0.08658364], Smallest density: [0.11682192])
# (Perc: 10.0, Obs: 234, Weight obs: [0.08658364], Smallest density: [0.11682192]); the corresponding values are set to y_min
#   warnings.warn(
#  19%|█▉        | 191/1000 [00:45<03:08,  4.28it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 8, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 21, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 25, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 51, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 53, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 78, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 89, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 112, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 118, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 146, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 148, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 168, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 178, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 222, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 230, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 232, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 9.999999999999998, Obs: 248, Weight obs: [0.16221415], Smallest density: [0.16230218]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1272: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 8, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 21, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 25, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 51, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 53, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 78, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 89, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 112, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 118, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 146, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 148, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 168, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 178, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 222, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 230, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 232, Weight obs: [0.16221415])
# (Perc: 90.0, Obs: 248, Weight obs: [0.16221415]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 8, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 21, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 25, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 51, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 53, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 78, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 89, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 112, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 118, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 146, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 148, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 168, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 178, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 222, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 230, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 232, Weight obs: [0.16221415], Smallest density: [0.16230218])
# (Perc: 10.0, Obs: 248, Weight obs: [0.16221415], Smallest density: [0.16230218]); the corresponding values are set to y_min
#   warnings.warn(
#  20%|█▉        | 195/1000 [00:46<03:10,  4.22it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 55, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 92, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 111, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 127, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 136, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 140, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 153, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 164, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 213, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 227, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 232, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 233, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 234, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 236, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 9.999999999999998, Obs: 239, Weight obs: [0.11613059], Smallest density: [0.11912425]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1272: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 55, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 92, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 111, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 127, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 136, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 140, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 153, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 164, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 213, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 227, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 232, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 233, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 234, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 236, Weight obs: [0.11613059])
# (Perc: 90.0, Obs: 239, Weight obs: [0.11613059]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 55, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 92, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 111, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 127, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 136, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 140, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 153, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 164, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 213, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 227, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 232, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 233, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 234, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 236, Weight obs: [0.11613059], Smallest density: [0.11912425])
# (Perc: 10.0, Obs: 239, Weight obs: [0.11613059], Smallest density: [0.11912425]); the corresponding values are set to y_min
#   warnings.warn(
#  21%|██        | 210/1000 [00:50<03:14,  4.06it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 0, Weight obs: [0.00048057], Smallest density: [0.14078555])
# (Perc: 9.999999999999998, Obs: 1, Weight obs: [0.01046547], Smallest density: [0.14936885])
# (Perc: 9.999999999999998, Obs: 2, Weight obs: [0.00571345], Smallest density: [0.14528388])
# (Perc: 9.999999999999998, Obs: 3, Weight obs: [0.0003979], Smallest density: [0.14071449])
# (Perc: 9.999999999999998, Obs: 4, Weight obs: [0.00689873], Smallest density: [0.14630278])
# (Perc: 9.999999999999998, Obs: 5, Weight obs: [0.00022225], Smallest density: [0.1405635])
# (Perc: 9.999999999999998, Obs: 6, Weight obs: [0.00300303], Smallest density: [0.14295393])
# (Perc: 9.999999999999998, Obs: 7, Weight obs: [0.00064889], Smallest density: [0.14093024])
# (Perc: 9.999999999999998, Obs: 8, Weight obs: [0.05808542], Smallest density: [0.19030426])
# (Perc: 9.999999999999998, Obs: 9, Weight obs: [0.00779897], Smallest density: [0.14707664])
# (Perc: 9.999999999999998, Obs: 10, Weight obs: [0.00263159], Smallest density: [0.14263463])
# (Perc: 9.999999999999998, Obs: 11, Weight obs: [0.00327737], Smallest density: [0.14318975])
# (Perc: 9.999999999999998, Obs: 12, Weight obs: [0.00343884], Smallest density: [0.14332856])
# (Perc: 9.999999999999998, Obs: 13, Weight obs: [0.00539652], Smallest density: [0.14501144])
# (Perc: 9.999999999999998, Obs: 14, Weight obs: [0.00061557], Smallest density: [0.1409016])
# (Perc: 9.999999999999998, Obs: 15, Weight obs: [0.04043172], Smallest density: [0.17512866])
# (Perc: 9.999999999999998, Obs: 16, Weight obs: [0.0010961], Smallest density: [0.14131468])
# (Perc: 9.999999999999998, Obs: 17, Weight obs: [0.04518543], Smallest density: [0.17921508])
# (Perc: 9.999999999999998, Obs: 18, Weight obs: [0.00447589], Smallest density: [0.14422004])
# (Perc: 9.999999999999998, Obs: 19, Weight obs: [0.00176849], Smallest density: [0.14189269])
# (Perc: 9.999999999999998, Obs: 20, Weight obs: [0.04043172], Smallest density: [0.17512866])
# (Perc: 9.999999999999998, Obs: 21, Weight obs: [0.00268745], Smallest density: [0.14268264])
# (Perc: 9.999999999999998, Obs: 22, Weight obs: [0.00700792], Smallest density: [0.14639664])
# (Perc: 9.999999999999998, Obs: 23, Weight obs: [0.02042613], Smallest density: [0.15793131])
# (Perc: 9.999999999999998, Obs: 24, Weight obs: [0.0012997], Smallest density: [0.1414897])
# (Perc: 9.999999999999998, Obs: 25, Weight obs: [0.00526966], Smallest density: [0.14490238])
# (Perc: 9.999999999999998, Obs: 26, Weight obs: [0.00700792], Smallest density: [0.14639664])
# (Perc: 9.999999999999998, Obs: 27, Weight obs: [0.0042601], Smallest density: [0.14403454])
# (Perc: 9.999999999999998, Obs: 28, Weight obs: [0.05808542], Smallest density: [0.19030426])
# (Perc: 9.999999999999998, Obs: 29, Weight obs: [0.00297353], Smallest density: [0.14292856])
# (Perc: 9.999999999999998, Obs: 30, Weight obs: [0.00557075], Smallest density: [0.14516121])
# (Perc: 9.999999999999998, Obs: 31, Weight obs: [0.00331317], Smallest density: [0.14322053])
# (Perc: 9.999999999999998, Obs: 32, Weight obs: [0.00591381], Smallest density: [0.14545611])
# (Perc: 9.999999999999998, Obs: 33, Weight obs: [0.00370345], Smallest density: [0.14355602])
# (Perc: 9.999999999999998, Obs: 34, Weight obs: [0.00410638], Smallest density: [0.1439024])
# (Perc: 9.999999999999998, Obs: 35, Weight obs: [0.00123365], Smallest density: [0.14143292])
# (Perc: 9.999999999999998, Obs: 36, Weight obs: [0.00161419], Smallest density: [0.14176004])
# (Perc: 9.999999999999998, Obs: 37, Weight obs: [0.00728901], Smallest density: [0.14663827])
# (Perc: 9.999999999999998, Obs: 38, Weight obs: [0.00321082], Smallest density: [0.14313255])
# (Perc: 9.999999999999998, Obs: 39, Weight obs: [0.0008026], Smallest density: [0.14106238])
# (Perc: 9.999999999999998, Obs: 40, Weight obs: [0.00966688], Smallest density: [0.14868236])
# (Perc: 9.999999999999998, Obs: 41, Weight obs: [0.02288418], Smallest density: [0.16004431])
# (Perc: 9.999999999999998, Obs: 42, Weight obs: [0.0002129], Smallest density: [0.14055546])
# (Perc: 9.999999999999998, Obs: 43, Weight obs: [0.00039062], Smallest density: [0.14070823])
# (Perc: 9.999999999999998, Obs: 44, Weight obs: [0.02204084], Smallest density: [0.15931935])
# (Perc: 9.999999999999998, Obs: 45, Weight obs: [0.00484574], Smallest density: [0.14453797])
# ...
# (Perc: 9.999999999999998, Obs: 105, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 9.999999999999998, Obs: 193, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 9.999999999999998, Obs: 195, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 9.999999999999998, Obs: 209, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 9.999999999999998, Obs: 236, Weight obs: [0.08048683], Smallest density: [0.1037463]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 24, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 10.0, Obs: 34, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 10.0, Obs: 41, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 10.0, Obs: 96, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 10.0, Obs: 105, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 10.0, Obs: 193, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 10.0, Obs: 195, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 10.0, Obs: 209, Weight obs: [0.08048683], Smallest density: [0.1037463])
# (Perc: 10.0, Obs: 236, Weight obs: [0.08048683], Smallest density: [0.1037463]); the corresponding values are set to y_min
#   warnings.warn(
#  94%|█████████▍| 944/1000 [03:49<00:13,  4.07it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 69, Weight obs: [0.06683476], Smallest density: [0.11512914])
# (Perc: 9.999999999999998, Obs: 75, Weight obs: [0.06683476], Smallest density: [0.11512914])
# (Perc: 9.999999999999998, Obs: 122, Weight obs: [0.06683476], Smallest density: [0.11512914])
# (Perc: 9.999999999999998, Obs: 130, Weight obs: [0.06683476], Smallest density: [0.11512914])
# (Perc: 9.999999999999998, Obs: 223, Weight obs: [0.06683476], Smallest density: [0.11512914]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 69, Weight obs: [0.06683476], Smallest density: [0.11512914])
# (Perc: 10.0, Obs: 75, Weight obs: [0.06683476], Smallest density: [0.11512914])
# (Perc: 10.0, Obs: 122, Weight obs: [0.06683476], Smallest density: [0.11512914])
# (Perc: 10.0, Obs: 130, Weight obs: [0.06683476], Smallest density: [0.11512914])
# (Perc: 10.0, Obs: 223, Weight obs: [0.06683476], Smallest density: [0.11512914]); the corresponding values are set to y_min
#   warnings.warn(
#  96%|█████████▌| 957/1000 [03:52<00:10,  4.19it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 15, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 9.999999999999998, Obs: 62, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 9.999999999999998, Obs: 138, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 9.999999999999998, Obs: 163, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 9.999999999999998, Obs: 174, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 9.999999999999998, Obs: 175, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 9.999999999999998, Obs: 182, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 9.999999999999998, Obs: 189, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 9.999999999999998, Obs: 242, Weight obs: [0.12248479], Smallest density: [0.13479551]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1272: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 15, Weight obs: [0.12248479])
# (Perc: 90.0, Obs: 62, Weight obs: [0.12248479])
# (Perc: 90.0, Obs: 138, Weight obs: [0.12248479])
# (Perc: 90.0, Obs: 163, Weight obs: [0.12248479])
# (Perc: 90.0, Obs: 174, Weight obs: [0.12248479])
# (Perc: 90.0, Obs: 175, Weight obs: [0.12248479])
# (Perc: 90.0, Obs: 182, Weight obs: [0.12248479])
# (Perc: 90.0, Obs: 189, Weight obs: [0.12248479])
# (Perc: 90.0, Obs: 242, Weight obs: [0.12248479]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 15, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 10.0, Obs: 62, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 10.0, Obs: 138, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 10.0, Obs: 163, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 10.0, Obs: 174, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 10.0, Obs: 175, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 10.0, Obs: 182, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 10.0, Obs: 189, Weight obs: [0.12248479], Smallest density: [0.13479551])
# (Perc: 10.0, Obs: 242, Weight obs: [0.12248479], Smallest density: [0.13479551]); the corresponding values are set to y_min
#   warnings.warn(
#  98%|█████████▊| 981/1000 [03:58<00:04,  4.27it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 0, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 14, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 26, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 44, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 56, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 87, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 110, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 125, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 133, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 138, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 143, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 169, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 195, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 201, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 212, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 9.999999999999998, Obs: 249, Weight obs: [0.10671671], Smallest density: [0.14415828]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1272: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 0, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 14, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 26, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 44, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 56, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 87, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 110, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 125, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 133, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 138, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 143, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 169, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 195, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 201, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 212, Weight obs: [0.10671671])
# (Perc: 90.0, Obs: 249, Weight obs: [0.10671671]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 0, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 14, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 26, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 44, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 56, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 87, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 110, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 125, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 133, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 138, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 143, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 169, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 195, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 201, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 212, Weight obs: [0.10671671], Smallest density: [0.14415828])
# (Perc: 10.0, Obs: 249, Weight obs: [0.10671671], Smallest density: [0.14415828]); the corresponding values are set to y_min
#   warnings.warn(
# 100%|█████████▉| 997/1000 [04:02<00:00,  4.25it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 1, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 11, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 16, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 17, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 27, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 32, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 36, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 37, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 43, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 51, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 58, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 61, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 73, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 80, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 86, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 100, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 105, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 127, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 141, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 152, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 175, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 9.999999999999998, Obs: 234, Weight obs: [0.13845704], Smallest density: [0.13879757]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1272: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 1, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 11, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 16, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 17, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 27, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 32, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 36, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 37, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 43, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 51, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 58, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 61, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 73, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 80, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 86, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 100, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 105, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 127, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 141, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 152, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 175, Weight obs: [0.13845704])
# (Perc: 90.0, Obs: 234, Weight obs: [0.13845704]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1196: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 1, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 11, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 16, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 17, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 27, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 32, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 36, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 37, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 43, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 51, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 58, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 61, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 73, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 80, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 86, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 100, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 105, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 127, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 141, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 152, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 175, Weight obs: [0.13845704], Smallest density: [0.13879757])
# (Perc: 10.0, Obs: 234, Weight obs: [0.13845704], Smallest density: [0.13879757]); the corresponding values are set to y_min
#   warnings.warn(
# 100%|██████████| 1000/1000 [04:03<00:00,  4.11it/s]

# %%
df_results_cps_no_shift_syn['Method'] = 'SCPS (no shift)'
df_results_cps_shift_not_weighted_syn['Method'] = 'SCPS (shift)'
df_results_cps_shift_weighted_syn['Method'] = 'WSCPS (shift)'
df_results_cps_no_shift_reduced_syn['Method'] = 'SCPS (no shift, reduced)'
df_results_cp_no_shift_syn['Method'] = 'CP (no shift)'
df_results_cp_shift_not_weighted_syn['Method'] = 'CP (shift)'
df_results_cp_shift_weighted_syn['Method'] = 'WCP (shift)'
df_results_cp_no_shift_reduced_syn['Method'] = 'CP (no shift, reduced)'

df_results_syn = pd.concat([df_results_cps_no_shift_syn, df_results_cps_shift_not_weighted_syn, df_results_cps_shift_weighted_syn,
                        df_results_cps_no_shift_reduced_syn,
                        df_results_cp_no_shift_syn, df_results_cp_shift_not_weighted_syn, df_results_cp_shift_weighted_syn,
                        df_results_cp_no_shift_reduced_syn])

df_results_syn["Coverage"] = 1 - df_results_syn["error"]

fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper left")
# set the color palette
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper left")
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="Coverage", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper left")
axs[0].vlines(0.8, 0, 250, color='r', linestyle='--')
axs[1].vlines(0.8, 0, 200, color='r', linestyle='--')
axs[2].vlines(0.8, 0, 175, color='r', linestyle='--')
plt.tight_layout()
plt.savefig("plots/coverage_synthetic.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
df_results_cps_no_shift_syn['Method'] = 'SCPS (no shift)'
df_results_cps_shift_not_weighted_syn['Method'] = 'SCPS (shift)'
df_results_cps_shift_weighted_syn['Method'] = 'WSCPS (shift)'
df_results_cps_no_shift_reduced_syn['Method'] = 'SCPS (no shift, reduced)'
df_results_cp_no_shift_syn['Method'] = 'CP (no shift)'
df_results_cp_shift_not_weighted_syn['Method'] = 'CP (shift)'
df_results_cp_shift_weighted_syn['Method'] = 'WCP (shift)'
df_results_cp_no_shift_reduced_syn['Method'] = 'CP (no shift, reduced)'

df_results_syn = pd.concat([df_results_cps_no_shift_syn, df_results_cps_shift_not_weighted_syn, df_results_cps_shift_weighted_syn,
                        df_results_cps_no_shift_reduced_syn,
                        df_results_cp_no_shift_syn, df_results_cp_shift_not_weighted_syn, df_results_cp_shift_weighted_syn,
                        df_results_cp_no_shift_reduced_syn])

df_results_syn["Coverage"] = 1 - df_results_syn["error"]

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharex=True, sharey=True)
bins = 20
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper left")
# set the color palette
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper left")
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="Coverage", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper left")
axs[0].vlines(0.8, 0, 250, color='r', linestyle='--')
axs[1].vlines(0.8, 0, 200, color='r', linestyle='--')
axs[2].vlines(0.8, 0, 175, color='r', linestyle='--')
plt.tight_layout()
plt.savefig("plots/coverage_synthetic_horizontal.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper right")
# set the color palette
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper right")
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="CRPS", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper right")
plt.tight_layout()
fig.savefig("plots/crps_synthetic.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import scipy.stats as ss
import scikit_posthocs as sp

df_results_cps = df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)', 'SCPS (shift)', 'WSCPS (shift)', 'SCPS (no shift, reduced)'])]

avg_rank = df_results_cps.groupby("sim_id")["CRPS"].rank(pct=True).groupby(df_results_cps.Method).mean()

ss.friedmanchisquare(*[df_results_cps[df_results_cps.Method == method].CRPS for method in df_results_cps.Method.unique()])

test_results = sp.posthoc_nemenyi_friedman(df_results_cps, melted=True, y_col="CRPS", block_col="sim_id", group_col="Method")

plt.figure(figsize=(10, 2))
# plt.title("Post-hoc Friedman-Nemenyi test for CRPS")
sp.critical_difference_diagram(avg_rank, test_results, color_palette={"SCPS (no shift)": sns.color_palette()[0],
                                                                      "SCPS (shift)": sns.color_palette()[1],
                                                                      "WSCPS (shift)": sns.color_palette()[2],
                                                                      "SCPS (no shift, reduced)": sns.color_palette()[3]})
plt.tight_layout()
plt.savefig("plots/nemenyi_synthetic.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %%
quantile_names = [f"coverage_q{q}" for q in np.arange(10, 100, 10)]

# Plot calibration curves
df_results_cps = df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)', 'SCPS (shift)', 'WSCPS (shift)', 'SCPS (no shift, reduced)'])]

## melt the data
df_results_cps_melted = pd.melt(df_results_cps, id_vars=["sim_id", "Method"], value_vars=quantile_names, value_name="Error", var_name="Quantile")
df_results_cps_melted["Quantile"] = df_results_cps_melted["Quantile"].str.replace("coverage_q", "").astype(int)

# %%
sns.pointplot(data=df_results_cps_melted, x="Quantile", y="Error", hue="Method", errorbar="sd")
sns.pointplot(y=np.arange(0.1, 1, 0.1), x=np.arange(10, 100, 10), color='black')
plt.savefig("plots/marginal_calibration_synthetic.pdf")

# %%
NSim = 10000 # very slow
# NSim = 1000 # faster, but more variability

list_p_values_cps = []
list_p_values_wcps = []
list_p_values_cps_no_shift = []
for i in tqdm(range(NSim)):
    X, y = synthetic_kang_schafer_2007()
    # Without covariate-shift
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
    X_train_prop, X_cal, y_train_prop, y_cal = train_test_split(X_train, y_train, test_size=0.25)

    shift_weights = np.array([-1, 0.5, -0.25, -0.1])
    shifted_likelihood_train_prop = np.exp(X_train_prop @ shift_weights)
    shifted_weights_train_prop = shifted_likelihood_train_prop / np.sum(shifted_likelihood_train_prop)
    shifted_likelihood_test = np.exp(X_test @ shift_weights)
    shifted_weights_test = shifted_likelihood_test / np.sum(shifted_likelihood_test)
    shifted_likelihood_cal =  np.exp(X_cal @ shift_weights)

    rf_cps = WrapRegressor(RandomForestRegressor(n_estimators=100, random_state=17))
    rf_cps.fit(X_train_prop, y_train_prop)
    rf_wcps = copy.deepcopy(rf_cps)


    idx_shift = weighted_sample(shifted_weights_test, frac=1/len(y_test))
    idx_no_shift = weighted_sample(np.ones(len(y_test))/ len(y_test), frac=1/len(y_test))

    rf_cps.calibrate(X_cal, y_cal, cps=True)
    rf_wcps.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=True)

    p_values_cps = rf_cps.predict_cps(X_test[idx_shift], y=y_test[idx_shift])
    p_values_cps_no_shift = rf_cps.predict_cps(X_test[idx_no_shift], y=y_test[idx_no_shift])
    p_values_wcps = rf_wcps.predict_cps(X_test[idx_shift], y=y_test[idx_shift], likelihood_ratios=shifted_likelihood_test[idx_shift])

    list_p_values_cps.append(p_values_cps)
    list_p_values_cps_no_shift.append(p_values_cps_no_shift)
    list_p_values_wcps.append(p_values_wcps)
# Out:
# 100%|██████████| 10000/10000 [42:45<00:00,  3.90it/s]

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
bins = 20
sns.histplot(np.concatenate(list_p_values_cps_no_shift), ax = axs[0], bins=bins,
             color=sns.color_palette()[0], label="CPS (no shift)")
sns.histplot(np.concatenate(list_p_values_cps), ax = axs[1], bins=bins,
             color=sns.color_palette()[1], label="CPS (shift)")
sns.histplot(np.concatenate(list_p_values_wcps), ax = axs[2], bins=bins,
             color=sns.color_palette()[2], label="WCPS (shift)")


axs[0].hlines(len(np.concatenate(list_p_values_cps_no_shift)) / bins, 0, 1, color='r', linestyle='--')
axs[1].hlines(len(np.concatenate(list_p_values_cps)) / bins, 0, 1, color='r', linestyle='--')
axs[2].hlines(len(np.concatenate(list_p_values_wcps)) / bins, 0, 1, color='r', linestyle='--')

axs[0].vlines(0, 0, len(np.concatenate(list_p_values_cps_no_shift)) / bins, color='r', linestyle='--')
axs[1].vlines(0, 0, len(np.concatenate(list_p_values_cps)) / bins, color='r', linestyle='--')
axs[2].vlines(0, 0, len(np.concatenate(list_p_values_wcps)) / bins, color='r', linestyle='--')

axs[0].vlines(1, 0, len(np.concatenate(list_p_values_cps_no_shift)) / bins, color='r', linestyle='--')
axs[1].vlines(1, 0, len(np.concatenate(list_p_values_cps)) / bins, color='r', linestyle='--')
axs[2].vlines(1, 0, len(np.concatenate(list_p_values_wcps)) / bins, color='r', linestyle='--')

axs[0].set_title("Distribution of SCPS(X,y)\n(no shift)")
axs[1].set_title("Distribution of SCPS(X,y)\n(shift)")
axs[2].set_title("Distribution of WSCPS(X,y)\n(shift)")

axs[0].set_xlabel("Q(X,y)")
axs[1].set_xlabel("Q(X,y)")
axs[2].set_xlabel("Q(X,y)")

plt.tight_layout()
fig.savefig("plots/prob_calibration_synthetic.pdf")
plt.show()

from scipy.stats import kstest

kstest_cps_no_shift = kstest(np.concatenate(list_p_values_cps_no_shift), 'uniform', args=(0, 1), method='exact')
kstest_cps_shift = kstest(np.concatenate(list_p_values_cps), 'uniform', args=(0, 1), method='exact')
kstest_wcps_shift = kstest(np.concatenate(list_p_values_wcps), 'uniform', args=(0, 1), method='exact')

print("Kolmogorov-Smirnov test for uniformity")
print(f"CPS (no shift): {kstest_cps_no_shift}")
print(f"CPS (shift): {kstest_cps_shift}")
print(f"WCPS (shift): {kstest_wcps_shift}")
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from scipy.stats import kstest

kstest_cps_no_shift = kstest(np.concatenate(list_p_values_cps_no_shift), 'uniform', args=(0, 1), method='exact')
kstest_cps_shift = kstest(np.concatenate(list_p_values_cps), 'uniform', args=(0, 1), method='exact')
kstest_wcps_shift = kstest(np.concatenate(list_p_values_wcps), 'uniform', args=(0, 1), method='exact')

print("Kolmogorov-Smirnov test for uniformity")
print(f"CPS (no shift): {kstest_cps_no_shift}")
print(f"CPS (shift): {kstest_cps_shift}")
print(f"WCPS (shift): {kstest_wcps_shift}")
# Out:
# Kolmogorov-Smirnov test for uniformity
# CPS (no shift): KstestResult(statistic=0.006861018679187675, pvalue=0.7315033176499793, statistic_location=0.15786101867918767, statistic_sign=-1)
# CPS (shift): KstestResult(statistic=0.08020612200294394, pvalue=2.100551757082166e-56, statistic_location=0.22289387799705604, statistic_sign=1)
# WCPS (shift): KstestResult(statistic=0.0070857714947389905, pvalue=0.6941351685194472, statistic_location=0.581614228505261, statistic_sign=1)

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
bins = 20

# Plotting histograms
sns.histplot(np.concatenate(list_p_values_cps_no_shift), ax=axs[0], bins=bins,
             color=sns.color_palette()[0], label="CPS (no shift)")
sns.histplot(np.concatenate(list_p_values_cps), ax=axs[1], bins=bins,
             color=sns.color_palette()[1], label="CPS (shift)")
sns.histplot(np.concatenate(list_p_values_wcps), ax=axs[2], bins=bins,
             color=sns.color_palette()[2], label="WCPS (shift)")

# Adding horizontal and vertical lines
for ax, data in zip(axs, [list_p_values_cps_no_shift, list_p_values_cps, list_p_values_wcps]):
    ax.hlines(len(np.concatenate(data)) / bins, 0, 1, color='r', linestyle='--')
    ax.vlines(0, 0, len(np.concatenate(data)) / bins, color='r', linestyle='--')
    ax.vlines(1, 0, len(np.concatenate(data)) / bins, color='r', linestyle='--')

# Setting titles and labels
titles = ["Distribution of SCPS(X,y)\n(no shift)",
          "Distribution of SCPS(X,y)\n(shift)",
          "Distribution of WSCPS(X,y)\n(shift)"]
for ax, title in zip(axs, titles):
    ax.set_title(title)
    ax.set_xlabel("Q(X,y)")

# Performing Kolmogorov-Smirnov tests
kstest_cps_no_shift = kstest(np.concatenate(list_p_values_cps_no_shift), 'uniform', args=(0, 1), method='exact')
kstest_cps_shift = kstest(np.concatenate(list_p_values_cps), 'uniform', args=(0, 1), method='exact')
kstest_wcps_shift = kstest(np.concatenate(list_p_values_wcps), 'uniform', args=(0, 1), method='exact')

# Adding test statistics and p-values to the plots with a heading
for ax, result in zip(axs, [kstest_cps_no_shift, kstest_cps_shift, kstest_wcps_shift]):
    text = r"$\it{Kolmogorov-Smirnov}$ $\it{test}$" + "\n"
    text += f"Statistic: {result.statistic:.4f}\n"
    text += f"p-value: {result.pvalue:.4f}"
    ax.text(0.95, 0.95, text,
            transform=ax.transAxes,
            verticalalignment='top',
            horizontalalignment='right',
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.tight_layout()
fig.savefig("plots/prob_calibration_synthetic.pdf")
plt.show()

# Printing Kolmogorov-Smirnov test results
print("Kolmogorov-Smirnov test for uniformity")
print(f"CPS (no shift): {kstest_cps_no_shift}")
print(f"CPS (shift): {kstest_cps_shift}")
print(f"WCPS (shift): {kstest_wcps_shift}")
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Kolmogorov-Smirnov test for uniformity
# CPS (no shift): KstestResult(statistic=0.006861018679187675, pvalue=0.7315033176499793, statistic_location=0.15786101867918767, statistic_sign=-1)
# CPS (shift): KstestResult(statistic=0.08020612200294394, pvalue=2.100551757082166e-56, statistic_location=0.22289387799705604, statistic_sign=1)
# WCPS (shift): KstestResult(statistic=0.0070857714947389905, pvalue=0.6941351685194472, statistic_location=0.581614228505261, statistic_sign=1)
