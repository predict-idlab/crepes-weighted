# %% [markdown]
# # Simulation Experiments

# %%
import sys
sys.path.append('..')
sys.path.append('../src')

import opendatasets as od
import tempfile
import zipfile
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor
from src.crepes_weighted import WrapRegressor
import copy
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def weighted_sample(weights, frac=0.5):
    return np.random.choice(range(len(weights)), size=int(len(weights) * frac), p=weights)

# %% [markdown]
# ## Airfoil Dataset

# %%
with tempfile.TemporaryDirectory() as temp_dir:
    od.download("https://archive.ics.uci.edu/static/public/291/airfoil+self+noise.zip",
                temp_dir)
    with zipfile.ZipFile(temp_dir + "/airfoil+self+noise.zip", 'r') as zip_ref:
        df = pd.read_csv(zip_ref.open('airfoil_self_noise.dat'), sep='\t', header=None)
        df.columns = ['Frequency', 'Angle', 'Chord', 'Velocity', 'Suction', 'Sound']
        df['Log_freq'] = np.log(df['Frequency'])
        df['Log_suct'] = np.log(df['Suction'])
        df = df.drop(columns=['Frequency', 'Suction'])
# Out:
# Downloading https://archive.ics.uci.edu/static/public/291/airfoil+self+noise.zip to /var/folders/fb/lzd0fz_d69v05khmd495_rwr0000gn/T/tmp5ni59766/airfoil+self+noise.zip
# 65536it [00:00, 81994.32it/s]

# %%
NSim = 1000
confidence = 0.8

for i in tqdm(range(NSim)):
    # Without covariate-shift
    X_train, X_test, y_train, y_test = train_test_split(df.drop('Sound', axis=1), df['Sound'], test_size=0.5)
    X_train_prop, X_cal, y_train_prop, y_cal = train_test_split(X_train, y_train, test_size=0.5)

    shifted_likelihood_train_prop = np.exp(X_train_prop[['Log_freq', 'Log_suct']].to_numpy() @ np.array([-1, 1]))
    shifted_weights_train_prop = shifted_likelihood_train_prop / np.sum(shifted_likelihood_train_prop)
    shifted_likelihood_test = np.exp(X_test[['Log_freq', 'Log_suct']].to_numpy() @ np.array([-1, 1]))
    shifted_weights_test = shifted_likelihood_test / np.sum(shifted_likelihood_test)
    shifted_likelihood_cal = np.exp(X_cal[['Log_freq', 'Log_suct']].to_numpy() @ np.array([-1, 1]))

    rf_cps = WrapRegressor(RandomForestRegressor(n_estimators=100, random_state=17))
    rf_cps.fit(X_train_prop, y_train_prop)
    rf_cp = copy.deepcopy(rf_cps)
    rf_cp.calibrate(X_cal, y_cal, cps=False)
    rf_cps.calibrate(X_cal, y_cal, cps=True)

    idx_no_shift = weighted_sample(np.ones(len(shifted_weights_test))/len(shifted_weights_test), frac=0.25)
    idx_shift = weighted_sample(shifted_weights_test, frac=0.25)

    n_reduced = np.sum(np.abs(shifted_likelihood_cal))**2 / np.sum(shifted_likelihood_cal**2)
    n = len(shifted_likelihood_cal)

    result_cps_no_shift = rf_cps.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift],
                                  confidence=confidence)
    result_cps_shift_not_weighted = rf_cps.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift],
                                            confidence=confidence)
    result_cp_no_shift = rf_cp.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift],
                                    confidence=confidence)
    result_cp_shift_not_weighted = rf_cp.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift],
                                              confidence=confidence)

    idx_cal_n_reduced = np.random.choice(range(n), size=int(n_reduced), replace=False)

    rf_cps_shift = copy.deepcopy(rf_cps)
    rf_cps_no_shift_reduced = copy.deepcopy(rf_cps)
    rf_cp_shift = copy.deepcopy(rf_cp)
    rf_cp_no_shift_reduced = copy.deepcopy(rf_cp)


    rf_cps_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=True)
    rf_cp_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=False)

    rf_cps_no_shift_reduced.calibrate(X_cal.iloc[idx_cal_n_reduced], y_cal.iloc[idx_cal_n_reduced], cps=True)
    rf_cp_no_shift_reduced.calibrate(X_cal.iloc[idx_cal_n_reduced], y_cal.iloc[idx_cal_n_reduced], cps=False)

    result_cps_shift_weighted = rf_cps_shift.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift].to_numpy(),
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cp_shift_weighted = rf_cp_shift.evaluate(X_test.iloc[idx_shift], y_test.iloc[idx_shift].to_numpy(),
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cps_no_shift_reduced = rf_cps_no_shift_reduced.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift].to_numpy(),
                    confidence=confidence)
    result_cp_no_shift_reduced = rf_cp_no_shift_reduced.evaluate(X_test.iloc[idx_no_shift], y_test.iloc[idx_no_shift].to_numpy(),
                    confidence=confidence)

    result_cps_shift_weighted["reduced_n"] = n_reduced
    result_cp_shift_weighted["reduced_n"] = n_reduced
    result_cps_no_shift_reduced["reduced_n"] = int(n_reduced)
    result_cp_no_shift_reduced["reduced_n"] = int(n_reduced)

    result_cps_no_shift["sim_id"] = i
    result_cps_shift_not_weighted["sim_id"] = i
    result_cps_shift_weighted["sim_id"] = i
    result_cp_no_shift["sim_id"] = i
    result_cp_shift_not_weighted["sim_id"] = i
    result_cp_shift_weighted["sim_id"] = i
    result_cps_no_shift_reduced["sim_id"] = i
    result_cp_no_shift_reduced["sim_id"] = i

    if i == 0:
        df_results_cps_no_shift = pd.DataFrame(result_cps_no_shift, index=[0])
        df_results_cps_shift_not_weighted = pd.DataFrame(result_cps_shift_not_weighted, index=[0])
        df_results_cps_shift_weighted = pd.DataFrame(result_cps_shift_weighted, index=[0])
        df_results_cp_no_shift = pd.DataFrame(result_cp_no_shift, index=[0])
        df_results_cp_shift_not_weighted = pd.DataFrame(result_cp_shift_not_weighted, index=[0])
        df_results_cp_shift_weighted = pd.DataFrame(result_cp_shift_weighted, index=[0])
        df_results_cps_no_shift_reduced = pd.DataFrame(result_cps_no_shift_reduced, index=[0])
        df_results_cp_no_shift_reduced = pd.DataFrame(result_cp_no_shift_reduced, index=[0])
    else:
        df_results_cps_no_shift = pd.concat([df_results_cps_no_shift, pd.DataFrame(result_cps_no_shift, index=[0])])
        df_results_cps_shift_not_weighted = pd.concat([df_results_cps_shift_not_weighted, pd.DataFrame(result_cps_shift_not_weighted, index=[0])])
        df_results_cps_shift_weighted = pd.concat([df_results_cps_shift_weighted, pd.DataFrame(result_cps_shift_weighted, index=[0])])
        df_results_cp_no_shift = pd.concat([df_results_cp_no_shift, pd.DataFrame(result_cp_no_shift, index=[0])])
        df_results_cp_shift_not_weighted = pd.concat([df_results_cp_shift_not_weighted, pd.DataFrame(result_cp_shift_not_weighted, index=[0])])
        df_results_cp_shift_weighted = pd.concat([df_results_cp_shift_weighted, pd.DataFrame(result_cp_shift_weighted, index=[0])])
        df_results_cps_no_shift_reduced = pd.concat([df_results_cps_no_shift_reduced, pd.DataFrame(result_cps_no_shift_reduced, index=[0])])
        df_results_cp_no_shift_reduced = pd.concat([df_results_cp_no_shift_reduced, pd.DataFrame(result_cp_no_shift_reduced, index=[0])])
# Out:
#  13%|█▎        | 127/1000 [00:21<02:25,  6.01it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 8, Weight obs: [0.0509649], Smallest density: [0.10729411])
# (Perc: 9.999999999999998, Obs: 35, Weight obs: [0.0509649], Smallest density: [0.10729411])
# (Perc: 9.999999999999998, Obs: 38, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 9.999999999999998, Obs: 43, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 9.999999999999998, Obs: 52, Weight obs: [0.0509649], Smallest density: [0.10729411])
# (Perc: 9.999999999999998, Obs: 57, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 9.999999999999998, Obs: 99, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 9.999999999999998, Obs: 109, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 9.999999999999998, Obs: 118, Weight obs: [0.0509649], Smallest density: [0.10729411])
# (Perc: 9.999999999999998, Obs: 124, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 9.999999999999998, Obs: 157, Weight obs: [0.0509649], Smallest density: [0.10729411]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 8, Weight obs: [0.0509649], Smallest density: [0.10729411])
# (Perc: 10.0, Obs: 35, Weight obs: [0.0509649], Smallest density: [0.10729411])
# (Perc: 10.0, Obs: 38, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 10.0, Obs: 43, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 10.0, Obs: 52, Weight obs: [0.0509649], Smallest density: [0.10729411])
# (Perc: 10.0, Obs: 57, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 10.0, Obs: 99, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 10.0, Obs: 109, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 10.0, Obs: 118, Weight obs: [0.0509649], Smallest density: [0.10729411])
# (Perc: 10.0, Obs: 124, Weight obs: [0.04679824], Smallest density: [0.10337476])
# (Perc: 10.0, Obs: 157, Weight obs: [0.0509649], Smallest density: [0.10729411]); the corresponding values are set to y_min
#   warnings.warn(
#  98%|█████████▊| 984/1000 [02:50<00:02,  5.89it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 11, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 9.999999999999998, Obs: 13, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 9.999999999999998, Obs: 29, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 9.999999999999998, Obs: 39, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 9.999999999999998, Obs: 104, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 9.999999999999998, Obs: 135, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 9.999999999999998, Obs: 147, Weight obs: [0.04809626], Smallest density: [0.10125491]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 11, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 10.0, Obs: 13, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 10.0, Obs: 29, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 10.0, Obs: 39, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 10.0, Obs: 104, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 10.0, Obs: 135, Weight obs: [0.04809626], Smallest density: [0.10125491])
# (Perc: 10.0, Obs: 147, Weight obs: [0.04809626], Smallest density: [0.10125491]); the corresponding values are set to y_min
#   warnings.warn(
# 100%|██████████| 1000/1000 [02:53<00:00,  5.77it/s]

# %%
df_results_cps_no_shift['Method'] = 'SCPS (no shift)'
df_results_cps_shift_not_weighted['Method'] = 'SCPS (shift)'
df_results_cps_shift_weighted['Method'] = 'WSCPS (shift)'
df_results_cps_no_shift_reduced['Method'] = 'SCPS (no shift, reduced)'
df_results_cp_no_shift['Method'] = 'CP (no shift)'
df_results_cp_shift_not_weighted['Method'] = 'CP (shift)'
df_results_cp_shift_weighted['Method'] = 'WCP (shift)'
df_results_cp_no_shift_reduced['Method'] = 'CP (no shift, reduced)'

df_results = pd.concat([df_results_cps_no_shift, df_results_cps_shift_not_weighted, df_results_cps_shift_weighted,
                        df_results_cps_no_shift_reduced,
                        df_results_cp_no_shift, df_results_cp_shift_not_weighted, df_results_cp_shift_weighted,
                        df_results_cp_no_shift_reduced])

df_results["Coverage"] = 1 - df_results["error"]

fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results[df_results["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper left")
# set the color palette
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper left")
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="Coverage", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper left")
axs[0].vlines(0.8, 0, 250, color='r', linestyle='--')
axs[1].vlines(0.8, 0, 160, color='r', linestyle='--')
axs[2].vlines(0.8, 0, 175, color='r', linestyle='--')
plt.tight_layout()
fig.savefig("plots/coverage_airfoil.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results[df_results["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper right")
# set the color palette
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper right")
sns.histplot(data=df_results[df_results["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="CRPS", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper right")
plt.tight_layout()
fig.savefig("plots/crps_airfoil.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import scipy.stats as ss
import scikit_posthocs as sp

df_results_cps = df_results[df_results["Method"].isin(['SCPS (no shift)', 'SCPS (shift)', 'WSCPS (shift)', 'SCPS (no shift, reduced)'])]

avg_rank = df_results_cps.groupby("sim_id")["CRPS"].rank(pct=True).groupby(df_results_cps.Method).mean()

ss.friedmanchisquare(*[df_results_cps[df_results_cps.Method == method].CRPS for method in df_results_cps.Method.unique()])

test_results = sp.posthoc_nemenyi_friedman(df_results_cps, melted=True, y_col="CRPS", block_col="sim_id", group_col="Method")


plt.figure(figsize=(10, 2))
# plt.title("Post-hoc Friedman-Nemenyi test for CRPS")
sp.critical_difference_diagram(avg_rank, test_results, color_palette={"SCPS (no shift)": sns.color_palette()[0],
                                                                      "SCPS (shift)": sns.color_palette()[1],
                                                                      "WSCPS (shift)": sns.color_palette()[2],
                                                                      "SCPS (no shift, reduced)": sns.color_palette()[3]})
plt.tight_layout()
plt.savefig("plots/nemenyi_airfoil.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %% [markdown]
# ## Synthetic Dataset (Kang and Schafer (2007))
# **Note: that this synthetic dataset is also used in Yang et al. 2022**

# %%
def synthetic_kang_schafer_2007(n=2000, weights=None):
    if weights is None:
        weights = np.ones(n)/n
    x1 = np.random.normal(size=n)
    x2 = np.random.normal(size=n)
    x3 = np.random.normal(size=n)
    x4 = np.random.normal(size=n)

    y = 210 + 27.4*x1 + 13.7*x2 + 13.7*x3 + 13.7*x4 + np.random.normal(size=n)

    return np.stack([x1, x2, x3, x4], axis=1), y

# %%
NSim = 1000
confidence = 0.8

for i in tqdm(range(NSim)):
    X, y = synthetic_kang_schafer_2007()
    # Without covariate-shift
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
    X_train_prop, X_cal, y_train_prop, y_cal = train_test_split(X_train, y_train, test_size=0.5)

    shift_weights = np.array([-1, 0.5, -0.25, -0.1])
    shifted_likelihood_train_prop = np.exp(X_train_prop @ shift_weights)
    shifted_weights_train_prop = shifted_likelihood_train_prop / np.sum(shifted_likelihood_train_prop)
    shifted_likelihood_test = np.exp(X_test @ shift_weights)
    shifted_weights_test = shifted_likelihood_test / np.sum(shifted_likelihood_test)
    shifted_likelihood_cal =  np.exp(X_cal @ shift_weights)

    rf_cps = WrapRegressor(RandomForestRegressor(n_estimators=100, random_state=17))
    rf_cps.fit(X_train_prop, y_train_prop)
    rf_cp = copy.deepcopy(rf_cps)
    rf_cp.calibrate(X_cal, y_cal, cps=False)
    rf_cps.calibrate(X_cal, y_cal, cps=True)

    idx_no_shift = weighted_sample(np.ones(len(shifted_weights_test))/len(shifted_weights_test), frac=0.25)
    idx_shift = weighted_sample(shifted_weights_test, frac=0.25)

    n_reduced = np.sum(np.abs(shifted_likelihood_cal))**2 / np.sum(shifted_likelihood_cal**2)
    n = len(shifted_likelihood_cal)

    result_cps_no_shift = rf_cps.evaluate(X_test[idx_no_shift], y_test[idx_no_shift],
                                  confidence=confidence)
    result_cps_shift_not_weighted = rf_cps.evaluate(X_test[idx_shift], y_test[idx_shift],
                                            confidence=confidence)
    result_cp_no_shift = rf_cp.evaluate(X_test[idx_no_shift], y_test[idx_no_shift],
                                    confidence=confidence)
    result_cp_shift_not_weighted = rf_cp.evaluate(X_test[idx_shift], y_test[idx_shift],
                                              confidence=confidence)

    idx_cal_n_reduced = np.random.choice(range(n), size=int(n_reduced), replace=False)

    rf_cps_shift = copy.deepcopy(rf_cps)
    rf_cps_no_shift_reduced = copy.deepcopy(rf_cps)
    rf_cp_shift = copy.deepcopy(rf_cp)
    rf_cp_no_shift_reduced = copy.deepcopy(rf_cp)


    rf_cps_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=True)
    rf_cp_shift.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=False)

    rf_cps_no_shift_reduced.calibrate(X_cal[idx_cal_n_reduced], y_cal[idx_cal_n_reduced], cps=True)
    rf_cp_no_shift_reduced.calibrate(X_cal[idx_cal_n_reduced], y_cal[idx_cal_n_reduced], cps=False)

    result_cps_shift_weighted = rf_cps_shift.evaluate(X_test[idx_shift], y_test[idx_shift],
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cp_shift_weighted = rf_cp_shift.evaluate(X_test[idx_shift], y_test[idx_shift],
                    likelihood_ratios=shifted_likelihood_test[idx_shift], confidence=confidence)
    result_cps_no_shift_reduced = rf_cps_no_shift_reduced.evaluate(X_test[idx_no_shift], y_test[idx_no_shift],
                    confidence=confidence)
    result_cp_no_shift_reduced = rf_cp_no_shift_reduced.evaluate(X_test[idx_no_shift], y_test[idx_no_shift],
                    confidence=confidence)

    result_cps_shift_weighted["reduced_n"] = n_reduced
    result_cp_shift_weighted["reduced_n"] = n_reduced
    result_cps_no_shift_reduced["reduced_n"] = int(n_reduced)
    result_cp_no_shift_reduced["reduced_n"] = int(n_reduced)

    result_cps_no_shift["sim_id"] = i
    result_cps_shift_not_weighted["sim_id"] = i
    result_cps_shift_weighted["sim_id"] = i
    result_cp_no_shift["sim_id"] = i
    result_cp_shift_not_weighted["sim_id"] = i
    result_cp_shift_weighted["sim_id"] = i
    result_cps_no_shift_reduced["sim_id"] = i
    result_cp_no_shift_reduced["sim_id"] = i

    if i == 0:
        df_results_cps_no_shift_syn = pd.DataFrame(result_cps_no_shift, index=[0])
        df_results_cps_shift_not_weighted_syn = pd.DataFrame(result_cps_shift_not_weighted, index=[0])
        df_results_cps_shift_weighted_syn = pd.DataFrame(result_cps_shift_weighted, index=[0])
        df_results_cp_no_shift_syn = pd.DataFrame(result_cp_no_shift, index=[0])
        df_results_cp_shift_not_weighted_syn = pd.DataFrame(result_cp_shift_not_weighted, index=[0])
        df_results_cp_shift_weighted_syn = pd.DataFrame(result_cp_shift_weighted, index=[0])
        df_results_cps_no_shift_reduced_syn = pd.DataFrame(result_cps_no_shift_reduced, index=[0])
        df_results_cp_no_shift_reduced_syn = pd.DataFrame(result_cp_no_shift_reduced, index=[0])
    else:
        df_results_cps_no_shift_syn = pd.concat([df_results_cps_no_shift_syn, pd.DataFrame(result_cps_no_shift, index=[0])])
        df_results_cps_shift_not_weighted_syn = pd.concat([df_results_cps_shift_not_weighted_syn, pd.DataFrame(result_cps_shift_not_weighted, index=[0])])
        df_results_cps_shift_weighted_syn = pd.concat([df_results_cps_shift_weighted_syn, pd.DataFrame(result_cps_shift_weighted, index=[0])])
        df_results_cp_no_shift_syn = pd.concat([df_results_cp_no_shift_syn, pd.DataFrame(result_cp_no_shift, index=[0])])
        df_results_cp_shift_not_weighted_syn = pd.concat([df_results_cp_shift_not_weighted_syn, pd.DataFrame(result_cp_shift_not_weighted, index=[0])])
        df_results_cp_shift_weighted_syn = pd.concat([df_results_cp_shift_weighted_syn, pd.DataFrame(result_cp_shift_weighted, index=[0])])
        df_results_cps_no_shift_reduced_syn = pd.concat([df_results_cps_no_shift_reduced_syn, pd.DataFrame(result_cps_no_shift_reduced, index=[0])])
        df_results_cp_no_shift_reduced_syn = pd.concat([df_results_cp_no_shift_reduced_syn, pd.DataFrame(result_cp_no_shift_reduced, index=[0])])
# Out:
#   0%|          | 3/1000 [00:00<03:53,  4.27it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 3, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 9.999999999999998, Obs: 8, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 9.999999999999998, Obs: 56, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 9.999999999999998, Obs: 84, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 9.999999999999998, Obs: 140, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 9.999999999999998, Obs: 200, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 9.999999999999998, Obs: 202, Weight obs: [0.06045172], Smallest density: [0.10091071]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 3, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 10.0, Obs: 8, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 10.0, Obs: 56, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 10.0, Obs: 84, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 10.0, Obs: 140, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 10.0, Obs: 200, Weight obs: [0.06045172], Smallest density: [0.10091071])
# (Perc: 10.0, Obs: 202, Weight obs: [0.06045172], Smallest density: [0.10091071]); the corresponding values are set to y_min
#   warnings.warn(
#   8%|▊         | 79/1000 [00:18<03:40,  4.17it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 0, Weight obs: [0.00079433], Smallest density: [0.17206736])
# (Perc: 9.999999999999998, Obs: 1, Weight obs: [0.00049513], Smallest density: [0.17181945])
# (Perc: 9.999999999999998, Obs: 2, Weight obs: [0.00115415], Smallest density: [0.17236551])
# (Perc: 9.999999999999998, Obs: 3, Weight obs: [0.00153558], Smallest density: [0.17268156])
# (Perc: 9.999999999999998, Obs: 4, Weight obs: [0.00373862], Smallest density: [0.17450697])
# (Perc: 9.999999999999998, Obs: 5, Weight obs: [0.01703216], Smallest density: [0.18552188])
# (Perc: 9.999999999999998, Obs: 6, Weight obs: [0.00673757], Smallest density: [0.17699187])
# (Perc: 9.999999999999998, Obs: 7, Weight obs: [0.01356438], Smallest density: [0.18264851])
# (Perc: 9.999999999999998, Obs: 8, Weight obs: [0.02356959], Smallest density: [0.19093873])
# (Perc: 9.999999999999998, Obs: 9, Weight obs: [0.00721163], Smallest density: [0.17738468])
# (Perc: 9.999999999999998, Obs: 10, Weight obs: [0.00523561], Smallest density: [0.17574737])
# (Perc: 9.999999999999998, Obs: 11, Weight obs: [0.00152353], Smallest density: [0.17267157])
# (Perc: 9.999999999999998, Obs: 12, Weight obs: [0.00799318], Smallest density: [0.17803226])
# (Perc: 9.999999999999998, Obs: 13, Weight obs: [0.00349305], Smallest density: [0.1743035])
# (Perc: 9.999999999999998, Obs: 14, Weight obs: [0.01018291], Smallest density: [0.17984665])
# (Perc: 9.999999999999998, Obs: 15, Weight obs: [0.00970604], Smallest density: [0.17945152])
# (Perc: 9.999999999999998, Obs: 16, Weight obs: [0.00420046], Smallest density: [0.17488965])
# (Perc: 9.999999999999998, Obs: 17, Weight obs: [0.00045564], Smallest density: [0.17178673])
# (Perc: 9.999999999999998, Obs: 18, Weight obs: [0.01018291], Smallest density: [0.17984665])
# (Perc: 9.999999999999998, Obs: 19, Weight obs: [0.01149856], Smallest density: [0.18093679])
# (Perc: 9.999999999999998, Obs: 20, Weight obs: [0.00483257], Smallest density: [0.17541341])
# (Perc: 9.999999999999998, Obs: 21, Weight obs: [0.00126334], Smallest density: [0.17245598])
# (Perc: 9.999999999999998, Obs: 22, Weight obs: [0.00758306], Smallest density: [0.17769244])
# (Perc: 9.999999999999998, Obs: 23, Weight obs: [0.00758306], Smallest density: [0.17769244])
# (Perc: 9.999999999999998, Obs: 24, Weight obs: [0.00424566], Smallest density: [0.1749271])
# (Perc: 9.999999999999998, Obs: 25, Weight obs: [0.00114736], Smallest density: [0.17235988])
# (Perc: 9.999999999999998, Obs: 26, Weight obs: [0.00292519], Smallest density: [0.17383297])
# (Perc: 9.999999999999998, Obs: 27, Weight obs: [0.00597176], Smallest density: [0.17635733])
# (Perc: 9.999999999999998, Obs: 28, Weight obs: [0.00470468], Smallest density: [0.17530744])
# (Perc: 9.999999999999998, Obs: 29, Weight obs: [0.00355123], Smallest density: [0.1743517])
# (Perc: 9.999999999999998, Obs: 30, Weight obs: [0.00310617], Smallest density: [0.17398293])
# (Perc: 9.999999999999998, Obs: 31, Weight obs: [0.00128392], Smallest density: [0.17247303])
# (Perc: 9.999999999999998, Obs: 32, Weight obs: [0.01765774], Smallest density: [0.18604023])
# (Perc: 9.999999999999998, Obs: 33, Weight obs: [0.00350289], Smallest density: [0.17431166])
# (Perc: 9.999999999999998, Obs: 34, Weight obs: [0.00177671], Smallest density: [0.17288135])
# (Perc: 9.999999999999998, Obs: 35, Weight obs: [0.01402133], Smallest density: [0.18302714])
# (Perc: 9.999999999999998, Obs: 36, Weight obs: [0.00320914], Smallest density: [0.17406825])
# (Perc: 9.999999999999998, Obs: 37, Weight obs: [0.02829378], Smallest density: [0.19485316])
# (Perc: 9.999999999999998, Obs: 38, Weight obs: [0.00114514], Smallest density: [0.17235804])
# (Perc: 9.999999999999998, Obs: 39, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 9.999999999999998, Obs: 40, Weight obs: [0.00393502], Smallest density: [0.17466971])
# (Perc: 9.999999999999998, Obs: 41, Weight obs: [0.00597176], Smallest density: [0.17635733])
# (Perc: 9.999999999999998, Obs: 42, Weight obs: [0.01765774], Smallest density: [0.18604023])
# (Perc: 9.999999999999998, Obs: 43, Weight obs: [0.0101024], Smallest density: [0.17977995])
# (Perc: 9.999999999999998, Obs: 44, Weight obs: [0.00055411], Smallest density: [0.17186832])
# (Perc: 9.999999999999998, Obs: 45, Weight obs: [0.00388834], Smallest density: [0.17463103])
# (Perc: 9.999999999999998, Obs: 46, Weight obs: [0.00564151], Smallest density: [0.17608369])
# (Perc: 9.999999999999998, Obs: 47, Weight obs: [0.00393127], Smallest density: [0.17466661])
# (Perc: 9.999999999999998, Obs: 48, Weight obs: [0.00526942], Smallest density: [0.17577538])
# (Perc: 9.999999999999998, Obs: 49, Weight obs: [0.00365274], Smallest density: [0.17443581])
# (Perc: 9.999999999999998, Obs: 50, Weight obs: [0.00160327], Smallest density: [0.17273765])
# (Perc: 9.999999999999998, Obs: 51, Weight obs: [0.01822941], Smallest density: [0.18651391])
# (Perc: 9.999999999999998, Obs: 52, Weight obs: [0.01121076], Smallest density: [0.18069832])
# (Perc: 9.999999999999998, Obs: 53, Weight obs: [0.00351], Smallest density: [0.17431754])
# (Perc: 9.999999999999998, Obs: 54, Weight obs: [0.00729757], Smallest density: [0.17745589])
# (Perc: 9.999999999999998, Obs: 55, Weight obs: [0.00035661], Smallest density: [0.17170467])
# (Perc: 9.999999999999998, Obs: 56, Weight obs: [0.00084425], Smallest density: [0.17210873])
# (Perc: 9.999999999999998, Obs: 57, Weight obs: [0.00328084], Smallest density: [0.17412766])
# (Perc: 9.999999999999998, Obs: 58, Weight obs: [0.00536805], Smallest density: [0.1758571])
# (Perc: 9.999999999999998, Obs: 59, Weight obs: [0.0051261], Smallest density: [0.17565663])
# (Perc: 9.999999999999998, Obs: 60, Weight obs: [0.00113986], Smallest density: [0.17235366])
# (Perc: 9.999999999999998, Obs: 61, Weight obs: [0.02184445], Smallest density: [0.1895093])
# (Perc: 9.999999999999998, Obs: 62, Weight obs: [0.00237883], Smallest density: [0.17338027])
# (Perc: 9.999999999999998, Obs: 63, Weight obs: [0.00458546], Smallest density: [0.17520866])
# (Perc: 9.999999999999998, Obs: 64, Weight obs: [0.00186991], Smallest density: [0.17295858])
# (Perc: 9.999999999999998, Obs: 65, Weight obs: [0.00376082], Smallest density: [0.17452537])
# (Perc: 9.999999999999998, Obs: 66, Weight obs: [0.00159249], Smallest density: [0.17272871])
# (Perc: 9.999999999999998, Obs: 67, Weight obs: [0.01392737], Smallest density: [0.18294928])
# (Perc: 9.999999999999998, Obs: 68, Weight obs: [0.00617669], Smallest density: [0.17652714])
# (Perc: 9.999999999999998, Obs: 69, Weight obs: [0.00067083], Smallest density: [0.17196503])
# (Perc: 9.999999999999998, Obs: 70, Weight obs: [0.01194552], Smallest density: [0.18130714])
# (Perc: 9.999999999999998, Obs: 71, Weight obs: [0.00608005], Smallest density: [0.17644706])
# (Perc: 9.999999999999998, Obs: 72, Weight obs: [0.00852532], Smallest density: [0.17847319])
# (Perc: 9.999999999999998, Obs: 73, Weight obs: [0.00036259], Smallest density: [0.17170963])
# (Perc: 9.999999999999998, Obs: 74, Weight obs: [0.01402133], Smallest density: [0.18302714])
# (Perc: 9.999999999999998, Obs: 75, Weight obs: [0.00078442], Smallest density: [0.17205915])
# (Perc: 9.999999999999998, Obs: 76, Weight obs: [0.01524437], Smallest density: [0.18404053])
# (Perc: 9.999999999999998, Obs: 77, Weight obs: [0.00477339], Smallest density: [0.17536437])
# (Perc: 9.999999999999998, Obs: 78, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 9.999999999999998, Obs: 79, Weight obs: [0.00250141], Smallest density: [0.17348184])
# (Perc: 9.999999999999998, Obs: 80, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 9.999999999999998, Obs: 81, Weight obs: [0.00970604], Smallest density: [0.17945152])
# (Perc: 9.999999999999998, Obs: 82, Weight obs: [0.00391846], Smallest density: [0.17465599])
# (Perc: 9.999999999999998, Obs: 83, Weight obs: [0.00556843], Smallest density: [0.17602314])
# (Perc: 9.999999999999998, Obs: 84, Weight obs: [0.00454983], Smallest density: [0.17517914])
# (Perc: 9.999999999999998, Obs: 85, Weight obs: [0.0005388], Smallest density: [0.17185564])
# (Perc: 9.999999999999998, Obs: 86, Weight obs: [0.00173726], Smallest density: [0.17284866])
# (Perc: 9.999999999999998, Obs: 87, Weight obs: [0.00134714], Smallest density: [0.17252542])
# (Perc: 9.999999999999998, Obs: 88, Weight obs: [0.00065674], Smallest density: [0.17195336])
# (Perc: 9.999999999999998, Obs: 89, Weight obs: [0.00433587], Smallest density: [0.17500185])
# (Perc: 9.999999999999998, Obs: 90, Weight obs: [0.00231253], Smallest density: [0.17332533])
# (Perc: 9.999999999999998, Obs: 91, Weight obs: [0.00086178], Smallest density: [0.17212326])
# (Perc: 9.999999999999998, Obs: 92, Weight obs: [0.00144034], Smallest density: [0.17260264])
# (Perc: 9.999999999999998, Obs: 93, Weight obs: [0.01417273], Smallest density: [0.18315258])
# (Perc: 9.999999999999998, Obs: 94, Weight obs: [0.00718425], Smallest density: [0.17736199])
# (Perc: 9.999999999999998, Obs: 95, Weight obs: [0.00217455], Smallest density: [0.17321101])
# (Perc: 9.999999999999998, Obs: 96, Weight obs: [0.00799318], Smallest density: [0.17803226])
# (Perc: 9.999999999999998, Obs: 97, Weight obs: [0.00238951], Smallest density: [0.17338911])
# (Perc: 9.999999999999998, Obs: 98, Weight obs: [0.00161631], Smallest density: [0.17274845])
# (Perc: 9.999999999999998, Obs: 99, Weight obs: [0.00173366], Smallest density: [0.17284569])
# (Perc: 9.999999999999998, Obs: 100, Weight obs: [0.00420046], Smallest density: [0.17488965])
# (Perc: 9.999999999999998, Obs: 101, Weight obs: [0.01493163], Smallest density: [0.1837814])
# (Perc: 9.999999999999998, Obs: 102, Weight obs: [0.00142237], Smallest density: [0.17258775])
# (Perc: 9.999999999999998, Obs: 103, Weight obs: [0.00093687], Smallest density: [0.17218547])
# (Perc: 9.999999999999998, Obs: 104, Weight obs: [0.00084807], Smallest density: [0.17211189])
# (Perc: 9.999999999999998, Obs: 105, Weight obs: [0.0017141], Smallest density: [0.17282947])
# (Perc: 9.999999999999998, Obs: 106, Weight obs: [0.00084106], Smallest density: [0.17210608])
# (Perc: 9.999999999999998, Obs: 107, Weight obs: [0.0047749], Smallest density: [0.17536562])
# (Perc: 9.999999999999998, Obs: 108, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 9.999999999999998, Obs: 109, Weight obs: [0.0031309], Smallest density: [0.17400342])
# (Perc: 9.999999999999998, Obs: 110, Weight obs: [0.00448978], Smallest density: [0.17512938])
# (Perc: 9.999999999999998, Obs: 111, Weight obs: [0.00135188], Smallest density: [0.17252935])
# (Perc: 9.999999999999998, Obs: 112, Weight obs: [0.00296807], Smallest density: [0.1738685])
# (Perc: 9.999999999999998, Obs: 113, Weight obs: [0.00707143], Smallest density: [0.17726851])
# (Perc: 9.999999999999998, Obs: 114, Weight obs: [0.00328084], Smallest density: [0.17412766])
# (Perc: 9.999999999999998, Obs: 115, Weight obs: [0.00124935], Smallest density: [0.17244439])
# (Perc: 9.999999999999998, Obs: 116, Weight obs: [0.00873807], Smallest density: [0.17864948])
# (Perc: 9.999999999999998, Obs: 117, Weight obs: [0.0065108], Smallest density: [0.17680398])
# (Perc: 9.999999999999998, Obs: 118, Weight obs: [0.00040832], Smallest density: [0.17174752])
# (Perc: 9.999999999999998, Obs: 119, Weight obs: [0.00474511], Smallest density: [0.17534094])
# (Perc: 9.999999999999998, Obs: 120, Weight obs: [0.00978554], Smallest density: [0.1795174])
# (Perc: 9.999999999999998, Obs: 121, Weight obs: [0.00617669], Smallest density: [0.17652714])
# (Perc: 9.999999999999998, Obs: 122, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 9.999999999999998, Obs: 123, Weight obs: [0.00370971], Smallest density: [0.17448302])
# (Perc: 9.999999999999998, Obs: 124, Weight obs: [0.00414514], Smallest density: [0.17484382])
# (Perc: 9.999999999999998, Obs: 125, Weight obs: [0.00538949], Smallest density: [0.17587487])
# (Perc: 9.999999999999998, Obs: 126, Weight obs: [0.00231005], Smallest density: [0.17332328])
# (Perc: 9.999999999999998, Obs: 127, Weight obs: [0.00236415], Smallest density: [0.1733681])
# (Perc: 9.999999999999998, Obs: 128, Weight obs: [0.00097997], Smallest density: [0.17222118])
# (Perc: 9.999999999999998, Obs: 129, Weight obs: [0.0087216], Smallest density: [0.17863583])
# (Perc: 9.999999999999998, Obs: 130, Weight obs: [0.00193951], Smallest density: [0.17301625])
# (Perc: 9.999999999999998, Obs: 131, Weight obs: [0.0030939], Smallest density: [0.17397276])
# (Perc: 9.999999999999998, Obs: 132, Weight obs: [0.01402133], Smallest density: [0.18302714])
# (Perc: 9.999999999999998, Obs: 133, Weight obs: [0.00445141], Smallest density: [0.17509758])
# (Perc: 9.999999999999998, Obs: 134, Weight obs: [0.00102228], Smallest density: [0.17225624])
# (Perc: 9.999999999999998, Obs: 135, Weight obs: [0.00228793], Smallest density: [0.17330494])
# (Perc: 9.999999999999998, Obs: 136, Weight obs: [0.00105446], Smallest density: [0.1722829])
# (Perc: 9.999999999999998, Obs: 137, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 9.999999999999998, Obs: 138, Weight obs: [0.02356959], Smallest density: [0.19093873])
# (Perc: 9.999999999999998, Obs: 139, Weight obs: [0.02356959], Smallest density: [0.19093873])
# (Perc: 9.999999999999998, Obs: 140, Weight obs: [0.00596217], Smallest density: [0.17634939])
# (Perc: 9.999999999999998, Obs: 141, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 9.999999999999998, Obs: 142, Weight obs: [0.00278005], Smallest density: [0.17371271])
# (Perc: 9.999999999999998, Obs: 143, Weight obs: [0.00779593], Smallest density: [0.17786882])
# (Perc: 9.999999999999998, Obs: 144, Weight obs: [0.00193951], Smallest density: [0.17301625])
# (Perc: 9.999999999999998, Obs: 145, Weight obs: [0.01493163], Smallest density: [0.1837814])
# (Perc: 9.999999999999998, Obs: 146, Weight obs: [0.00571718], Smallest density: [0.1761464])
# (Perc: 9.999999999999998, Obs: 147, Weight obs: [0.00941405], Smallest density: [0.17920958])
# (Perc: 9.999999999999998, Obs: 148, Weight obs: [0.0005388], Smallest density: [0.17185564])
# (Perc: 9.999999999999998, Obs: 149, Weight obs: [0.00058091], Smallest density: [0.17189053])
# (Perc: 9.999999999999998, Obs: 150, Weight obs: [0.00314674], Smallest density: [0.17401655])
# (Perc: 9.999999999999998, Obs: 151, Weight obs: [0.01367956], Smallest density: [0.18274395])
# (Perc: 9.999999999999998, Obs: 152, Weight obs: [0.00186991], Smallest density: [0.17295858])
# (Perc: 9.999999999999998, Obs: 153, Weight obs: [0.00108753], Smallest density: [0.17231031])
# (Perc: 9.999999999999998, Obs: 154, Weight obs: [0.00405502], Smallest density: [0.17476914])
# (Perc: 9.999999999999998, Obs: 155, Weight obs: [0.02829378], Smallest density: [0.19485316])
# (Perc: 9.999999999999998, Obs: 156, Weight obs: [0.00721163], Smallest density: [0.17738468])
# (Perc: 9.999999999999998, Obs: 157, Weight obs: [0.01524437], Smallest density: [0.18404053])
# (Perc: 9.999999999999998, Obs: 158, Weight obs: [0.00029546], Smallest density: [0.171654])
# (Perc: 9.999999999999998, Obs: 159, Weight obs: [0.00296174], Smallest density: [0.17386326])
# (Perc: 9.999999999999998, Obs: 160, Weight obs: [0.00722341], Smallest density: [0.17739444])
# (Perc: 9.999999999999998, Obs: 161, Weight obs: [0.00090629], Smallest density: [0.17216013])
# (Perc: 9.999999999999998, Obs: 162, Weight obs: [0.00213816], Smallest density: [0.17318085])
# (Perc: 9.999999999999998, Obs: 163, Weight obs: [0.01466914], Smallest density: [0.18356391])
# (Perc: 9.999999999999998, Obs: 164, Weight obs: [0.00833762], Smallest density: [0.17831766])
# (Perc: 9.999999999999998, Obs: 165, Weight obs: [0.00617669], Smallest density: [0.17652714])
# (Perc: 9.999999999999998, Obs: 166, Weight obs: [0.00523561], Smallest density: [0.17574737])
# (Perc: 9.999999999999998, Obs: 167, Weight obs: [0.00974612], Smallest density: [0.17948474])
# (Perc: 9.999999999999998, Obs: 168, Weight obs: [0.00554992], Smallest density: [0.1760078])
# (Perc: 9.999999999999998, Obs: 169, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 9.999999999999998, Obs: 170, Weight obs: [0.02829378], Smallest density: [0.19485316])
# (Perc: 9.999999999999998, Obs: 171, Weight obs: [0.00758306], Smallest density: [0.17769244])
# (Perc: 9.999999999999998, Obs: 172, Weight obs: [0.01077936], Smallest density: [0.18034087])
# (Perc: 9.999999999999998, Obs: 173, Weight obs: [0.00130458], Smallest density: [0.17249016])
# (Perc: 9.999999999999998, Obs: 174, Weight obs: [0.00125037], Smallest density: [0.17244524])
# (Perc: 9.999999999999998, Obs: 175, Weight obs: [0.00852532], Smallest density: [0.17847319])
# (Perc: 9.999999999999998, Obs: 176, Weight obs: [0.00089921], Smallest density: [0.17215427])
# (Perc: 9.999999999999998, Obs: 177, Weight obs: [0.00159851], Smallest density: [0.1727337])
# (Perc: 9.999999999999998, Obs: 178, Weight obs: [0.00106364], Smallest density: [0.17229051])
# (Perc: 9.999999999999998, Obs: 179, Weight obs: [0.00313952], Smallest density: [0.17401057])
# (Perc: 9.999999999999998, Obs: 180, Weight obs: [0.00501447], Smallest density: [0.17556413])
# (Perc: 9.999999999999998, Obs: 181, Weight obs: [0.01466914], Smallest density: [0.18356391])
# (Perc: 9.999999999999998, Obs: 182, Weight obs: [0.00089921], Smallest density: [0.17215427])
# (Perc: 9.999999999999998, Obs: 183, Weight obs: [0.00159851], Smallest density: [0.1727337])
# (Perc: 9.999999999999998, Obs: 184, Weight obs: [0.00523561], Smallest density: [0.17574737])
# (Perc: 9.999999999999998, Obs: 185, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 9.999999999999998, Obs: 186, Weight obs: [0.00359659], Smallest density: [0.17438929])
# (Perc: 9.999999999999998, Obs: 187, Weight obs: [0.00729757], Smallest density: [0.17745589])
# (Perc: 9.999999999999998, Obs: 188, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 9.999999999999998, Obs: 189, Weight obs: [0.00454983], Smallest density: [0.17517914])
# (Perc: 9.999999999999998, Obs: 190, Weight obs: [0.00366627], Smallest density: [0.17444702])
# (Perc: 9.999999999999998, Obs: 191, Weight obs: [0.00722341], Smallest density: [0.17739444])
# (Perc: 9.999999999999998, Obs: 192, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 9.999999999999998, Obs: 193, Weight obs: [0.00078037], Smallest density: [0.1720558])
# (Perc: 9.999999999999998, Obs: 194, Weight obs: [0.0022647], Smallest density: [0.1732857])
# (Perc: 9.999999999999998, Obs: 195, Weight obs: [0.00200997], Smallest density: [0.17307464])
# (Perc: 9.999999999999998, Obs: 196, Weight obs: [0.01121076], Smallest density: [0.18069832])
# (Perc: 9.999999999999998, Obs: 197, Weight obs: [0.00393127], Smallest density: [0.17466661])
# (Perc: 9.999999999999998, Obs: 198, Weight obs: [0.00273255], Smallest density: [0.17367336])
# (Perc: 9.999999999999998, Obs: 199, Weight obs: [0.00222128], Smallest density: [0.17324972])
# (Perc: 9.999999999999998, Obs: 200, Weight obs: [0.01392737], Smallest density: [0.18294928])
# (Perc: 9.999999999999998, Obs: 201, Weight obs: [0.00451434], Smallest density: [0.17514973])
# (Perc: 9.999999999999998, Obs: 202, Weight obs: [0.00188488], Smallest density: [0.17297098])
# (Perc: 9.999999999999998, Obs: 203, Weight obs: [0.00564151], Smallest density: [0.17608369])
# (Perc: 9.999999999999998, Obs: 204, Weight obs: [0.01046507], Smallest density: [0.18008045])
# (Perc: 9.999999999999998, Obs: 205, Weight obs: [0.00203427], Smallest density: [0.17309477])
# (Perc: 9.999999999999998, Obs: 206, Weight obs: [0.00068462], Smallest density: [0.17197646])
# (Perc: 9.999999999999998, Obs: 207, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 9.999999999999998, Obs: 208, Weight obs: [0.00941405], Smallest density: [0.17920958])
# (Perc: 9.999999999999998, Obs: 209, Weight obs: [0.00495462], Smallest density: [0.17551454])
# (Perc: 9.999999999999998, Obs: 210, Weight obs: [0.00909172], Smallest density: [0.17894251])
# (Perc: 9.999999999999998, Obs: 211, Weight obs: [0.01149856], Smallest density: [0.18093679])
# (Perc: 9.999999999999998, Obs: 212, Weight obs: [0.00526057], Smallest density: [0.17576805])
# (Perc: 9.999999999999998, Obs: 213, Weight obs: [0.00196654], Smallest density: [0.17303864])
# (Perc: 9.999999999999998, Obs: 214, Weight obs: [0.02184445], Smallest density: [0.1895093])
# (Perc: 9.999999999999998, Obs: 215, Weight obs: [0.00136675], Smallest density: [0.17254166])
# (Perc: 9.999999999999998, Obs: 216, Weight obs: [0.00648117], Smallest density: [0.17677943])
# (Perc: 9.999999999999998, Obs: 217, Weight obs: [0.0020545], Smallest density: [0.17311153])
# (Perc: 9.999999999999998, Obs: 218, Weight obs: [0.00070774], Smallest density: [0.17199562])
# (Perc: 9.999999999999998, Obs: 219, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 9.999999999999998, Obs: 220, Weight obs: [0.0047749], Smallest density: [0.17536562])
# (Perc: 9.999999999999998, Obs: 221, Weight obs: [0.00228129], Smallest density: [0.17329944])
# (Perc: 9.999999999999998, Obs: 222, Weight obs: [0.00941405], Smallest density: [0.17920958])
# (Perc: 9.999999999999998, Obs: 223, Weight obs: [0.00376082], Smallest density: [0.17452537])
# (Perc: 9.999999999999998, Obs: 224, Weight obs: [0.00648117], Smallest density: [0.17677943])
# (Perc: 9.999999999999998, Obs: 225, Weight obs: [0.0013915], Smallest density: [0.17256218])
# (Perc: 9.999999999999998, Obs: 226, Weight obs: [0.00597176], Smallest density: [0.17635733])
# (Perc: 9.999999999999998, Obs: 227, Weight obs: [0.00718425], Smallest density: [0.17736199])
# (Perc: 9.999999999999998, Obs: 228, Weight obs: [0.00107251], Smallest density: [0.17229786])
# (Perc: 9.999999999999998, Obs: 229, Weight obs: [0.00128392], Smallest density: [0.17247303])
# (Perc: 9.999999999999998, Obs: 230, Weight obs: [0.0020545], Smallest density: [0.17311153])
# (Perc: 9.999999999999998, Obs: 231, Weight obs: [0.00087052], Smallest density: [0.1721305])
# (Perc: 9.999999999999998, Obs: 232, Weight obs: [0.01356438], Smallest density: [0.18264851])
# (Perc: 9.999999999999998, Obs: 233, Weight obs: [0.01524437], Smallest density: [0.18404053])
# (Perc: 9.999999999999998, Obs: 234, Weight obs: [0.00474511], Smallest density: [0.17534094])
# (Perc: 9.999999999999998, Obs: 235, Weight obs: [0.00164696], Smallest density: [0.17277385])
# (Perc: 9.999999999999998, Obs: 236, Weight obs: [0.00139372], Smallest density: [0.17256402])
# (Perc: 9.999999999999998, Obs: 237, Weight obs: [0.00526942], Smallest density: [0.17577538])
# (Perc: 9.999999999999998, Obs: 238, Weight obs: [0.00336118], Smallest density: [0.17419423])
# (Perc: 9.999999999999998, Obs: 239, Weight obs: [0.00114716], Smallest density: [0.17235972])
# (Perc: 9.999999999999998, Obs: 240, Weight obs: [0.01356438], Smallest density: [0.18264851])
# (Perc: 9.999999999999998, Obs: 241, Weight obs: [0.00722341], Smallest density: [0.17739444])
# (Perc: 9.999999999999998, Obs: 242, Weight obs: [0.00060336], Smallest density: [0.17190913])
# (Perc: 9.999999999999998, Obs: 243, Weight obs: [0.00125739], Smallest density: [0.17245105])
# (Perc: 9.999999999999998, Obs: 244, Weight obs: [0.00371466], Smallest density: [0.17448712])
# (Perc: 9.999999999999998, Obs: 245, Weight obs: [0.00238951], Smallest density: [0.17338911])
# (Perc: 9.999999999999998, Obs: 246, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 9.999999999999998, Obs: 247, Weight obs: [0.0025476], Smallest density: [0.17352011])
# (Perc: 9.999999999999998, Obs: 248, Weight obs: [0.00089544], Smallest density: [0.17215115])
# (Perc: 9.999999999999998, Obs: 249, Weight obs: [0.00677199], Smallest density: [0.17702039]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 0, Weight obs: [0.00079433], Smallest density: [0.17206736])
# (Perc: 10.0, Obs: 1, Weight obs: [0.00049513], Smallest density: [0.17181945])
# (Perc: 10.0, Obs: 2, Weight obs: [0.00115415], Smallest density: [0.17236551])
# (Perc: 10.0, Obs: 3, Weight obs: [0.00153558], Smallest density: [0.17268156])
# (Perc: 10.0, Obs: 4, Weight obs: [0.00373862], Smallest density: [0.17450697])
# (Perc: 10.0, Obs: 5, Weight obs: [0.01703216], Smallest density: [0.18552188])
# (Perc: 10.0, Obs: 6, Weight obs: [0.00673757], Smallest density: [0.17699187])
# (Perc: 10.0, Obs: 7, Weight obs: [0.01356438], Smallest density: [0.18264851])
# (Perc: 10.0, Obs: 8, Weight obs: [0.02356959], Smallest density: [0.19093873])
# (Perc: 10.0, Obs: 9, Weight obs: [0.00721163], Smallest density: [0.17738468])
# (Perc: 10.0, Obs: 10, Weight obs: [0.00523561], Smallest density: [0.17574737])
# (Perc: 10.0, Obs: 11, Weight obs: [0.00152353], Smallest density: [0.17267157])
# (Perc: 10.0, Obs: 12, Weight obs: [0.00799318], Smallest density: [0.17803226])
# (Perc: 10.0, Obs: 13, Weight obs: [0.00349305], Smallest density: [0.1743035])
# (Perc: 10.0, Obs: 14, Weight obs: [0.01018291], Smallest density: [0.17984665])
# (Perc: 10.0, Obs: 15, Weight obs: [0.00970604], Smallest density: [0.17945152])
# (Perc: 10.0, Obs: 16, Weight obs: [0.00420046], Smallest density: [0.17488965])
# (Perc: 10.0, Obs: 17, Weight obs: [0.00045564], Smallest density: [0.17178673])
# (Perc: 10.0, Obs: 18, Weight obs: [0.01018291], Smallest density: [0.17984665])
# (Perc: 10.0, Obs: 19, Weight obs: [0.01149856], Smallest density: [0.18093679])
# (Perc: 10.0, Obs: 20, Weight obs: [0.00483257], Smallest density: [0.17541341])
# (Perc: 10.0, Obs: 21, Weight obs: [0.00126334], Smallest density: [0.17245598])
# (Perc: 10.0, Obs: 22, Weight obs: [0.00758306], Smallest density: [0.17769244])
# (Perc: 10.0, Obs: 23, Weight obs: [0.00758306], Smallest density: [0.17769244])
# (Perc: 10.0, Obs: 24, Weight obs: [0.00424566], Smallest density: [0.1749271])
# (Perc: 10.0, Obs: 25, Weight obs: [0.00114736], Smallest density: [0.17235988])
# (Perc: 10.0, Obs: 26, Weight obs: [0.00292519], Smallest density: [0.17383297])
# (Perc: 10.0, Obs: 27, Weight obs: [0.00597176], Smallest density: [0.17635733])
# (Perc: 10.0, Obs: 28, Weight obs: [0.00470468], Smallest density: [0.17530744])
# (Perc: 10.0, Obs: 29, Weight obs: [0.00355123], Smallest density: [0.1743517])
# (Perc: 10.0, Obs: 30, Weight obs: [0.00310617], Smallest density: [0.17398293])
# (Perc: 10.0, Obs: 31, Weight obs: [0.00128392], Smallest density: [0.17247303])
# (Perc: 10.0, Obs: 32, Weight obs: [0.01765774], Smallest density: [0.18604023])
# (Perc: 10.0, Obs: 33, Weight obs: [0.00350289], Smallest density: [0.17431166])
# (Perc: 10.0, Obs: 34, Weight obs: [0.00177671], Smallest density: [0.17288135])
# (Perc: 10.0, Obs: 35, Weight obs: [0.01402133], Smallest density: [0.18302714])
# (Perc: 10.0, Obs: 36, Weight obs: [0.00320914], Smallest density: [0.17406825])
# (Perc: 10.0, Obs: 37, Weight obs: [0.02829378], Smallest density: [0.19485316])
# (Perc: 10.0, Obs: 38, Weight obs: [0.00114514], Smallest density: [0.17235804])
# (Perc: 10.0, Obs: 39, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 20.0, Obs: 39, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 10.0, Obs: 40, Weight obs: [0.00393502], Smallest density: [0.17466971])
# (Perc: 10.0, Obs: 41, Weight obs: [0.00597176], Smallest density: [0.17635733])
# (Perc: 10.0, Obs: 42, Weight obs: [0.01765774], Smallest density: [0.18604023])
# (Perc: 10.0, Obs: 43, Weight obs: [0.0101024], Smallest density: [0.17977995])
# (Perc: 10.0, Obs: 44, Weight obs: [0.00055411], Smallest density: [0.17186832])
# (Perc: 10.0, Obs: 45, Weight obs: [0.00388834], Smallest density: [0.17463103])
# (Perc: 10.0, Obs: 46, Weight obs: [0.00564151], Smallest density: [0.17608369])
# (Perc: 10.0, Obs: 47, Weight obs: [0.00393127], Smallest density: [0.17466661])
# (Perc: 10.0, Obs: 48, Weight obs: [0.00526942], Smallest density: [0.17577538])
# (Perc: 10.0, Obs: 49, Weight obs: [0.00365274], Smallest density: [0.17443581])
# (Perc: 10.0, Obs: 50, Weight obs: [0.00160327], Smallest density: [0.17273765])
# (Perc: 10.0, Obs: 51, Weight obs: [0.01822941], Smallest density: [0.18651391])
# (Perc: 10.0, Obs: 52, Weight obs: [0.01121076], Smallest density: [0.18069832])
# (Perc: 10.0, Obs: 53, Weight obs: [0.00351], Smallest density: [0.17431754])
# (Perc: 10.0, Obs: 54, Weight obs: [0.00729757], Smallest density: [0.17745589])
# (Perc: 10.0, Obs: 55, Weight obs: [0.00035661], Smallest density: [0.17170467])
# (Perc: 10.0, Obs: 56, Weight obs: [0.00084425], Smallest density: [0.17210873])
# (Perc: 10.0, Obs: 57, Weight obs: [0.00328084], Smallest density: [0.17412766])
# (Perc: 10.0, Obs: 58, Weight obs: [0.00536805], Smallest density: [0.1758571])
# (Perc: 10.0, Obs: 59, Weight obs: [0.0051261], Smallest density: [0.17565663])
# (Perc: 10.0, Obs: 60, Weight obs: [0.00113986], Smallest density: [0.17235366])
# (Perc: 10.0, Obs: 61, Weight obs: [0.02184445], Smallest density: [0.1895093])
# (Perc: 10.0, Obs: 62, Weight obs: [0.00237883], Smallest density: [0.17338027])
# (Perc: 10.0, Obs: 63, Weight obs: [0.00458546], Smallest density: [0.17520866])
# (Perc: 10.0, Obs: 64, Weight obs: [0.00186991], Smallest density: [0.17295858])
# (Perc: 10.0, Obs: 65, Weight obs: [0.00376082], Smallest density: [0.17452537])
# (Perc: 10.0, Obs: 66, Weight obs: [0.00159249], Smallest density: [0.17272871])
# (Perc: 10.0, Obs: 67, Weight obs: [0.01392737], Smallest density: [0.18294928])
# (Perc: 10.0, Obs: 68, Weight obs: [0.00617669], Smallest density: [0.17652714])
# (Perc: 10.0, Obs: 69, Weight obs: [0.00067083], Smallest density: [0.17196503])
# (Perc: 10.0, Obs: 70, Weight obs: [0.01194552], Smallest density: [0.18130714])
# (Perc: 10.0, Obs: 71, Weight obs: [0.00608005], Smallest density: [0.17644706])
# (Perc: 10.0, Obs: 72, Weight obs: [0.00852532], Smallest density: [0.17847319])
# (Perc: 10.0, Obs: 73, Weight obs: [0.00036259], Smallest density: [0.17170963])
# (Perc: 10.0, Obs: 74, Weight obs: [0.01402133], Smallest density: [0.18302714])
# (Perc: 10.0, Obs: 75, Weight obs: [0.00078442], Smallest density: [0.17205915])
# (Perc: 10.0, Obs: 76, Weight obs: [0.01524437], Smallest density: [0.18404053])
# (Perc: 10.0, Obs: 77, Weight obs: [0.00477339], Smallest density: [0.17536437])
# (Perc: 10.0, Obs: 78, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 20.0, Obs: 78, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 10.0, Obs: 79, Weight obs: [0.00250141], Smallest density: [0.17348184])
# (Perc: 10.0, Obs: 80, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 20.0, Obs: 80, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 10.0, Obs: 81, Weight obs: [0.00970604], Smallest density: [0.17945152])
# (Perc: 10.0, Obs: 82, Weight obs: [0.00391846], Smallest density: [0.17465599])
# (Perc: 10.0, Obs: 83, Weight obs: [0.00556843], Smallest density: [0.17602314])
# (Perc: 10.0, Obs: 84, Weight obs: [0.00454983], Smallest density: [0.17517914])
# (Perc: 10.0, Obs: 85, Weight obs: [0.0005388], Smallest density: [0.17185564])
# (Perc: 10.0, Obs: 86, Weight obs: [0.00173726], Smallest density: [0.17284866])
# (Perc: 10.0, Obs: 87, Weight obs: [0.00134714], Smallest density: [0.17252542])
# (Perc: 10.0, Obs: 88, Weight obs: [0.00065674], Smallest density: [0.17195336])
# (Perc: 10.0, Obs: 89, Weight obs: [0.00433587], Smallest density: [0.17500185])
# (Perc: 10.0, Obs: 90, Weight obs: [0.00231253], Smallest density: [0.17332533])
# (Perc: 10.0, Obs: 91, Weight obs: [0.00086178], Smallest density: [0.17212326])
# (Perc: 10.0, Obs: 92, Weight obs: [0.00144034], Smallest density: [0.17260264])
# (Perc: 10.0, Obs: 93, Weight obs: [0.01417273], Smallest density: [0.18315258])
# (Perc: 10.0, Obs: 94, Weight obs: [0.00718425], Smallest density: [0.17736199])
# (Perc: 10.0, Obs: 95, Weight obs: [0.00217455], Smallest density: [0.17321101])
# (Perc: 10.0, Obs: 96, Weight obs: [0.00799318], Smallest density: [0.17803226])
# (Perc: 10.0, Obs: 97, Weight obs: [0.00238951], Smallest density: [0.17338911])
# (Perc: 10.0, Obs: 98, Weight obs: [0.00161631], Smallest density: [0.17274845])
# (Perc: 10.0, Obs: 99, Weight obs: [0.00173366], Smallest density: [0.17284569])
# (Perc: 10.0, Obs: 100, Weight obs: [0.00420046], Smallest density: [0.17488965])
# (Perc: 10.0, Obs: 101, Weight obs: [0.01493163], Smallest density: [0.1837814])
# (Perc: 10.0, Obs: 102, Weight obs: [0.00142237], Smallest density: [0.17258775])
# (Perc: 10.0, Obs: 103, Weight obs: [0.00093687], Smallest density: [0.17218547])
# (Perc: 10.0, Obs: 104, Weight obs: [0.00084807], Smallest density: [0.17211189])
# (Perc: 10.0, Obs: 105, Weight obs: [0.0017141], Smallest density: [0.17282947])
# (Perc: 10.0, Obs: 106, Weight obs: [0.00084106], Smallest density: [0.17210608])
# (Perc: 10.0, Obs: 107, Weight obs: [0.0047749], Smallest density: [0.17536562])
# (Perc: 10.0, Obs: 108, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 20.0, Obs: 108, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 10.0, Obs: 109, Weight obs: [0.0031309], Smallest density: [0.17400342])
# (Perc: 10.0, Obs: 110, Weight obs: [0.00448978], Smallest density: [0.17512938])
# (Perc: 10.0, Obs: 111, Weight obs: [0.00135188], Smallest density: [0.17252935])
# (Perc: 10.0, Obs: 112, Weight obs: [0.00296807], Smallest density: [0.1738685])
# (Perc: 10.0, Obs: 113, Weight obs: [0.00707143], Smallest density: [0.17726851])
# (Perc: 10.0, Obs: 114, Weight obs: [0.00328084], Smallest density: [0.17412766])
# (Perc: 10.0, Obs: 115, Weight obs: [0.00124935], Smallest density: [0.17244439])
# (Perc: 10.0, Obs: 116, Weight obs: [0.00873807], Smallest density: [0.17864948])
# (Perc: 10.0, Obs: 117, Weight obs: [0.0065108], Smallest density: [0.17680398])
# (Perc: 10.0, Obs: 118, Weight obs: [0.00040832], Smallest density: [0.17174752])
# (Perc: 10.0, Obs: 119, Weight obs: [0.00474511], Smallest density: [0.17534094])
# (Perc: 10.0, Obs: 120, Weight obs: [0.00978554], Smallest density: [0.1795174])
# (Perc: 10.0, Obs: 121, Weight obs: [0.00617669], Smallest density: [0.17652714])
# (Perc: 10.0, Obs: 122, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 20.0, Obs: 122, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 10.0, Obs: 123, Weight obs: [0.00370971], Smallest density: [0.17448302])
# (Perc: 10.0, Obs: 124, Weight obs: [0.00414514], Smallest density: [0.17484382])
# (Perc: 10.0, Obs: 125, Weight obs: [0.00538949], Smallest density: [0.17587487])
# (Perc: 10.0, Obs: 126, Weight obs: [0.00231005], Smallest density: [0.17332328])
# (Perc: 10.0, Obs: 127, Weight obs: [0.00236415], Smallest density: [0.1733681])
# (Perc: 10.0, Obs: 128, Weight obs: [0.00097997], Smallest density: [0.17222118])
# (Perc: 10.0, Obs: 129, Weight obs: [0.0087216], Smallest density: [0.17863583])
# (Perc: 10.0, Obs: 130, Weight obs: [0.00193951], Smallest density: [0.17301625])
# (Perc: 10.0, Obs: 131, Weight obs: [0.0030939], Smallest density: [0.17397276])
# (Perc: 10.0, Obs: 132, Weight obs: [0.01402133], Smallest density: [0.18302714])
# (Perc: 10.0, Obs: 133, Weight obs: [0.00445141], Smallest density: [0.17509758])
# (Perc: 10.0, Obs: 134, Weight obs: [0.00102228], Smallest density: [0.17225624])
# (Perc: 10.0, Obs: 135, Weight obs: [0.00228793], Smallest density: [0.17330494])
# (Perc: 10.0, Obs: 136, Weight obs: [0.00105446], Smallest density: [0.1722829])
# (Perc: 10.0, Obs: 137, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 20.0, Obs: 137, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 10.0, Obs: 138, Weight obs: [0.02356959], Smallest density: [0.19093873])
# (Perc: 10.0, Obs: 139, Weight obs: [0.02356959], Smallest density: [0.19093873])
# (Perc: 10.0, Obs: 140, Weight obs: [0.00596217], Smallest density: [0.17634939])
# (Perc: 10.0, Obs: 141, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 20.0, Obs: 141, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 10.0, Obs: 142, Weight obs: [0.00278005], Smallest density: [0.17371271])
# (Perc: 10.0, Obs: 143, Weight obs: [0.00779593], Smallest density: [0.17786882])
# (Perc: 10.0, Obs: 144, Weight obs: [0.00193951], Smallest density: [0.17301625])
# (Perc: 10.0, Obs: 145, Weight obs: [0.01493163], Smallest density: [0.1837814])
# (Perc: 10.0, Obs: 146, Weight obs: [0.00571718], Smallest density: [0.1761464])
# (Perc: 10.0, Obs: 147, Weight obs: [0.00941405], Smallest density: [0.17920958])
# (Perc: 10.0, Obs: 148, Weight obs: [0.0005388], Smallest density: [0.17185564])
# (Perc: 10.0, Obs: 149, Weight obs: [0.00058091], Smallest density: [0.17189053])
# (Perc: 10.0, Obs: 150, Weight obs: [0.00314674], Smallest density: [0.17401655])
# (Perc: 10.0, Obs: 151, Weight obs: [0.01367956], Smallest density: [0.18274395])
# (Perc: 10.0, Obs: 152, Weight obs: [0.00186991], Smallest density: [0.17295858])
# (Perc: 10.0, Obs: 153, Weight obs: [0.00108753], Smallest density: [0.17231031])
# (Perc: 10.0, Obs: 154, Weight obs: [0.00405502], Smallest density: [0.17476914])
# (Perc: 10.0, Obs: 155, Weight obs: [0.02829378], Smallest density: [0.19485316])
# (Perc: 10.0, Obs: 156, Weight obs: [0.00721163], Smallest density: [0.17738468])
# (Perc: 10.0, Obs: 157, Weight obs: [0.01524437], Smallest density: [0.18404053])
# (Perc: 10.0, Obs: 158, Weight obs: [0.00029546], Smallest density: [0.171654])
# (Perc: 10.0, Obs: 159, Weight obs: [0.00296174], Smallest density: [0.17386326])
# (Perc: 10.0, Obs: 160, Weight obs: [0.00722341], Smallest density: [0.17739444])
# (Perc: 10.0, Obs: 161, Weight obs: [0.00090629], Smallest density: [0.17216013])
# (Perc: 10.0, Obs: 162, Weight obs: [0.00213816], Smallest density: [0.17318085])
# (Perc: 10.0, Obs: 163, Weight obs: [0.01466914], Smallest density: [0.18356391])
# (Perc: 10.0, Obs: 164, Weight obs: [0.00833762], Smallest density: [0.17831766])
# (Perc: 10.0, Obs: 165, Weight obs: [0.00617669], Smallest density: [0.17652714])
# (Perc: 10.0, Obs: 166, Weight obs: [0.00523561], Smallest density: [0.17574737])
# (Perc: 10.0, Obs: 167, Weight obs: [0.00974612], Smallest density: [0.17948474])
# (Perc: 10.0, Obs: 168, Weight obs: [0.00554992], Smallest density: [0.1760078])
# (Perc: 10.0, Obs: 169, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 20.0, Obs: 169, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 10.0, Obs: 170, Weight obs: [0.02829378], Smallest density: [0.19485316])
# (Perc: 10.0, Obs: 171, Weight obs: [0.00758306], Smallest density: [0.17769244])
# (Perc: 10.0, Obs: 172, Weight obs: [0.01077936], Smallest density: [0.18034087])
# (Perc: 10.0, Obs: 173, Weight obs: [0.00130458], Smallest density: [0.17249016])
# (Perc: 10.0, Obs: 174, Weight obs: [0.00125037], Smallest density: [0.17244524])
# (Perc: 10.0, Obs: 175, Weight obs: [0.00852532], Smallest density: [0.17847319])
# (Perc: 10.0, Obs: 176, Weight obs: [0.00089921], Smallest density: [0.17215427])
# (Perc: 10.0, Obs: 177, Weight obs: [0.00159851], Smallest density: [0.1727337])
# (Perc: 10.0, Obs: 178, Weight obs: [0.00106364], Smallest density: [0.17229051])
# (Perc: 10.0, Obs: 179, Weight obs: [0.00313952], Smallest density: [0.17401057])
# (Perc: 10.0, Obs: 180, Weight obs: [0.00501447], Smallest density: [0.17556413])
# (Perc: 10.0, Obs: 181, Weight obs: [0.01466914], Smallest density: [0.18356391])
# (Perc: 10.0, Obs: 182, Weight obs: [0.00089921], Smallest density: [0.17215427])
# (Perc: 10.0, Obs: 183, Weight obs: [0.00159851], Smallest density: [0.1727337])
# (Perc: 10.0, Obs: 184, Weight obs: [0.00523561], Smallest density: [0.17574737])
# (Perc: 10.0, Obs: 185, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 20.0, Obs: 185, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 10.0, Obs: 186, Weight obs: [0.00359659], Smallest density: [0.17438929])
# (Perc: 10.0, Obs: 187, Weight obs: [0.00729757], Smallest density: [0.17745589])
# (Perc: 10.0, Obs: 188, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 20.0, Obs: 188, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 10.0, Obs: 189, Weight obs: [0.00454983], Smallest density: [0.17517914])
# (Perc: 10.0, Obs: 190, Weight obs: [0.00366627], Smallest density: [0.17444702])
# (Perc: 10.0, Obs: 191, Weight obs: [0.00722341], Smallest density: [0.17739444])
# (Perc: 10.0, Obs: 192, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 20.0, Obs: 192, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 10.0, Obs: 193, Weight obs: [0.00078037], Smallest density: [0.1720558])
# (Perc: 10.0, Obs: 194, Weight obs: [0.0022647], Smallest density: [0.1732857])
# (Perc: 10.0, Obs: 195, Weight obs: [0.00200997], Smallest density: [0.17307464])
# (Perc: 10.0, Obs: 196, Weight obs: [0.01121076], Smallest density: [0.18069832])
# (Perc: 10.0, Obs: 197, Weight obs: [0.00393127], Smallest density: [0.17466661])
# (Perc: 10.0, Obs: 198, Weight obs: [0.00273255], Smallest density: [0.17367336])
# (Perc: 10.0, Obs: 199, Weight obs: [0.00222128], Smallest density: [0.17324972])
# (Perc: 10.0, Obs: 200, Weight obs: [0.01392737], Smallest density: [0.18294928])
# (Perc: 10.0, Obs: 201, Weight obs: [0.00451434], Smallest density: [0.17514973])
# (Perc: 10.0, Obs: 202, Weight obs: [0.00188488], Smallest density: [0.17297098])
# (Perc: 10.0, Obs: 203, Weight obs: [0.00564151], Smallest density: [0.17608369])
# (Perc: 10.0, Obs: 204, Weight obs: [0.01046507], Smallest density: [0.18008045])
# (Perc: 10.0, Obs: 205, Weight obs: [0.00203427], Smallest density: [0.17309477])
# (Perc: 10.0, Obs: 206, Weight obs: [0.00068462], Smallest density: [0.17197646])
# (Perc: 10.0, Obs: 207, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 20.0, Obs: 207, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 10.0, Obs: 208, Weight obs: [0.00941405], Smallest density: [0.17920958])
# (Perc: 10.0, Obs: 209, Weight obs: [0.00495462], Smallest density: [0.17551454])
# (Perc: 10.0, Obs: 210, Weight obs: [0.00909172], Smallest density: [0.17894251])
# (Perc: 10.0, Obs: 211, Weight obs: [0.01149856], Smallest density: [0.18093679])
# (Perc: 10.0, Obs: 212, Weight obs: [0.00526057], Smallest density: [0.17576805])
# (Perc: 10.0, Obs: 213, Weight obs: [0.00196654], Smallest density: [0.17303864])
# (Perc: 10.0, Obs: 214, Weight obs: [0.02184445], Smallest density: [0.1895093])
# (Perc: 10.0, Obs: 215, Weight obs: [0.00136675], Smallest density: [0.17254166])
# (Perc: 10.0, Obs: 216, Weight obs: [0.00648117], Smallest density: [0.17677943])
# (Perc: 10.0, Obs: 217, Weight obs: [0.0020545], Smallest density: [0.17311153])
# (Perc: 10.0, Obs: 218, Weight obs: [0.00070774], Smallest density: [0.17199562])
# (Perc: 10.0, Obs: 219, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 20.0, Obs: 219, Weight obs: [0.03624651], Smallest density: [0.20144271])
# (Perc: 10.0, Obs: 220, Weight obs: [0.0047749], Smallest density: [0.17536562])
# (Perc: 10.0, Obs: 221, Weight obs: [0.00228129], Smallest density: [0.17329944])
# (Perc: 10.0, Obs: 222, Weight obs: [0.00941405], Smallest density: [0.17920958])
# (Perc: 10.0, Obs: 223, Weight obs: [0.00376082], Smallest density: [0.17452537])
# (Perc: 10.0, Obs: 224, Weight obs: [0.00648117], Smallest density: [0.17677943])
# (Perc: 10.0, Obs: 225, Weight obs: [0.0013915], Smallest density: [0.17256218])
# (Perc: 10.0, Obs: 226, Weight obs: [0.00597176], Smallest density: [0.17635733])
# (Perc: 10.0, Obs: 227, Weight obs: [0.00718425], Smallest density: [0.17736199])
# (Perc: 10.0, Obs: 228, Weight obs: [0.00107251], Smallest density: [0.17229786])
# (Perc: 10.0, Obs: 229, Weight obs: [0.00128392], Smallest density: [0.17247303])
# (Perc: 10.0, Obs: 230, Weight obs: [0.0020545], Smallest density: [0.17311153])
# (Perc: 10.0, Obs: 231, Weight obs: [0.00087052], Smallest density: [0.1721305])
# (Perc: 10.0, Obs: 232, Weight obs: [0.01356438], Smallest density: [0.18264851])
# (Perc: 10.0, Obs: 233, Weight obs: [0.01524437], Smallest density: [0.18404053])
# (Perc: 10.0, Obs: 234, Weight obs: [0.00474511], Smallest density: [0.17534094])
# (Perc: 10.0, Obs: 235, Weight obs: [0.00164696], Smallest density: [0.17277385])
# (Perc: 10.0, Obs: 236, Weight obs: [0.00139372], Smallest density: [0.17256402])
# (Perc: 10.0, Obs: 237, Weight obs: [0.00526942], Smallest density: [0.17577538])
# (Perc: 10.0, Obs: 238, Weight obs: [0.00336118], Smallest density: [0.17419423])
# (Perc: 10.0, Obs: 239, Weight obs: [0.00114716], Smallest density: [0.17235972])
# (Perc: 10.0, Obs: 240, Weight obs: [0.01356438], Smallest density: [0.18264851])
# (Perc: 10.0, Obs: 241, Weight obs: [0.00722341], Smallest density: [0.17739444])
# (Perc: 10.0, Obs: 242, Weight obs: [0.00060336], Smallest density: [0.17190913])
# (Perc: 10.0, Obs: 243, Weight obs: [0.00125739], Smallest density: [0.17245105])
# (Perc: 10.0, Obs: 244, Weight obs: [0.00371466], Smallest density: [0.17448712])
# (Perc: 10.0, Obs: 245, Weight obs: [0.00238951], Smallest density: [0.17338911])
# (Perc: 10.0, Obs: 246, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 20.0, Obs: 246, Weight obs: [0.05274967], Smallest density: [0.21511708])
# (Perc: 10.0, Obs: 247, Weight obs: [0.0025476], Smallest density: [0.17352011])
# (Perc: 10.0, Obs: 248, Weight obs: [0.00089544], Smallest density: [0.17215115])
# (Perc: 10.0, Obs: 249, Weight obs: [0.00677199], Smallest density: [0.17702039]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:591: UserWarning: the no. of calibration examples is too smallfor the chosen confidence level; the intervals will be of maximum size
#   warnings.warn(
#  19%|█▉        | 193/1000 [00:46<03:14,  4.15it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 21, Weight obs: [0.11872222], Smallest density: [0.11891823])
# ...
# (Perc: 9.999999999999998, Obs: 226, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 9.999999999999998, Obs: 231, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 9.999999999999998, Obs: 246, Weight obs: [0.12855164], Smallest density: [0.13020589]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1270: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 11, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 25, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 29, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 37, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 75, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 100, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 118, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 123, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 147, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 149, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 153, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 202, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 216, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 219, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 220, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 224, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 226, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 231, Weight obs: [0.12855164])
# (Perc: 90.0, Obs: 246, Weight obs: [0.12855164]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 11, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 25, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 29, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 37, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 75, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 100, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 118, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 123, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 147, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 149, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 153, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 202, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 216, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 219, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 220, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 224, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 226, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 231, Weight obs: [0.12855164], Smallest density: [0.13020589])
# (Perc: 10.0, Obs: 246, Weight obs: [0.12855164], Smallest density: [0.13020589]); the corresponding values are set to y_min
#   warnings.warn(
#  95%|█████████▌| 950/1000 [03:47<00:12,  4.00it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 47, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 9.999999999999998, Obs: 94, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 9.999999999999998, Obs: 109, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 9.999999999999998, Obs: 140, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 9.999999999999998, Obs: 174, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 9.999999999999998, Obs: 175, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 9.999999999999998, Obs: 219, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 9.999999999999998, Obs: 224, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 9.999999999999998, Obs: 228, Weight obs: [0.08168813], Smallest density: [0.11841357]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 47, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 10.0, Obs: 94, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 10.0, Obs: 109, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 10.0, Obs: 140, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 10.0, Obs: 174, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 10.0, Obs: 175, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 10.0, Obs: 219, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 10.0, Obs: 224, Weight obs: [0.08168813], Smallest density: [0.11841357])
# (Perc: 10.0, Obs: 228, Weight obs: [0.08168813], Smallest density: [0.11841357]); the corresponding values are set to y_min
#   warnings.warn(
#  96%|█████████▌| 959/1000 [03:49<00:10,  4.00it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 11, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 9.999999999999998, Obs: 20, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 9.999999999999998, Obs: 31, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 9.999999999999998, Obs: 62, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 9.999999999999998, Obs: 110, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 9.999999999999998, Obs: 114, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 9.999999999999998, Obs: 149, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 9.999999999999998, Obs: 161, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 9.999999999999998, Obs: 186, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 9.999999999999998, Obs: 199, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 9.999999999999998, Obs: 204, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 9.999999999999998, Obs: 249, Weight obs: [0.11451037], Smallest density: [0.11714428]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1270: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 11, Weight obs: [0.11451037])
# (Perc: 90.0, Obs: 20, Weight obs: [0.11451037])
# (Perc: 90.0, Obs: 31, Weight obs: [0.11451037])
# (Perc: 90.0, Obs: 62, Weight obs: [0.11451037])
# (Perc: 90.0, Obs: 110, Weight obs: [0.11451037])
# (Perc: 90.0, Obs: 114, Weight obs: [0.11451037])
# (Perc: 90.0, Obs: 149, Weight obs: [0.11451037])
# (Perc: 90.0, Obs: 161, Weight obs: [0.11451037])
# (Perc: 90.0, Obs: 186, Weight obs: [0.11451037])
# (Perc: 90.0, Obs: 199, Weight obs: [0.11451037])
# (Perc: 90.0, Obs: 204, Weight obs: [0.11451037])
# (Perc: 90.0, Obs: 249, Weight obs: [0.11451037]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 11, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 10.0, Obs: 20, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 10.0, Obs: 31, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 10.0, Obs: 62, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 10.0, Obs: 110, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 10.0, Obs: 114, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 10.0, Obs: 149, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 10.0, Obs: 161, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 10.0, Obs: 186, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 10.0, Obs: 199, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 10.0, Obs: 204, Weight obs: [0.11451037], Smallest density: [0.11714428])
# (Perc: 10.0, Obs: 249, Weight obs: [0.11451037], Smallest density: [0.11714428]); the corresponding values are set to y_min
#   warnings.warn(
#  97%|█████████▋| 971/1000 [03:52<00:07,  4.09it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 12, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 40, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 60, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 81, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 82, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 87, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 98, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 104, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 113, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 121, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 161, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 180, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 183, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 235, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 9.999999999999998, Obs: 246, Weight obs: [0.10442044], Smallest density: [0.106594]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1270: UserWarning: the no. of calibration examples is too small for the following higher percentiles and observation:
# (Perc: 90.0, Obs: 12, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 40, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 60, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 81, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 82, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 87, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 98, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 104, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 113, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 121, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 161, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 180, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 183, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 235, Weight obs: [0.10442044])
# (Perc: 90.0, Obs: 246, Weight obs: [0.10442044]); the corresponding values are set to y_max
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 12, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 40, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 60, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 81, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 82, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 87, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 98, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 104, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 113, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 121, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 161, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 180, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 183, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 235, Weight obs: [0.10442044], Smallest density: [0.106594])
# (Perc: 10.0, Obs: 246, Weight obs: [0.10442044], Smallest density: [0.106594]); the corresponding values are set to y_min
#   warnings.warn(
#  97%|█████████▋| 974/1000 [03:53<00:06,  4.09it/s]/Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 9.999999999999998, Obs: 2, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 9.999999999999998, Obs: 42, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 9.999999999999998, Obs: 72, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 9.999999999999998, Obs: 78, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 9.999999999999998, Obs: 79, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 9.999999999999998, Obs: 117, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 9.999999999999998, Obs: 145, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 9.999999999999998, Obs: 164, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 9.999999999999998, Obs: 165, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 9.999999999999998, Obs: 203, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 9.999999999999998, Obs: 209, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 9.999999999999998, Obs: 225, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 9.999999999999998, Obs: 237, Weight obs: [0.03590539], Smallest density: [0.10461463]); the corresponding values are set to y_min
#   warnings.warn(
# /Users/jefjonkers/Code/crepes-weighted/src/crepes_weighted/base.py:1195: UserWarning: the no. of calibration examples is too small for the following lower percentiles and observation:
# (Perc: 10.0, Obs: 2, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 10.0, Obs: 42, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 10.0, Obs: 72, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 10.0, Obs: 78, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 10.0, Obs: 79, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 10.0, Obs: 117, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 10.0, Obs: 145, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 10.0, Obs: 164, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 10.0, Obs: 165, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 10.0, Obs: 203, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 10.0, Obs: 209, Weight obs: [0.03590539], Smallest density: [0.10461463])
# (Perc: 10.0, Obs: 225, Weight obs: [0.03875303], Smallest density: [0.10725932])
# (Perc: 10.0, Obs: 237, Weight obs: [0.03590539], Smallest density: [0.10461463]); the corresponding values are set to y_min
#   warnings.warn(
# 100%|██████████| 1000/1000 [03:59<00:00,  4.17it/s]

# %%
df_results_cps_no_shift_syn['Method'] = 'SCPS (no shift)'
df_results_cps_shift_not_weighted_syn['Method'] = 'SCPS (shift)'
df_results_cps_shift_weighted_syn['Method'] = 'WSCPS (shift)'
df_results_cps_no_shift_reduced_syn['Method'] = 'SCPS (no shift, reduced)'
df_results_cp_no_shift_syn['Method'] = 'CP (no shift)'
df_results_cp_shift_not_weighted_syn['Method'] = 'CP (shift)'
df_results_cp_shift_weighted_syn['Method'] = 'WCP (shift)'
df_results_cp_no_shift_reduced_syn['Method'] = 'CP (no shift, reduced)'

df_results_syn = pd.concat([df_results_cps_no_shift_syn, df_results_cps_shift_not_weighted_syn, df_results_cps_shift_weighted_syn,
                        df_results_cps_no_shift_reduced_syn,
                        df_results_cp_no_shift_syn, df_results_cp_shift_not_weighted_syn, df_results_cp_shift_weighted_syn,
                        df_results_cp_no_shift_reduced_syn])

df_results_syn["Coverage"] = 1 - df_results_syn["error"]

fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper left")
# set the color palette
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="Coverage", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper left")
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="Coverage", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper left")
axs[0].vlines(0.8, 0, 250, color='r', linestyle='--')
axs[1].vlines(0.8, 0, 200, color='r', linestyle='--')
axs[2].vlines(0.8, 0, 175, color='r', linestyle='--')
plt.tight_layout()
plt.savefig("plots/coverage_synthetic.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
fig, axs = plt.subplots(3, 1, figsize=(4, 9), sharex=True)
bins = 20
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[0], bins=bins)
sns.move_legend(axs[0], "upper right")
# set the color palette
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (shift)'])]
             , x="CRPS", hue="Method", kde=True, ax=axs[1], bins=bins,
             palette=[sns.color_palette()[1], sns.color_palette()[2]])
sns.move_legend(axs[1], "upper right")
sns.histplot(data=df_results_syn[df_results_syn["Method"].isin(['WSCPS (shift)',
                                                        'SCPS (no shift, reduced)'])]
                , x="CRPS", hue="Method", kde=True, ax=axs[2], bins=bins,
                palette=[sns.color_palette()[2], sns.color_palette()[3]])
sns.move_legend(axs[2], "upper right")
plt.tight_layout()
fig.savefig("plots/crps_synthetic.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import scipy.stats as ss
import scikit_posthocs as sp

df_results_cps = df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)', 'SCPS (shift)', 'WSCPS (shift)', 'SCPS (no shift, reduced)'])]

avg_rank = df_results_cps.groupby("sim_id")["CRPS"].rank(pct=True).groupby(df_results_cps.Method).mean()

ss.friedmanchisquare(*[df_results_cps[df_results_cps.Method == method].CRPS for method in df_results_cps.Method.unique()])

test_results = sp.posthoc_nemenyi_friedman(df_results_cps, melted=True, y_col="CRPS", block_col="sim_id", group_col="Method")

plt.figure(figsize=(10, 2))
# plt.title("Post-hoc Friedman-Nemenyi test for CRPS")
sp.critical_difference_diagram(avg_rank, test_results, color_palette={"SCPS (no shift)": sns.color_palette()[0],
                                                                      "SCPS (shift)": sns.color_palette()[1],
                                                                      "WSCPS (shift)": sns.color_palette()[2],
                                                                      "SCPS (no shift, reduced)": sns.color_palette()[3]})
plt.tight_layout()
plt.savefig("plots/nemenyi_synthetic.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %%
quantile_names = [f"coverage_q{q}" for q in np.arange(10, 100, 10)]

# Plot calibration curves
df_results_cps = df_results_syn[df_results_syn["Method"].isin(['SCPS (no shift)', 'SCPS (shift)', 'WSCPS (shift)', 'SCPS (no shift, reduced)'])]

## melt the data
df_results_cps_melted = pd.melt(df_results_cps, id_vars=["sim_id", "Method"], value_vars=quantile_names, value_name="Error", var_name="Quantile")
df_results_cps_melted["Quantile"] = df_results_cps_melted["Quantile"].str.replace("coverage_q", "").astype(int)

# %%
sns.pointplot(data=df_results_cps_melted, x="Quantile", y="Error", hue="Method", errorbar="sd")
sns.pointplot(y=np.arange(0.1, 1, 0.1), x=np.arange(10, 100, 10), color='black')
plt.savefig("plots/marginal_calibration_synthetic.pdf")

# %%
NSim = 1000

list_p_values_cps = []
list_p_values_wcps = []
list_p_values_cps_no_shift = []
for i in tqdm(range(NSim)):
    X, y = synthetic_kang_schafer_2007()
    # Without covariate-shift
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
    X_train_prop, X_cal, y_train_prop, y_cal = train_test_split(X_train, y_train, test_size=0.25)

    shift_weights = np.array([-1, 0.5, -0.25, -0.1])
    shifted_likelihood_train_prop = np.exp(X_train_prop @ shift_weights)
    shifted_weights_train_prop = shifted_likelihood_train_prop / np.sum(shifted_likelihood_train_prop)
    shifted_likelihood_test = np.exp(X_test @ shift_weights)
    shifted_weights_test = shifted_likelihood_test / np.sum(shifted_likelihood_test)
    shifted_likelihood_cal =  np.exp(X_cal @ shift_weights)

    rf_cps = WrapRegressor(RandomForestRegressor(n_estimators=100, random_state=17))
    rf_cps.fit(X_train_prop, y_train_prop)
    rf_wcps = copy.deepcopy(rf_cps)


    idx_shift = weighted_sample(shifted_weights_test, frac=0.5)
    idx_no_shift = weighted_sample(np.ones(len(y_test))/ len(y_test), frac=0.5)

    rf_cps.calibrate(X_cal, y_cal, cps=True)
    rf_wcps.calibrate(X_cal, y_cal, likelihood_ratios=shifted_likelihood_cal, cps=True)

    p_values_cps = rf_cps.predict_cps(X_test[idx_shift], y=y_test[idx_shift])
    p_values_cps_no_shift = rf_cps.predict_cps(X_test[idx_no_shift], y=y_test[idx_no_shift])
    p_values_wcps = rf_wcps.predict_cps(X_test[idx_shift], y=y_test[idx_shift], likelihood_ratios=shifted_likelihood_test[idx_shift])

    list_p_values_cps.append(p_values_cps)
    list_p_values_cps_no_shift.append(p_values_cps_no_shift)
    list_p_values_wcps.append(p_values_wcps)
# Out:
# 100%|██████████| 1000/1000 [03:13<00:00,  5.16it/s]

# %%
fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
bins = 30
sns.histplot(np.concatenate(list_p_values_cps_no_shift), ax = axs[0], bins=bins,
             color=sns.color_palette()[0], label="CPS (no shift)")
sns.histplot(np.concatenate(list_p_values_cps), ax = axs[1], bins=bins,
             color=sns.color_palette()[1], label="CPS (shift)")
sns.histplot(np.concatenate(list_p_values_wcps), ax = axs[2], bins=bins,
             color=sns.color_palette()[2], label="WCPS (shift)")


axs[0].hlines(len(np.concatenate(list_p_values_cps_no_shift)) / bins, 0, 1, color='r', linestyle='--')
axs[1].hlines(len(np.concatenate(list_p_values_cps)) / bins, 0, 1, color='r', linestyle='--')
axs[2].hlines(len(np.concatenate(list_p_values_wcps)) / bins, 0, 1, color='r', linestyle='--')

axs[0].vlines(0, 0, len(np.concatenate(list_p_values_cps_no_shift)) / bins, color='r', linestyle='--')
axs[1].vlines(0, 0, len(np.concatenate(list_p_values_cps)) / bins, color='r', linestyle='--')
axs[2].vlines(0, 0, len(np.concatenate(list_p_values_wcps)) / bins, color='r', linestyle='--')

axs[0].vlines(1, 0, len(np.concatenate(list_p_values_cps_no_shift)) / bins, color='r', linestyle='--')
axs[1].vlines(1, 0, len(np.concatenate(list_p_values_cps)) / bins, color='r', linestyle='--')
axs[2].vlines(1, 0, len(np.concatenate(list_p_values_wcps)) / bins, color='r', linestyle='--')

axs[0].set_title("Distribution of SCPS(X,y)\n(no shift)")
axs[1].set_title("Distribution of SCPS(X,y)\n(shift)")
axs[2].set_title("Distribution of WSCPS(X,y)\n(shift)")

axs[0].set_xlabel("Q(X,y)")
axs[1].set_xlabel("Q(X,y)")
axs[2].set_xlabel("Q(X,y)")

plt.tight_layout()
fig.savefig("plots/prob_calibration_synthetic.pdf")
plt.show()
# Out:
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
